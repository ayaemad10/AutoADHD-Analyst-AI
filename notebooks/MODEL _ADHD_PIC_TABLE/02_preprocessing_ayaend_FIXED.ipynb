# %% [markdown]
# ## **8th Annual WiDS Datathon Challenges:**
#
# ### **Unraveling the Mysteries of the Female Brain**
#
# # PREPROCESSING

# %% [markdown]
# * [0. Imports](#0-imports)
# * [1. Handling Missing Data](#1-handling-missing-data)
# * [2. Feature Engineering](#2-feature-engineering)
# * [3. Dimensionality reduction](#3-dimensionality-reduction)
# * [4. Train Test Split](#4-train-test-split)
# * [5. Data Export](#5-data-export)

# %% [markdown]
# # 0. Imports

# %%
import sys
import re
import math
import openpyxl
import joblib

import numpy as np
import pandas as pd
import scipy
import scipy.stats as stats

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import plotly as py

import sklearn
from sklearn.preprocessing import (
    LabelEncoder,
    MinMaxScaler,
    OneHotEncoder,
    StandardScaler,
)
from sklearn.model_selection import (
    train_test_split,
)
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectFromModel
from sklearn.manifold import TSNE


print(f"python version: {sys.version}")
print(f"pandas version: {pd.__version__}")
print(f"numpy version: {np.__version__}")
print(f"matplotlib version: {matplotlib.__version__}")
print(f"seaborn version: {sns.__version__}")
print(f"plotly version: {py.__version__}")
print(f"scikit-learn version: {sklearn.__version__}")
print(f"scipy version: {scipy.__version__}")
# Out:
# python version: 3.11.0 (main, Oct 24 2022, 18:26:48) [MSC v.1933 64 bit (AMD64)]
# pandas version: 3.0.3
# numpy version: 2.4.6
# matplotlib version: 3.11.1
# seaborn version: 0.13.2
# plotly version: 6.9.0
# scikit-learn version: 1.9.0
# scipy version: 1.17.1

# %%
import os

zip_path = r"C:\Users\Admin\Downloads\model_adhd\widsdatathon2025.zip"

print(os.path.exists(zip_path))
# Out:
# True

# %%
import zipfile
import os

zip_path = r"C:\Users\Admin\Downloads\model_adhd\widsdatathon2025.zip"
extract_path = r"C:\Users\Admin\Downloads\model_adhd\widsdatathon2025"

os.makedirs(extract_path, exist_ok=True)

with zipfile.ZipFile(zip_path, "r") as zip_ref:
    zip_ref.extractall(extract_path)

print("Extraction completed.")
# Out:
# Extraction completed.

# %%
import os

print(os.listdir(r"C:\Users\Admin\Downloads\model_adhd\widsdatathon2025"))
# Out:
# ['Data Dictionary.xlsx', 'SAMPLE_SUBMISSION.xlsx', 'TEST', 'TRAIN_NEW', 'TRAIN_OLD']

# %%
# data paths

file_path_train_cat_md = "../data/raw/TRAIN_NEW/TRAIN_CATEGORICAL_METADATA_new.xlsx"
file_path_train_fun_cm = "../data/raw/TRAIN_NEW/TRAIN_FUNCTIONAL_CONNECTOME_MATRICES_new_36P_Pearson.csv"
file_path_train_quan_md = "../data/raw/TRAIN_NEW/TRAIN_QUANTITATIVE_METADATA_new.xlsx"
file_path_train_sol = "../data/raw/TRAIN_NEW/TRAINING_SOLUTIONS.xlsx"

# %%
import os
import pandas as pd

base_path = r"C:\Users\Admin\Downloads\model_adhd\widsdatathon2025"

file_path_train_cat_md = os.path.join(base_path, "TRAIN_NEW", "TRAIN_CATEGORICAL_METADATA_new.xlsx")
file_path_train_fun_cm = os.path.join(base_path, "TRAIN_NEW", "TRAIN_FUNCTIONAL_CONNECTOME_MATRICES_new_36P_Pearson.csv")
file_path_train_quan_md = os.path.join(base_path, "TRAIN_NEW", "TRAIN_QUANTITATIVE_METADATA_new.xlsx")
file_path_train_sol = os.path.join(base_path, "TRAIN_NEW", "TRAINING_SOLUTIONS.xlsx")

train_cat = pd.read_excel(file_path_train_cat_md)
train_fcm = pd.read_csv(file_path_train_fun_cm)
train_quan = pd.read_excel(file_path_train_quan_md)
train_sol = pd.read_excel(file_path_train_sol)

# %%
print("\nTRAIN_CATEGORICAL_METADATA.xlsx - records:")
print(train_cat.shape[0])
print("\nTRAIN_FUNCTIONAL_CONNECTOME_MATRICES.csv - records:")
print(train_fcm.shape[0])
print("\nTRAIN_QUANTITATIVE_METADATA.xlsx - records:")
print(train_quan.shape[0])
print("\nTRAINING_SOLUTIONS.xlsx - records:")
print(train_sol.shape[0])
# Out:
# TRAIN_CATEGORICAL_METADATA.xlsx - records:
# 1213
#
# TRAIN_FUNCTIONAL_CONNECTOME_MATRICES.csv - records:
# 1213
#
# TRAIN_QUANTITATIVE_METADATA.xlsx - records:
# 1213
#
# TRAINING_SOLUTIONS.xlsx - records:
# 1213

# %% [markdown]
# # 1. Handling Missing Data

# %% [markdown]
# ### Handling null values

# %%
print("\nTRAIN_CATEGORICAL_METADATA.xlsx")
print(train_cat.isnull().sum())
# Out:
# TRAIN_CATEGORICAL_METADATA.xlsx
# participant_id                        0
# Basic_Demos_Enroll_Year               0
# Basic_Demos_Study_Site                0
# PreInt_Demos_Fam_Child_Ethnicity     43
# PreInt_Demos_Fam_Child_Race          54
# MRI_Track_Scan_Location               3
# Barratt_Barratt_P1_Edu               15
# Barratt_Barratt_P1_Occ               31
# Barratt_Barratt_P2_Edu              198
# Barratt_Barratt_P2_Occ              222
# dtype: int64

# %% [markdown]
# PreInt_Demos_Fam_Child_Ethnicity
#
# ✅  3 = Unknown (from data dictionary)

# %%
train_cat.fillna({'PreInt_Demos_Fam_Child_Ethnicity': 3}, inplace=True)
# Out:
#      participant_id  Basic_Demos_Enroll_Year  Basic_Demos_Study_Site  \
# 0      00aIpNTbG5uh                     2019                       4
# 1      00fV0OyyoLfw                     2017                       1
# 2      04X1eiS79T4B                     2017                       1
# 3      05ocQutkURd6                     2018                       1
# 4      06YUNBA9ZRLq                     2018                       1
# ...             ...                      ...                     ...
# 1208   zwjJWCRzKhDz                     2019                       4
# 1209   zwXD5v17Rx01                     2018                       1
# 1210   zWzLCi3NTBTd                     2018                       3
# 1211   Zy9GTHDxUbXU                     2019                       4
# 1212   Zye7yYRQohXi                     2017                       1
#
#       PreInt_Demos_Fam_Child_Ethnicity  PreInt_Demos_Fam_Child_Race  \
# 0                                  1.0                          0.0
# 1                                  0.0                          9.0
# 2                                  1.0                          2.0
# 3                                  3.0                          8.0
# 4                                  0.0                          1.0
# ...                                ...                          ...
# 1208                               1.0                          1.0
# 1209                               0.0                          0.0
# 1210                               2.0                          3.0
# 1211                               0.0                          1.0
# 1212                               0.0                          0.0
#
#       MRI_Track_Scan_Location  Barratt_Barratt_P1_Edu  Barratt_Barratt_P1_Occ  \
# 0                         3.0                    21.0                    45.0
# 1                         2.0                    21.0                     0.0
# 2                         2.0                     9.0                     0.0
# 3                         2.0                    18.0                    10.0
# 4                         2.0                    12.0                     0.0
# ...                       ...                     ...                     ...
# 1208                      3.0                    12.0                     NaN
# 1209                      3.0                    21.0                    40.0
# 1210                      3.0                    21.0                    40.0
# 1211                      3.0                    18.0                    35.0
# 1212                      2.0                    18.0                    35.0
#
#       Barratt_Barratt_P2_Edu  Barratt_Barratt_P2_Occ
# 0                        NaN                     NaN
# 1                       21.0                    45.0
# 2                        NaN                     NaN
# 3                       18.0                     0.0
# 4                        NaN                     NaN
# ...                      ...                     ...
# 1208                    15.0                     5.0
# 1209                    21.0                    40.0
# 1210                    21.0                    35.0
# 1211                    18.0                    45.0
# 1212                    15.0                    35.0
#
# [1213 rows x 10 columns]

# %% [markdown]
# PreInt_Demos_Fam_Child_Race
#
# ✅  10 = Unknown (from data dictionary)

# %%
train_cat.fillna({'PreInt_Demos_Fam_Child_Race': 10}, inplace=True)
# Out:
#      participant_id  Basic_Demos_Enroll_Year  Basic_Demos_Study_Site  \
# 0      00aIpNTbG5uh                     2019                       4
# 1      00fV0OyyoLfw                     2017                       1
# 2      04X1eiS79T4B                     2017                       1
# 3      05ocQutkURd6                     2018                       1
# 4      06YUNBA9ZRLq                     2018                       1
# ...             ...                      ...                     ...
# 1208   zwjJWCRzKhDz                     2019                       4
# 1209   zwXD5v17Rx01                     2018                       1
# 1210   zWzLCi3NTBTd                     2018                       3
# 1211   Zy9GTHDxUbXU                     2019                       4
# 1212   Zye7yYRQohXi                     2017                       1
#
#       PreInt_Demos_Fam_Child_Ethnicity  PreInt_Demos_Fam_Child_Race  \
# 0                                  1.0                          0.0
# 1                                  0.0                          9.0
# 2                                  1.0                          2.0
# 3                                  3.0                          8.0
# 4                                  0.0                          1.0
# ...                                ...                          ...
# 1208                               1.0                          1.0
# 1209                               0.0                          0.0
# 1210                               2.0                          3.0
# 1211                               0.0                          1.0
# 1212                               0.0                          0.0
#
#       MRI_Track_Scan_Location  Barratt_Barratt_P1_Edu  Barratt_Barratt_P1_Occ  \
# 0                         3.0                    21.0                    45.0
# 1                         2.0                    21.0                     0.0
# 2                         2.0                     9.0                     0.0
# 3                         2.0                    18.0                    10.0
# 4                         2.0                    12.0                     0.0
# ...                       ...                     ...                     ...
# 1208                      3.0                    12.0                     NaN
# 1209                      3.0                    21.0                    40.0
# 1210                      3.0                    21.0                    40.0
# 1211                      3.0                    18.0                    35.0
# 1212                      2.0                    18.0                    35.0
#
#       Barratt_Barratt_P2_Edu  Barratt_Barratt_P2_Occ
# 0                        NaN                     NaN
# 1                       21.0                    45.0
# 2                        NaN                     NaN
# 3                       18.0                     0.0
# 4                        NaN                     NaN
# ...                      ...                     ...
# 1208                    15.0                     5.0
# 1209                    21.0                    40.0
# 1210                    21.0                    35.0
# 1211                    18.0                    45.0
# 1212                    15.0                    35.0
#
# [1213 rows x 10 columns]

# %%
columns=train_cat.columns

# %%
for col in columns:
    print(f"Column: {col}")
    print(train_cat.groupby([col]).size())
# Out:
# Column: participant_id
# participant_id
# 00aIpNTbG5uh    1
# 00fV0OyyoLfw    1
# 04X1eiS79T4B    1
# 05ocQutkURd6    1
# 06YUNBA9ZRLq    1
#                ..
# zpU7rEseBMH8    1
# zpr8w4jCfVPe    1
# zwBG0rZ05Mcb    1
# zwXD5v17Rx01    1
# zwjJWCRzKhDz    1
# Length: 1213, dtype: int64
# Column: Basic_Demos_Enroll_Year
# Basic_Demos_Enroll_Year
# 2015     36
# 2016    191
# 2017    254
# 2018    415
# 2019    312
# 2020      5
# dtype: int64
# Column: Basic_Demos_Study_Site
# Basic_Demos_Study_Site
# 1    652
# 2     11
# 3    430
# 4    120
# dtype: int64
# Column: PreInt_Demos_Fam_Child_Ethnicity
# PreInt_Demos_Fam_Child_Ethnicity
# 0.0    777
# 1.0    296
# 2.0     77
# 3.0     63
# dtype: int64
# Column: PreInt_Demos_Fam_Child_Race
# PreInt_Demos_Fam_Child_Race
# 0.0     573
# 1.0     181
# 2.0     128
# 3.0      30
# 4.0      10
# 7.0       2
# 8.0     195
# 9.0      23
# 10.0     65
# 11.0      6
# dtype: int64
# Column: MRI_Track_Scan_Location
# MRI_Track_Scan_Location
# 1.0    179
# 2.0    532
# 3.0    463
# 4.0     36
# dtype: int64
# Column: Barratt_Barratt_P1_Edu
# Barratt_Barratt_P1_Edu
# 3.0       5
# 6.0      15
# 9.0      28
# 12.0     97
# 15.0    162
# 18.0    421
# 21.0    470
# dtype: int64
# Column: Barratt_Barratt_P1_Occ
# Barratt_Barratt_P1_Occ
# 0.0     286
# 5.0      31
# 10.0      6
# 15.0     35
# 20.0     31
# 25.0     79
# 30.0    154
# 35.0    219
# 40.0    154
# 45.0    187
# dtype: int64
# Column: Barratt_Barratt_P2_Edu
# Barratt_Barratt_P2_Edu
# 3.0       5
# 6.0      14
# 9.0      44
# 12.0    162
# 15.0    166
# 18.0    301
# 21.0    323
# dtype: int64
# Column: Barratt_Barratt_P2_Occ
# Barratt_Barratt_P2_Occ
# 0.0      65
# 5.0      38
# 10.0     37
# 15.0     86
# 20.0     41
# 25.0     25
# 30.0    149
# 35.0    195
# 40.0    116
# 45.0    239
# dtype: int64

# %%
# Print rows where 'MRI_Track_Scan_Location' column has missing values (NaN)
missing_values_rows = train_cat[train_cat['MRI_Track_Scan_Location'].isna()]

missing_values_rows.head()
# Out:
#      participant_id  Basic_Demos_Enroll_Year  Basic_Demos_Study_Site  \
# 998    UmN79UUheNpw                     2016                       1
# 1095   x0yuhCZiG4mU                     2016                       1
# 1200   zSOTbT8r7FQ2                     2016                       1
#
#       PreInt_Demos_Fam_Child_Ethnicity  PreInt_Demos_Fam_Child_Race  \
# 998                                0.0                          0.0
# 1095                               0.0                          0.0
# 1200                               0.0                         10.0
#
#       MRI_Track_Scan_Location  Barratt_Barratt_P1_Edu  Barratt_Barratt_P1_Occ  \
# 998                       NaN                    21.0                    25.0
# 1095                      NaN                    18.0                    40.0
# 1200                      NaN                    15.0                     0.0
#
#       Barratt_Barratt_P2_Edu  Barratt_Barratt_P2_Occ
# 998                     18.0                    45.0
# 1095                    18.0                    45.0
# 1200                    21.0                    35.0

# %%
# Print rows where 'MRI_Track_Scan_Location' column has missing values (NaN)
df = train_cat[train_cat['Basic_Demos_Study_Site']==1]

df.describe()
# Out:
#        Basic_Demos_Enroll_Year  Basic_Demos_Study_Site  \
# count               652.000000                   652.0
# mean               2017.203988                     1.0
# std                   1.149280                     0.0
# min                2015.000000                     1.0
# 25%                2016.000000                     1.0
# 50%                2017.000000                     1.0
# 75%                2018.000000                     1.0
# max                2019.000000                     1.0
#
#        PreInt_Demos_Fam_Child_Ethnicity  PreInt_Demos_Fam_Child_Race  \
# count                        652.000000                   652.000000
# mean                           0.613497                     2.592025
# std                            0.904504                     3.621806
# min                            0.000000                     0.000000
# 25%                            0.000000                     0.000000
# 50%                            0.000000                     1.000000
# 75%                            1.000000                     4.000000
# max                            3.000000                    11.000000
#
#        MRI_Track_Scan_Location  Barratt_Barratt_P1_Edu  \
# count               649.000000              646.000000
# mean                  1.876733               17.284830
# std                   0.601103                3.869898
# min                   1.000000                3.000000
# 25%                   2.000000               15.000000
# 50%                   2.000000               18.000000
# 75%                   2.000000               21.000000
# max                   4.000000               21.000000
#
#        Barratt_Barratt_P1_Occ  Barratt_Barratt_P2_Edu  Barratt_Barratt_P2_Occ
# count              639.000000               550.00000              535.000000
# mean                24.241002                16.32000               28.794393
# std                 16.978083                 4.08018               13.941920
# min                  0.000000                 3.00000                0.000000
# 25%                  0.000000                12.00000               15.000000
# 50%                 30.000000                18.00000               35.000000
# 75%                 40.000000                21.00000               40.000000
# max                 45.000000                21.00000               45.000000

# %%
# Print rows where 'MRI_Track_Scan_Location' column has missing values (NaN)
df = train_cat[(train_cat['Basic_Demos_Study_Site'] == 1) & (train_cat['Basic_Demos_Enroll_Year'] == 2016)]

df.describe()
# Out:
#        Basic_Demos_Enroll_Year  Basic_Demos_Study_Site  \
# count                    170.0                   170.0
# mean                    2016.0                     1.0
# std                        0.0                     0.0
# min                     2016.0                     1.0
# 25%                     2016.0                     1.0
# 50%                     2016.0                     1.0
# 75%                     2016.0                     1.0
# max                     2016.0                     1.0
#
#        PreInt_Demos_Fam_Child_Ethnicity  PreInt_Demos_Fam_Child_Race  \
# count                        170.000000                   170.000000
# mean                           1.011765                     4.005882
# std                            1.221059                     4.194244
# min                            0.000000                     0.000000
# 25%                            0.000000                     0.000000
# 50%                            0.000000                     2.000000
# 75%                            2.000000                     8.000000
# max                            3.000000                    10.000000
#
#        MRI_Track_Scan_Location  Barratt_Barratt_P1_Edu  \
# count               167.000000              168.000000
# mean                  1.245509               17.000000
# std                   0.431683                3.962398
# min                   1.000000                3.000000
# 25%                   1.000000               15.000000
# 50%                   1.000000               18.000000
# 75%                   1.000000               21.000000
# max                   2.000000               21.000000
#
#        Barratt_Barratt_P1_Occ  Barratt_Barratt_P2_Edu  Barratt_Barratt_P2_Occ
# count              167.000000               130.00000              130.000000
# mean                22.754491                16.50000               27.653846
# std                 17.300138                 4.18052               13.909849
# min                  0.000000                 3.00000                0.000000
# 25%                  0.000000                12.00000               15.000000
# 50%                 30.000000                18.00000               30.000000
# 75%                 35.000000                21.00000               35.000000
# max                 45.000000                21.00000               45.000000

# %%
df
# Out:
#      participant_id  Basic_Demos_Enroll_Year  Basic_Demos_Study_Site  \
# 10     0JhQVAT7btJ5                     2016                       1
# 16     0ST9wPiJpQ8h                     2016                       1
# 25     1CrYokgmRpSg                     2016                       1
# 28     1HthYue8JWqZ                     2016                       1
# 29     1iFfsUtpS5rB                     2016                       1
# ...             ...                      ...                     ...
# 1163   z1FVD7d0BGpV                     2016                       1
# 1195   zQHCPgcPgAbd                     2016                       1
# 1197   ZrEocbbTa2lB                     2016                       1
# 1200   zSOTbT8r7FQ2                     2016                       1
# 1207   zwBG0rZ05Mcb                     2016                       1
#
#       PreInt_Demos_Fam_Child_Ethnicity  PreInt_Demos_Fam_Child_Race  \
# 10                                 3.0                         10.0
# 16                                 0.0                          4.0
# 25                                 0.0                          0.0
# 28                                 1.0                          2.0
# 29                                 0.0                          0.0
# ...                                ...                          ...
# 1163                               3.0                         10.0
# 1195                               2.0                          8.0
# 1197                               2.0                          0.0
# 1200                               0.0                         10.0
# 1207                               0.0                          0.0
#
#       MRI_Track_Scan_Location  Barratt_Barratt_P1_Edu  Barratt_Barratt_P1_Occ  \
# 10                        1.0                    18.0                    35.0
# 16                        1.0                    21.0                    35.0
# 25                        2.0                    15.0                    15.0
# 28                        1.0                    21.0                    40.0
# 29                        2.0                    21.0                     0.0
# ...                       ...                     ...                     ...
# 1163                      1.0                    18.0                    45.0
# 1195                      1.0                    15.0                    25.0
# 1197                      2.0                    21.0                    40.0
# 1200                      NaN                    15.0                     0.0
# 1207                      2.0                    15.0                    35.0
#
#       Barratt_Barratt_P2_Edu  Barratt_Barratt_P2_Occ
# 10                      12.0                    30.0
# 16                      21.0                    15.0
# 25                      21.0                     0.0
# 28                      12.0                     5.0
# 29                      18.0                    35.0
# ...                      ...                     ...
# 1163                    18.0                     0.0
# 1195                     NaN                     NaN
# 1197                    21.0                    40.0
# 1200                    21.0                    35.0
# 1207                    18.0                    35.0
#
# [170 rows x 10 columns]

# %%
counts = train_cat.groupby(['Basic_Demos_Enroll_Year','MRI_Track_Scan_Location', 'Basic_Demos_Study_Site']).size()
print(counts)
# Out:
# Basic_Demos_Enroll_Year  MRI_Track_Scan_Location  Basic_Demos_Study_Site
# 2015                     1.0                      1                          35
#                                                   2                           1
# 2016                     1.0                      1                         126
#                                                   2                          10
#                                                   3                           7
#                          2.0                      1                          41
#                                                   3                           4
# 2017                     2.0                      1                         159
#                                                   3                          50
#                          3.0                      1                          17
#                                                   3                          27
#                          4.0                      3                           1
# 2018                     2.0                      1                         128
#                                                   3                          43
#                          3.0                      1                          41
#                                                   3                         202
#                                                   4                           1
# 2019                     2.0                      1                          80
#                                                   3                          24
#                                                   4                           3
#                          3.0                      1                          21
#                                                   3                          72
#                                                   4                          80
#                          4.0                      1                           1
#                                                   4                          31
# 2020                     3.0                      4                           2
#                          4.0                      4                           3
# dtype: int64

# %% [markdown]
# I would fill it with 1

# %%
train_cat.fillna({'MRI_Track_Scan_Location': 1}, inplace=True)
# Out:
#      participant_id  Basic_Demos_Enroll_Year  Basic_Demos_Study_Site  \
# 0      00aIpNTbG5uh                     2019                       4
# 1      00fV0OyyoLfw                     2017                       1
# 2      04X1eiS79T4B                     2017                       1
# 3      05ocQutkURd6                     2018                       1
# 4      06YUNBA9ZRLq                     2018                       1
# ...             ...                      ...                     ...
# 1208   zwjJWCRzKhDz                     2019                       4
# 1209   zwXD5v17Rx01                     2018                       1
# 1210   zWzLCi3NTBTd                     2018                       3
# 1211   Zy9GTHDxUbXU                     2019                       4
# 1212   Zye7yYRQohXi                     2017                       1
#
#       PreInt_Demos_Fam_Child_Ethnicity  PreInt_Demos_Fam_Child_Race  \
# 0                                  1.0                          0.0
# 1                                  0.0                          9.0
# 2                                  1.0                          2.0
# 3                                  3.0                          8.0
# 4                                  0.0                          1.0
# ...                                ...                          ...
# 1208                               1.0                          1.0
# 1209                               0.0                          0.0
# 1210                               2.0                          3.0
# 1211                               0.0                          1.0
# 1212                               0.0                          0.0
#
#       MRI_Track_Scan_Location  Barratt_Barratt_P1_Edu  Barratt_Barratt_P1_Occ  \
# 0                         3.0                    21.0                    45.0
# 1                         2.0                    21.0                     0.0
# 2                         2.0                     9.0                     0.0
# 3                         2.0                    18.0                    10.0
# 4                         2.0                    12.0                     0.0
# ...                       ...                     ...                     ...
# 1208                      3.0                    12.0                     NaN
# 1209                      3.0                    21.0                    40.0
# 1210                      3.0                    21.0                    40.0
# 1211                      3.0                    18.0                    35.0
# 1212                      2.0                    18.0                    35.0
#
#       Barratt_Barratt_P2_Edu  Barratt_Barratt_P2_Occ
# 0                        NaN                     NaN
# 1                       21.0                    45.0
# 2                        NaN                     NaN
# 3                       18.0                     0.0
# 4                        NaN                     NaN
# ...                      ...                     ...
# 1208                    15.0                     5.0
# 1209                    21.0                    40.0
# 1210                    21.0                    35.0
# 1211                    18.0                    45.0
# 1212                    15.0                    35.0
#
# [1213 rows x 10 columns]

# %% [markdown]
# Cheking Year, Scan Location and Study Site

# %%
columns='Basic_Demos_Enroll_Year','Basic_Demos_Study_Site', 'MRI_Track_Scan_Location'

# %%
for col in columns:
    print(f"Column: {col}")
    print(train_cat.groupby([col]).size())
# Out:
# Column: Basic_Demos_Enroll_Year
# Basic_Demos_Enroll_Year
# 2015     36
# 2016    191
# 2017    254
# 2018    415
# 2019    312
# 2020      5
# dtype: int64
# Column: Basic_Demos_Study_Site
# Basic_Demos_Study_Site
# 1    652
# 2     11
# 3    430
# 4    120
# dtype: int64
# Column: MRI_Track_Scan_Location
# MRI_Track_Scan_Location
# 1.0    182
# 2.0    532
# 3.0    463
# 4.0     36
# dtype: int64

# %% [markdown]
# ### ❌ **since there were previously significant errors in the test set and in the training set - check the test set!**

# %%
file_path_test_cat = r"C:\Users\Admin\Downloads\model_adhd\widsdatathon2025\TEST\TEST_CATEGORICAL.xlsx"
test_cat = pd.read_excel(file_path_test_cat)

# %%
for col in columns:
    print(f"Column: {col}")
    print(test_cat.groupby([col]).size())
# Out:
# Column: Basic_Demos_Enroll_Year
# Basic_Demos_Enroll_Year
# 2019      1
# 2020      2
# 2021      1
# 2022    232
# 2023     68
# dtype: int64
# Column: Basic_Demos_Study_Site
# Basic_Demos_Study_Site
# 4    301
# 5      3
# dtype: int64
# Column: MRI_Track_Scan_Location
# MRI_Track_Scan_Location
# 3    110
# 4    194
# dtype: int64

# %% [markdown]
# TRAIN SET and TEST SET:
#
# Treating these cases as outliers might improve model performance.
#
# *Basic_Demos_Enroll_Year*
#
# 2015     35
#
# 2020      5
#
# *Basic_Demos_Study_Site*
#
# 2     11
#
#
# *MRI_Track_Scan_Location*
#
# 4.0     36
#
#
# ### ⚠️ **Potential Issues with Enrollment Year, Study Site, and Scan Location**
#
# We observed significant differences between the training and test sets in three key columns:
# **`Basic_Demos_Enroll_Year`**, **`Basic_Demos_Study_Site`**, and **`MRI_Track_Scan_Location`**.
# These variables reflect when and where the check-ups were conducted, and their distribution varies notably between datasets.
#
# **Key Differences**
# - **Enrollment Year:**
#   - Training data mainly consists of earlier years (**2015–2020**).
#   - Test set is dominated by **2022–2023** cases.
#
# - **Study Site:**
#   - Test set includes mostly site **4**, which is underrepresented in the training data.
#   - Site **5** appears only in the test set, while sites **1–3** are missing.
#
# - **MRI Scan Location:**
#   - The test set has different scan locations, with some locations missing from the training set.
#   - This suggests possible differences in scanning conditions or equipment.
#
# **Why This Matters**
# While we confirmed that these variables are **not directly correlated with ADHD**, they may still **influence MRI brain scans**.
# Differences in equipment, scanning techniques, or environmental factors across sites and years could impact brain imaging data.
#
# **Next Steps**
# It may be valuable to check whether these factors correlate with specific **brain structures, imaging artifacts, or analysis results**.
# This could help determine if adjustments are needed to account for site or time-based variability in the MRI data.

# %% [markdown]
# Moreover, MRI scan locations and years can impact results due to variations in machine parameters.
#
# The test set consists mostly of data from 2022, while the training set only includes data up to 2019.
#
# This split is not ideal, as a better approach would be to merge, clean, and resplit the data to ensure the model learns from all available information.
#
# However, since this is an educational task focused on pasting correct answers to the test set, I will remove years and locations with very few samples after checking if they include our target participants.

# %%
cat_site_year = pd.merge(train_cat, train_sol, on='participant_id', how='inner')

# %%
for col in columns:
    print(f"Column: {col}")
    print(cat_site_year.groupby([col, 'ADHD_Outcome', 'Sex_F']).size())
# Out:
# Column: Basic_Demos_Enroll_Year
# Basic_Demos_Enroll_Year  ADHD_Outcome  Sex_F
# 2015                     0             0          7
#                                        1          6
#                          1             0         15
#                                        1          8
# 2016                     0             0         52
#                                        1         43
#                          1             0         67
#                                        1         29
# 2017                     0             0         49
#                                        1         41
#                          1             0        113
#                                        1         51
# 2018                     0             0         54
#                                        1         49
#                          1             0        219
#                                        1         93
# 2019                     0             0         54
#                                        1         27
#                          1             0        163
#                                        1         68
# 2020                     1             0          4
#                                        1          1
# dtype: int64
# Column: Basic_Demos_Study_Site
# Basic_Demos_Study_Site  ADHD_Outcome  Sex_F
# 1                       0             0        125
#                                       1        106
#                         1             0        289
#                                       1        132
# 2                       0             0          1
#                                       1          1
#                         1             0          6
#                                       1          3
# 3                       0             0         69
#                                       1         47
#                         1             0        228
#                                       1         86
# 4                       0             0         21
#                                       1         12
#                         1             0         58
#                                       1         29
# dtype: int64
# Column: MRI_Track_Scan_Location
# MRI_Track_Scan_Location  ADHD_Outcome  Sex_F
# 1.0                      0             0         43
#                                        1         43
#                          1             0         66
#                                        1         30
# 2.0                      0             0        103
#                                        1         70
#                          1             0        247
#                                        1        112
# 3.0                      0             0         60
#                                        1         52
#                          1             0        248
#                                        1        103
# 4.0                      0             0         10
#                                        1          1
#                          1             0         20
#                                        1          5
# dtype: int64

# %%
filtered_participants_year = train_cat[train_cat['Basic_Demos_Enroll_Year'].isin([2015, 2020])]['participant_id'].tolist()

filtered_participants_year = set(filtered_participants_year)

train_cat = train_cat[~train_cat['participant_id'].isin(filtered_participants_year)]
train_fcm = train_fcm[~train_fcm['participant_id'].isin(filtered_participants_year)]
train_quan = train_quan[~train_quan['participant_id'].isin(filtered_participants_year)]
train_sol = train_sol[~train_sol['participant_id'].isin(filtered_participants_year)]

# %%
filtered_participants_ss = train_cat[train_cat['Basic_Demos_Study_Site'].isin([2])]['participant_id'].tolist()

filtered_participants_ss = set(filtered_participants_ss)

train_cat = train_cat[~train_cat['participant_id'].isin(filtered_participants_ss)]
train_fcm = train_fcm[~train_fcm['participant_id'].isin(filtered_participants_ss)]
train_quan = train_quan[~train_quan['participant_id'].isin(filtered_participants_ss)]
train_sol = train_sol[~train_sol['participant_id'].isin(filtered_participants_ss)]

# %%
filtered_participants_sl = train_cat[train_cat['MRI_Track_Scan_Location'].isin([4.0])]['participant_id'].tolist()

filtered_participants_sl = set(filtered_participants_sl)

train_cat = train_cat[~train_cat['participant_id'].isin(filtered_participants_sl)]
train_fcm = train_fcm[~train_fcm['participant_id'].isin(filtered_participants_sl)]
train_quan = train_quan[~train_quan['participant_id'].isin(filtered_participants_sl)]
train_sol = train_sol[~train_sol['participant_id'].isin(filtered_participants_sl)]

# %%
for col in columns:
    print(f"Column: {col}")
    print(train_cat.groupby([col]).size())
# Out:
# Column: Basic_Demos_Enroll_Year
# Basic_Demos_Enroll_Year
# 2016    181
# 2017    253
# 2018    415
# 2019    280
# dtype: int64
# Column: Basic_Demos_Study_Site
# Basic_Demos_Study_Site
# 1    616
# 3    429
# 4     84
# dtype: int64
# Column: MRI_Track_Scan_Location
# MRI_Track_Scan_Location
# 1.0    136
# 2.0    532
# 3.0    461
# dtype: int64

# %%
train_cat.drop('Basic_Demos_Enroll_Year',  axis = 1, inplace=True)
train_cat.drop('Basic_Demos_Study_Site',  axis = 1, inplace=True)
train_cat.drop('MRI_Track_Scan_Location',  axis = 1, inplace=True)

# %%
print("\nTRAIN_CATEGORICAL_METADATA.xlsx")
print(train_cat.isnull().sum())
# Out:
# TRAIN_CATEGORICAL_METADATA.xlsx
# participant_id                        0
# PreInt_Demos_Fam_Child_Ethnicity      0
# PreInt_Demos_Fam_Child_Race           0
# Barratt_Barratt_P1_Edu               14
# Barratt_Barratt_P1_Occ               27
# Barratt_Barratt_P2_Edu              184
# Barratt_Barratt_P2_Occ              205
# dtype: int64

# %%
train_cat.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1129 entries, 0 to 1212
# Data columns (total 7 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   participant_id                    1129 non-null   str
#  1   PreInt_Demos_Fam_Child_Ethnicity  1129 non-null   float64
#  2   PreInt_Demos_Fam_Child_Race       1129 non-null   float64
#  3   Barratt_Barratt_P1_Edu            1115 non-null   float64
#  4   Barratt_Barratt_P1_Occ            1102 non-null   float64
#  5   Barratt_Barratt_P2_Edu            945 non-null    float64
#  6   Barratt_Barratt_P2_Occ            924 non-null    float64
# dtypes: float64(6), str(1)
# memory usage: 70.6 KB

# %% [markdown]
# ⚠️  a lot NULL values in TRAIN_CATEGORICAL_METADATA - A lot of missing values - Parrents education and occupation - 18,5 %

# %%
print("\nTRAIN_FUNCTIONAL_CONNECTOME_MATRICES.csv")
print(f"Missing values: {train_fcm.isnull().values.any()}")
# Out:
# TRAIN_FUNCTIONAL_CONNECTOME_MATRICES.csv
# Missing values: False

# %% [markdown]
# ✅ No NULL values in TRAIN_FUNCTIONAL_CONNECTOME_MATRICES

# %%
print("\nTRAIN_QUANTITATIVE_METADATA.xlsx")
print(train_quan.isnull().sum())
# Out:
# TRAIN_QUANTITATIVE_METADATA.xlsx
# participant_id                  0
# EHQ_EHQ_Total                  12
# ColorVision_CV_Score           10
# APQ_P_APQ_P_CP                 11
# APQ_P_APQ_P_ID                 11
# APQ_P_APQ_P_INV                11
# APQ_P_APQ_P_OPD                11
# APQ_P_APQ_P_PM                 11
# APQ_P_APQ_P_PP                 11
# SDQ_SDQ_Conduct_Problems        4
# SDQ_SDQ_Difficulties_Total      4
# SDQ_SDQ_Emotional_Problems      4
# SDQ_SDQ_Externalizing           4
# SDQ_SDQ_Generating_Impact       4
# SDQ_SDQ_Hyperactivity           4
# SDQ_SDQ_Internalizing           4
# SDQ_SDQ_Peer_Problems           4
# SDQ_SDQ_Prosocial               4
# MRI_Track_Age_at_Scan         336
# dtype: int64

# %%
train_quan.columns
# Out:
# Index(['participant_id', 'EHQ_EHQ_Total', 'ColorVision_CV_Score',
#        'APQ_P_APQ_P_CP', 'APQ_P_APQ_P_ID', 'APQ_P_APQ_P_INV',
#        'APQ_P_APQ_P_OPD', 'APQ_P_APQ_P_PM', 'APQ_P_APQ_P_PP',
#        'SDQ_SDQ_Conduct_Problems', 'SDQ_SDQ_Difficulties_Total',
#        'SDQ_SDQ_Emotional_Problems', 'SDQ_SDQ_Externalizing',
#        'SDQ_SDQ_Generating_Impact', 'SDQ_SDQ_Hyperactivity',
#        'SDQ_SDQ_Internalizing', 'SDQ_SDQ_Peer_Problems', 'SDQ_SDQ_Prosocial',
#        'MRI_Track_Age_at_Scan'],
#       dtype='str')

# %%
columns = ['EHQ_EHQ_Total', 'ColorVision_CV_Score',
       'APQ_P_APQ_P_CP', 'APQ_P_APQ_P_ID', 'APQ_P_APQ_P_INV',
       'APQ_P_APQ_P_OPD', 'APQ_P_APQ_P_PM', 'APQ_P_APQ_P_PP',
       'SDQ_SDQ_Conduct_Problems', 'SDQ_SDQ_Difficulties_Total',
       'SDQ_SDQ_Emotional_Problems', 'SDQ_SDQ_Externalizing',
       'SDQ_SDQ_Generating_Impact', 'SDQ_SDQ_Hyperactivity',
       'SDQ_SDQ_Internalizing', 'SDQ_SDQ_Peer_Problems', 'SDQ_SDQ_Prosocial']

# %%
missing_values_rows = train_quan[columns].isna()

# Create a boolean mask indicating rows with at least one missing value
rows_with_missing = missing_values_rows.any(axis=1)

# Filter the DataFrame to show only rows with missing values
df_with_missing = train_quan[rows_with_missing]

df_with_missing.head(50)
# Out:
#      participant_id  EHQ_EHQ_Total  ColorVision_CV_Score  APQ_P_APQ_P_CP  \
# 19     16aihxrHTH3I         100.00                  14.0             4.0
# 80     3yjwwRWX7KUY            NaN                  14.0             3.0
# 84     43DBbRe4MRuo            NaN                  14.0             3.0
# 120    64kiQGd5o5kP          71.14                  14.0             NaN
# 183    A1AXFSUEtLFQ          60.00                  13.0             3.0
# 212    ATObhMwuXLIh            NaN                  10.0             3.0
# 250    BQP0hsFBBc6N          73.34                   NaN             3.0
# 286    CKkgPNyqu2OK            NaN                  13.0             5.0
# 300    CtJzGTu0T8sv         -76.67                   NaN             3.0
# 306    cYRQEhrfDAtH          43.35                   NaN             3.0
# 325    DImiLHwbsVjF            NaN                  14.0             4.0
# 350    eC2397lXg3Bm         100.00                  14.0             NaN
# 362    emH1j2pf9MZk          77.80                  14.0             NaN
# 368    epGIlkmYMthb         -16.68                  13.0             NaN
# 371    EQtPla3Usndh          66.67                   NaN             3.0
# 421    FudKx3F8glFq           8.94                  14.0             NaN
# 472    H3ToH743CSaM            NaN                  14.0             3.0
# 479    HAHYSPs753Cc          13.34                  14.0             NaN
# 515    I6ZzdRHILPBV          71.14                   NaN             3.0
# 703    MMH1uM7wltAr         -46.67                  14.0             3.0
# 735    NHpNjWCsdA90          60.00                  14.0             NaN
# 857    qk2RutjZfkP8            NaN                  14.0             3.0
# 870    QZMiqNgesq93            NaN                  14.0             3.0
# 874    R6QlZMfb71bW          73.34                   NaN             3.0
# 926    sP406TpFhhu9          60.00                   NaN             3.0
# 978    U3FzDZTOsMlD          81.14                  14.0             5.0
# 1022   v5YNYUpoXpmZ            NaN                  14.0             4.0
# 1026   vBf24YQteuvD            NaN                  14.0             3.0
# 1034   vm2P1hmAY1hl          71.14                   NaN             4.0
# 1060   waeaKz9kEkAX            NaN                  14.0             3.0
# 1076   WK20sSlccEMn          33.35                  14.0             NaN
# 1084   wRGO69GjV1v6            NaN                   NaN             NaN
# 1137   yBXIW5DPpBat          22.27                   NaN             3.0
# 1140   yDPAXPOdl29m         -20.00                  14.0             NaN
# 1165   Z1SInb6bBHsu          33.35                  13.0             NaN
#
#       APQ_P_APQ_P_ID  APQ_P_APQ_P_INV  APQ_P_APQ_P_OPD  APQ_P_APQ_P_PM  \
# 19              18.0             38.0             21.0            25.0
# 80              10.0             41.0             23.0            12.0
# 84              15.0             34.0             18.0            22.0
# 120              NaN              NaN              NaN             NaN
# 183             10.0             40.0             17.0            16.0
# 212             15.0             42.0             20.0            10.0
# 250             17.0             38.0             20.0            11.0
# 286             12.0             41.0             20.0            33.0
# 300             14.0             34.0             17.0            24.0
# 306             13.0             46.0             17.0            14.0
# 325             10.0             45.0             17.0            19.0
# 350              NaN              NaN              NaN             NaN
# 362              NaN              NaN              NaN             NaN
# 368              NaN              NaN              NaN             NaN
# 371             10.0             45.0             16.0            16.0
# 421              NaN              NaN              NaN             NaN
# 472             11.0             48.0             16.0            10.0
# 479              NaN              NaN              NaN             NaN
# 515              9.0             46.0             21.0            26.0
# 703             13.0             40.0             17.0            15.0
# 735              NaN              NaN              NaN             NaN
# 857             14.0             44.0             21.0            10.0
# 870             17.0             40.0             23.0            35.0
# 874             11.0             38.0             17.0            12.0
# 926             14.0             43.0             12.0            17.0
# 978             15.0             31.0             20.0            21.0
# 1022            18.0             44.0             22.0            11.0
# 1026             6.0             48.0             11.0            19.0
# 1034            14.0             35.0             19.0            18.0
# 1060            11.0             35.0             14.0            10.0
# 1076             NaN              NaN              NaN             NaN
# 1084             NaN              NaN              NaN             NaN
# 1137            13.0             45.0             17.0            14.0
# 1140             NaN              NaN              NaN             NaN
# 1165             NaN              NaN              NaN             NaN
#
#       APQ_P_APQ_P_PP  SDQ_SDQ_Conduct_Problems  SDQ_SDQ_Difficulties_Total  \
# 19              24.0                       NaN                         NaN
# 80              30.0                       0.0                        12.0
# 84              23.0                       2.0                        21.0
# 120              NaN                       2.0                         7.0
# 183             23.0                       NaN                         NaN
# 212             29.0                       4.0                        16.0
# 250             27.0                       2.0                        11.0
# 286             28.0                       6.0                        25.0
# 300             28.0                       0.0                         7.0
# 306             28.0                       1.0                         5.0
# 325             26.0                       4.0                        23.0
# 350              NaN                       0.0                        11.0
# 362              NaN                       4.0                        16.0
# 368              NaN                       0.0                         8.0
# 371             21.0                       1.0                        15.0
# 421              NaN                       3.0                         6.0
# 472             30.0                       5.0                        20.0
# 479              NaN                       3.0                         6.0
# 515             27.0                       0.0                        10.0
# 703             26.0                       NaN                         NaN
# 735              NaN                       3.0                         6.0
# 857             28.0                       6.0                        29.0
# 870             23.0                       1.0                        11.0
# 874             24.0                       1.0                        12.0
# 926             29.0                       0.0                         9.0
# 978             21.0                       NaN                         NaN
# 1022            27.0                       2.0                        21.0
# 1026            27.0                       0.0                         3.0
# 1034            26.0                       0.0                         2.0
# 1060            28.0                       1.0                        16.0
# 1076             NaN                       0.0                         2.0
# 1084             NaN                       1.0                        12.0
# 1137            27.0                       2.0                        15.0
# 1140             NaN                       2.0                        13.0
# 1165             NaN                       5.0                        16.0
#
#       SDQ_SDQ_Emotional_Problems  SDQ_SDQ_Externalizing  \
# 19                           NaN                    NaN
# 80                           3.0                    4.0
# 84                           9.0                    8.0
# 120                          0.0                    5.0
# 183                          NaN                    NaN
# 212                          1.0                   11.0
# 250                          3.0                    8.0
# 286                          5.0                   15.0
# 300                          2.0                    2.0
# 306                          1.0                    4.0
# 325                          6.0                   14.0
# 350                          8.0                    0.0
# 362                          3.0                    9.0
# 368                          0.0                    3.0
# 371                          1.0                   10.0
# 421                          0.0                    4.0
# 472                          4.0                   10.0
# 479                          0.0                    5.0
# 515                          3.0                    6.0
# 703                          NaN                    NaN
# 735                          0.0                    6.0
# 857                          4.0                   16.0
# 870                          3.0                    8.0
# 874                          1.0                    7.0
# 926                          1.0                    7.0
# 978                          NaN                    NaN
# 1022                         7.0                   11.0
# 1026                         1.0                    1.0
# 1034                         0.0                    0.0
# 1060                         1.0                   10.0
# 1076                         0.0                    2.0
# 1084                         1.0                    9.0
# 1137                         5.0                    6.0
# 1140                         4.0                    7.0
# 1165                         0.0                   10.0
#
#       SDQ_SDQ_Generating_Impact  SDQ_SDQ_Hyperactivity  SDQ_SDQ_Internalizing  \
# 19                          NaN                    NaN                    NaN
# 80                          3.0                    4.0                    8.0
# 84                         10.0                    6.0                   13.0
# 120                         0.0                    3.0                    2.0
# 183                         NaN                    NaN                    NaN
# 212                        10.0                    7.0                    5.0
# 250                         5.0                    6.0                    3.0
# 286                         6.0                    9.0                   10.0
# 300                         0.0                    2.0                    5.0
# 306                         4.0                    3.0                    1.0
# 325                         7.0                   10.0                    9.0
# 350                         0.0                    0.0                   11.0
# 362                         3.0                    5.0                    7.0
# 368                         4.0                    3.0                    5.0
# 371                         1.0                    9.0                    5.0
# 421                         3.0                    1.0                    2.0
# 472                         8.0                    5.0                   10.0
# 479                         0.0                    2.0                    1.0
# 515                         5.0                    6.0                    4.0
# 703                         NaN                    NaN                    NaN
# 735                         3.0                    3.0                    0.0
# 857                        10.0                   10.0                   13.0
# 870                         6.0                    7.0                    3.0
# 874                         5.0                    6.0                    5.0
# 926                         4.0                    7.0                    2.0
# 978                         NaN                    NaN                    NaN
# 1022                        8.0                    9.0                   10.0
# 1026                        0.0                    1.0                    2.0
# 1034                        0.0                    0.0                    2.0
# 1060                        3.0                    9.0                    6.0
# 1076                        2.0                    2.0                    0.0
# 1084                        2.0                    8.0                    3.0
# 1137                        2.0                    4.0                    9.0
# 1140                        0.0                    5.0                    6.0
# 1165                        6.0                    5.0                    6.0
#
#       SDQ_SDQ_Peer_Problems  SDQ_SDQ_Prosocial  MRI_Track_Age_at_Scan
# 19                      NaN                NaN               9.537873
# 80                      5.0                8.0               9.444216
# 84                      4.0                8.0              11.869952
# 120                     2.0                9.0               6.172826
# 183                     NaN                NaN              17.173169
# 212                     4.0               10.0                    NaN
# 250                     0.0                6.0               8.256217
# 286                     5.0                9.0              13.860255
# 300                     3.0                9.0              14.175678
# 306                     0.0                6.0                    NaN
# 325                     3.0                9.0                    NaN
# 350                     3.0               10.0                    NaN
# 362                     4.0                9.0                    NaN
# 368                     5.0                5.0               6.235911
# 371                     4.0                7.0              10.679101
# 421                     2.0                7.0                    NaN
# 472                     6.0                6.0              10.402806
# 479                     1.0                9.0                    NaN
# 515                     1.0               10.0              19.839493
# 703                     NaN                NaN               9.400752
# 735                     0.0               10.0               5.360255
# 857                     9.0                3.0               8.220282
# 870                     0.0               10.0              16.132785
# 874                     4.0                8.0              11.335957
# 926                     1.0               10.0              10.136778
# 978                     NaN                NaN               8.261464
# 1022                    3.0                5.0              10.281770
# 1026                    1.0               10.0              15.199178
# 1034                    2.0                8.0              15.869952
# 1060                    5.0                3.0              11.615331
# 1076                    0.0               10.0              12.001368
# 1084                    2.0                9.0               6.555783
# 1137                    4.0                9.0                    NaN
# 1140                    2.0                9.0               5.841775
# 1165                    6.0                5.0               5.682181

# %%
df_with_missing.describe()
# Out:
#        EHQ_EHQ_Total  ColorVision_CV_Score  APQ_P_APQ_P_CP  APQ_P_APQ_P_ID  \
# count      23.000000             25.000000       24.000000       24.000000
# mean       41.751739             13.680000        3.333333       12.916667
# std        46.377875              0.852447        0.637022        3.034822
# min       -76.670000             10.000000        3.000000        6.000000
# 25%        17.805000             14.000000        3.000000       10.750000
# 50%        60.000000             14.000000        3.000000       13.000000
# 75%        72.240000             14.000000        3.250000       15.000000
# max       100.000000             14.000000        5.000000       18.000000
#
#        APQ_P_APQ_P_INV  APQ_P_APQ_P_OPD  APQ_P_APQ_P_PM  APQ_P_APQ_P_PP  \
# count         24.00000        24.000000       24.000000       24.000000
# mean          40.87500        18.166667       17.500000       26.250000
# std            4.74857         3.130032        7.101745        2.625129
# min           31.00000        11.000000       10.000000       21.000000
# 25%           38.00000        17.000000       11.750000       24.000000
# 50%           41.00000        17.500000       16.000000       27.000000
# 75%           45.00000        20.250000       21.250000       28.000000
# max           48.00000        23.000000       35.000000       30.000000
#
#        SDQ_SDQ_Conduct_Problems  SDQ_SDQ_Difficulties_Total  \
# count                 31.000000                   31.000000
# mean                   1.967742                   12.451613
# std                    1.888277                    6.835392
# min                    0.000000                    2.000000
# 25%                    0.000000                    7.000000
# 50%                    2.000000                   12.000000
# 75%                    3.000000                   16.000000
# max                    6.000000                   29.000000
#
#        SDQ_SDQ_Emotional_Problems  SDQ_SDQ_Externalizing  \
# count                   31.000000              31.000000
# mean                     2.483871               7.032258
# std                      2.541272               4.127016
# min                      0.000000               0.000000
# 25%                      0.500000               4.000000
# 50%                      1.000000               7.000000
# 75%                      4.000000              10.000000
# max                      9.000000              16.000000
#
#        SDQ_SDQ_Generating_Impact  SDQ_SDQ_Hyperactivity  \
# count                  31.000000              31.000000
# mean                    3.870968               5.064516
# std                     3.170089               2.976973
# min                     0.000000               0.000000
# 25%                     1.500000               3.000000
# 50%                     3.000000               5.000000
# 75%                     6.000000               7.000000
# max                    10.000000              10.000000
#
#        SDQ_SDQ_Internalizing  SDQ_SDQ_Peer_Problems  SDQ_SDQ_Prosocial  \
# count              31.000000              31.000000          31.000000
# mean                5.419355               2.935484           7.935484
# std                 3.748548               2.174634           2.096592
# min                 0.000000               0.000000           3.000000
# 25%                 2.000000               1.000000           6.500000
# 50%                 5.000000               3.000000           9.000000
# 75%                 8.500000               4.000000           9.500000
# max                13.000000               9.000000          10.000000
#
#        MRI_Track_Age_at_Scan
# count              27.000000
# mean               10.723819
# std                 3.855221
# min                 5.360255
# 25%                 8.238249
# 50%                10.281770
# 75%                12.930812
# max                19.839493

# %%
train_quan.describe()
# Out:
#        EHQ_EHQ_Total  ColorVision_CV_Score  APQ_P_APQ_P_CP  APQ_P_APQ_P_ID  \
# count    1117.000000           1119.000000     1118.000000     1118.000000
# mean       59.649141             13.395889        3.834526       13.358676
# std        49.805728              2.173104        1.350880        3.577155
# min      -100.000000              0.000000        2.000000        5.000000
# 25%        46.670000             14.000000        3.000000       11.000000
# 50%        80.000000             14.000000        3.000000       13.000000
# 75%        94.470000             14.000000        4.000000       16.000000
# max       100.000000             14.000000       12.000000       28.000000
#
#        APQ_P_APQ_P_INV  APQ_P_APQ_P_OPD  APQ_P_APQ_P_PM  APQ_P_APQ_P_PP  \
# count      1118.000000      1118.000000     1118.000000     1118.000000
# mean         39.712880        17.931127       16.662791       25.454383
# std           4.821508         3.322382        5.183981        3.080126
# min          23.000000         7.000000        5.000000       13.000000
# 25%          36.000000        16.000000       13.000000       23.000000
# 50%          40.000000        18.000000       16.000000       26.000000
# 75%          43.000000        20.000000       20.000000       28.000000
# max          50.000000        28.000000       37.000000       30.000000
#
#        SDQ_SDQ_Conduct_Problems  SDQ_SDQ_Difficulties_Total  \
# count               1125.000000                 1125.000000
# mean                   2.046222                   12.095111
# std                    2.018067                    6.502725
# min                    0.000000                    0.000000
# 25%                    0.000000                    7.000000
# 50%                    2.000000                   12.000000
# 75%                    3.000000                   16.000000
# max                   10.000000                   34.000000
#
#        SDQ_SDQ_Emotional_Problems  SDQ_SDQ_Externalizing  \
# count                 1125.000000             1125.00000
# mean                     2.301333                7.52800
# std                      2.149412                4.12444
# min                      0.000000                0.00000
# 25%                      1.000000                4.00000
# 50%                      2.000000                7.00000
# 75%                      4.000000               10.00000
# max                     10.000000               20.00000
#
#        SDQ_SDQ_Generating_Impact  SDQ_SDQ_Hyperactivity  \
# count                1125.000000            1125.000000
# mean                    4.090667               5.481778
# std                     2.817515               2.802972
# min                     0.000000               0.000000
# 25%                     2.000000               3.000000
# 50%                     4.000000               5.000000
# 75%                     6.000000               8.000000
# max                    10.000000              10.000000
#
#        SDQ_SDQ_Internalizing  SDQ_SDQ_Peer_Problems  SDQ_SDQ_Prosocial  \
# count            1125.000000            1125.000000        1125.000000
# mean                4.567111               2.265778           7.728000
# std                 3.513343               2.086973           2.096593
# min                 0.000000               0.000000           0.000000
# 25%                 2.000000               0.000000           6.000000
# 50%                 4.000000               2.000000           8.000000
# 75%                 7.000000               4.000000          10.000000
# max                17.000000               9.000000          10.000000
#
#        MRI_Track_Age_at_Scan
# count             793.000000
# mean               11.248889
# std                 3.249396
# min                 0.000000
# 25%                 8.817362
# 50%                10.731234
# 75%                13.463381
# max                21.564453

# %%
counts = train_quan.groupby(['ColorVision_CV_Score']).size()
print(counts)
# Out:
# ColorVision_CV_Score
# 0.0       6
# 1.0      10
# 2.0       8
# 3.0       4
# 4.0       2
# 5.0       4
# 6.0       2
# 8.0       3
# 9.0       2
# 10.0      5
# 11.0      8
# 12.0     23
# 13.0    132
# 14.0    910
# dtype: int64

# %% [markdown]
# Mean for ColorVision_CV_Score is 13.4.
#
# Mode is 14
#
# Decission filling with 14

# %%
train_quan.fillna({'ColorVision_CV_Score': 14}, inplace=True)
# Out:
#      participant_id  EHQ_EHQ_Total  ColorVision_CV_Score  APQ_P_APQ_P_CP  \
# 0      00aIpNTbG5uh         100.00                  13.0             3.0
# 1      00fV0OyyoLfw          92.27                  14.0             3.0
# 2      04X1eiS79T4B          86.67                  14.0             3.0
# 3      05ocQutkURd6          93.34                  14.0             3.0
# 4      06YUNBA9ZRLq           0.00                  14.0             8.0
# ...             ...            ...                   ...             ...
# 1208   zwjJWCRzKhDz         100.00                  14.0             3.0
# 1209   zwXD5v17Rx01          46.67                  14.0             3.0
# 1210   zWzLCi3NTBTd         -40.00                  14.0             3.0
# 1211   Zy9GTHDxUbXU         100.00                  14.0             3.0
# 1212   Zye7yYRQohXi          87.80                  14.0             3.0
#
#       APQ_P_APQ_P_ID  APQ_P_APQ_P_INV  APQ_P_APQ_P_OPD  APQ_P_APQ_P_PM  \
# 0               15.0             44.0             14.0            20.0
# 1               12.0             35.0             25.0            28.0
# 2               21.0             37.0             18.0            26.0
# 3               11.0             42.0             15.0            20.0
# 4               12.0             35.0             22.0            12.0
# ...              ...              ...              ...             ...
# 1208            14.0             36.0             18.0            13.0
# 1209            18.0             42.0             21.0            15.0
# 1210            19.0             34.0             20.0            20.0
# 1211             9.0             45.0             23.0            11.0
# 1212             8.0             45.0             16.0            13.0
#
#       APQ_P_APQ_P_PP  SDQ_SDQ_Conduct_Problems  SDQ_SDQ_Difficulties_Total  \
# 0               27.0                       3.0                        17.0
# 1               30.0                       5.0                        20.0
# 2               28.0                       3.0                        24.0
# 3               28.0                       0.0                         5.0
# 4               24.0                       6.0                        23.0
# ...              ...                       ...                         ...
# 1208            22.0                       5.0                        20.0
# 1209            25.0                       2.0                         5.0
# 1210            25.0                       2.0                        14.0
# 1211            30.0                       1.0                        10.0
# 1212            24.0                       2.0                        11.0
#
#       SDQ_SDQ_Emotional_Problems  SDQ_SDQ_Externalizing  \
# 0                            4.0                   11.0
# 1                            4.0                   13.0
# 2                            7.0                   10.0
# 3                            0.0                    3.0
# 4                            7.0                   15.0
# ...                          ...                    ...
# 1208                         5.0                   13.0
# 1209                         0.0                    5.0
# 1210                         3.0                    9.0
# 1211                         0.0                    8.0
# 1212                         2.0                    9.0
#
#       SDQ_SDQ_Generating_Impact  SDQ_SDQ_Hyperactivity  SDQ_SDQ_Internalizing  \
# 0                           5.0                    8.0                    6.0
# 1                           5.0                    8.0                    7.0
# 2                          10.0                    7.0                   14.0
# 3                           0.0                    3.0                    2.0
# 4                           8.0                    9.0                    8.0
# ...                         ...                    ...                    ...
# 1208                        5.0                    8.0                    7.0
# 1209                        0.0                    3.0                    0.0
# 1210                        3.0                    7.0                    5.0
# 1211                        5.0                    7.0                    2.0
# 1212                        4.0                    7.0                    2.0
#
#       SDQ_SDQ_Peer_Problems  SDQ_SDQ_Prosocial  MRI_Track_Age_at_Scan
# 0                       2.0                9.0              14.274127
# 1                       3.0                8.0                    NaN
# 2                       7.0                7.0              13.463381
# 3                       2.0                6.0               9.572553
# 4                       1.0                4.0               6.654574
# ...                     ...                ...                    ...
# 1208                    2.0                8.0              11.272986
# 1209                    0.0                7.0               7.364020
# 1210                    2.0                9.0               9.962126
# 1211                    2.0                7.0                    NaN
# 1212                    0.0                5.0                    NaN
#
# [1129 rows x 19 columns]

# %% [markdown]
# ✅ NULL for color vision is corrected

# %%
print("\nTRAIN_QUANTITATIVE_METADATA.xlsx")
print(train_quan.isnull().sum())
# Out:
# TRAIN_QUANTITATIVE_METADATA.xlsx
# participant_id                  0
# EHQ_EHQ_Total                  12
# ColorVision_CV_Score            0
# APQ_P_APQ_P_CP                 11
# APQ_P_APQ_P_ID                 11
# APQ_P_APQ_P_INV                11
# APQ_P_APQ_P_OPD                11
# APQ_P_APQ_P_PM                 11
# APQ_P_APQ_P_PP                 11
# SDQ_SDQ_Conduct_Problems        4
# SDQ_SDQ_Difficulties_Total      4
# SDQ_SDQ_Emotional_Problems      4
# SDQ_SDQ_Externalizing           4
# SDQ_SDQ_Generating_Impact       4
# SDQ_SDQ_Hyperactivity           4
# SDQ_SDQ_Internalizing           4
# SDQ_SDQ_Peer_Problems           4
# SDQ_SDQ_Prosocial               4
# MRI_Track_Age_at_Scan         336
# dtype: int64

# %%
columns = [
       'APQ_P_APQ_P_CP', 'APQ_P_APQ_P_ID', 'APQ_P_APQ_P_INV',
       'APQ_P_APQ_P_OPD', 'APQ_P_APQ_P_PM', 'APQ_P_APQ_P_PP']

missing_values_rows = train_quan[columns].isna()

# Create a boolean mask indicating rows with at least one missing value
rows_with_missing = missing_values_rows.any(axis=1)

# Filter the DataFrame to show only rows with missing values
df_with_missing = train_quan[rows_with_missing]
df_with_missing = pd.merge(df_with_missing, train_sol, on='participant_id', how='left')

df_with_missing.head(50)
# Out:
#    participant_id  EHQ_EHQ_Total  ColorVision_CV_Score  APQ_P_APQ_P_CP  \
# 0    64kiQGd5o5kP          71.14                  14.0             NaN
# 1    eC2397lXg3Bm         100.00                  14.0             NaN
# 2    emH1j2pf9MZk          77.80                  14.0             NaN
# 3    epGIlkmYMthb         -16.68                  13.0             NaN
# 4    FudKx3F8glFq           8.94                  14.0             NaN
# 5    HAHYSPs753Cc          13.34                  14.0             NaN
# 6    NHpNjWCsdA90          60.00                  14.0             NaN
# 7    WK20sSlccEMn          33.35                  14.0             NaN
# 8    wRGO69GjV1v6            NaN                  14.0             NaN
# 9    yDPAXPOdl29m         -20.00                  14.0             NaN
# 10   Z1SInb6bBHsu          33.35                  13.0             NaN
#
#     APQ_P_APQ_P_ID  APQ_P_APQ_P_INV  APQ_P_APQ_P_OPD  APQ_P_APQ_P_PM  \
# 0              NaN              NaN              NaN             NaN
# 1              NaN              NaN              NaN             NaN
# 2              NaN              NaN              NaN             NaN
# 3              NaN              NaN              NaN             NaN
# 4              NaN              NaN              NaN             NaN
# 5              NaN              NaN              NaN             NaN
# 6              NaN              NaN              NaN             NaN
# 7              NaN              NaN              NaN             NaN
# 8              NaN              NaN              NaN             NaN
# 9              NaN              NaN              NaN             NaN
# 10             NaN              NaN              NaN             NaN
#
#     APQ_P_APQ_P_PP  SDQ_SDQ_Conduct_Problems  ...  SDQ_SDQ_Emotional_Problems  \
# 0              NaN                       2.0  ...                         0.0
# 1              NaN                       0.0  ...                         8.0
# 2              NaN                       4.0  ...                         3.0
# 3              NaN                       0.0  ...                         0.0
# 4              NaN                       3.0  ...                         0.0
# 5              NaN                       3.0  ...                         0.0
# 6              NaN                       3.0  ...                         0.0
# 7              NaN                       0.0  ...                         0.0
# 8              NaN                       1.0  ...                         1.0
# 9              NaN                       2.0  ...                         4.0
# 10             NaN                       5.0  ...                         0.0
#
#     SDQ_SDQ_Externalizing  SDQ_SDQ_Generating_Impact  SDQ_SDQ_Hyperactivity  \
# 0                     5.0                        0.0                    3.0
# 1                     0.0                        0.0                    0.0
# 2                     9.0                        3.0                    5.0
# 3                     3.0                        4.0                    3.0
# 4                     4.0                        3.0                    1.0
# 5                     5.0                        0.0                    2.0
# 6                     6.0                        3.0                    3.0
# 7                     2.0                        2.0                    2.0
# 8                     9.0                        2.0                    8.0
# 9                     7.0                        0.0                    5.0
# 10                   10.0                        6.0                    5.0
#
#     SDQ_SDQ_Internalizing  SDQ_SDQ_Peer_Problems  SDQ_SDQ_Prosocial  \
# 0                     2.0                    2.0                9.0
# 1                    11.0                    3.0               10.0
# 2                     7.0                    4.0                9.0
# 3                     5.0                    5.0                5.0
# 4                     2.0                    2.0                7.0
# 5                     1.0                    1.0                9.0
# 6                     0.0                    0.0               10.0
# 7                     0.0                    0.0               10.0
# 8                     3.0                    2.0                9.0
# 9                     6.0                    2.0                9.0
# 10                    6.0                    6.0                5.0
#
#     MRI_Track_Age_at_Scan  ADHD_Outcome  Sex_F
# 0                6.172826             0      0
# 1                     NaN             0      1
# 2                     NaN             1      0
# 3                6.235911             0      1
# 4                     NaN             0      0
# 5                     NaN             0      0
# 6                5.360255             1      1
# 7               12.001368             1      0
# 8                6.555783             0      1
# 9                5.841775             1      1
# 10               5.682181             1      0
#
# [11 rows x 21 columns]

# %%
columns = [
       'SDQ_SDQ_Conduct_Problems', 'SDQ_SDQ_Difficulties_Total',
       'SDQ_SDQ_Emotional_Problems', 'SDQ_SDQ_Externalizing',
       'SDQ_SDQ_Generating_Impact', 'SDQ_SDQ_Hyperactivity',
       'SDQ_SDQ_Internalizing', 'SDQ_SDQ_Peer_Problems', 'SDQ_SDQ_Prosocial']

missing_values_rows = train_quan[columns].isna()

# Create a boolean mask indicating rows with at least one missing value
rows_with_missing = missing_values_rows.any(axis=1)

# Filter the DataFrame to show only rows with missing values
df_with_missing = train_quan[rows_with_missing]
df_with_missing = pd.merge(df_with_missing, train_sol, on='participant_id', how='left')

df_with_missing.head(50)
# Out:
#   participant_id  EHQ_EHQ_Total  ColorVision_CV_Score  APQ_P_APQ_P_CP  \
# 0   16aihxrHTH3I         100.00                  14.0             4.0
# 1   A1AXFSUEtLFQ          60.00                  13.0             3.0
# 2   MMH1uM7wltAr         -46.67                  14.0             3.0
# 3   U3FzDZTOsMlD          81.14                  14.0             5.0
#
#    APQ_P_APQ_P_ID  APQ_P_APQ_P_INV  APQ_P_APQ_P_OPD  APQ_P_APQ_P_PM  \
# 0            18.0             38.0             21.0            25.0
# 1            10.0             40.0             17.0            16.0
# 2            13.0             40.0             17.0            15.0
# 3            15.0             31.0             20.0            21.0
#
#    APQ_P_APQ_P_PP  SDQ_SDQ_Conduct_Problems  ...  SDQ_SDQ_Emotional_Problems  \
# 0            24.0                       NaN  ...                         NaN
# 1            23.0                       NaN  ...                         NaN
# 2            26.0                       NaN  ...                         NaN
# 3            21.0                       NaN  ...                         NaN
#
#    SDQ_SDQ_Externalizing  SDQ_SDQ_Generating_Impact  SDQ_SDQ_Hyperactivity  \
# 0                    NaN                        NaN                    NaN
# 1                    NaN                        NaN                    NaN
# 2                    NaN                        NaN                    NaN
# 3                    NaN                        NaN                    NaN
#
#    SDQ_SDQ_Internalizing  SDQ_SDQ_Peer_Problems  SDQ_SDQ_Prosocial  \
# 0                    NaN                    NaN                NaN
# 1                    NaN                    NaN                NaN
# 2                    NaN                    NaN                NaN
# 3                    NaN                    NaN                NaN
#
#    MRI_Track_Age_at_Scan  ADHD_Outcome  Sex_F
# 0               9.537873             0      0
# 1              17.173169             1      1
# 2               9.400752             0      0
# 3               8.261464             1      0
#
# [4 rows x 21 columns]

# %% [markdown]
# # 2. Feature Engineering

# %% [markdown]
# ### AGE

# %% [markdown]
# Main focus is on brain activity patterns and their relationship to ADHD and sex differences.
#
# 🔹 ADHD symptoms change with age – Younger children may show hyperactive symptoms, while older ones may display inattentive symptoms.
#
# 🔹 Brain development is age-dependent – Some brain regions develop at different rates, which could be relevant for brain activity patterns.
#
# 🔹 Sex differences in ADHD symptoms may vary by age – Could be worth checking interactions between age, sex, and ADHD.
#
# AGE COLUMN - mising 347 data from 1162 = 30%
#
# Question: Should we delete AGE column?

# %%
print(train_quan['MRI_Track_Age_at_Scan'].round().value_counts())
# Out:
# MRI_Track_Age_at_Scan
# 10.0    111
# 9.0      97
# 8.0      94
# 11.0     90
# 12.0     77
# 7.0      57
# 13.0     53
# 15.0     53
# 14.0     49
# 17.0     31
# 16.0     29
# 18.0     20
# 6.0      16
# 21.0      5
# 20.0      4
# 19.0      3
# 0.0       2
# 22.0      1
# 5.0       1
# Name: count, dtype: int64

# %%
train_quan['MRI_Track_Age_at_Scan'].round().value_counts().sort_index().plot(kind='bar', figsize=(10, 6))
# Out:
# <Axes: xlabel='MRI_Track_Age_at_Scan'>

# %% [markdown]
# **Checking if age correlates with ADHD diagnosis or sex (e.g., using boxplots or correlation analysis)**

# %%
age_train = pd.merge(train_quan, train_sol, on='participant_id', how='inner')

# %%
age_train[['MRI_Track_Age_at_Scan', 'ADHD_Outcome', 'Sex_F']].corr(method='spearman')
# Out:
#                        MRI_Track_Age_at_Scan  ADHD_Outcome     Sex_F
# MRI_Track_Age_at_Scan               1.000000      0.015844 -0.036466
# ADHD_Outcome                        0.015844      1.000000 -0.139059
# Sex_F                              -0.036466     -0.139059  1.000000

# %% [markdown]
# ✅  Since age has almost no correlation with ADHD or sex, it’s not adding useful predictive power.

# %%
age_train.describe()
# Out:
#        EHQ_EHQ_Total  ColorVision_CV_Score  APQ_P_APQ_P_CP  APQ_P_APQ_P_ID  \
# count    1117.000000           1129.000000     1118.000000     1118.000000
# mean       59.649141             13.401240        3.834526       13.358676
# std        49.805728              2.164191        1.350880        3.577155
# min      -100.000000              0.000000        2.000000        5.000000
# 25%        46.670000             14.000000        3.000000       11.000000
# 50%        80.000000             14.000000        3.000000       13.000000
# 75%        94.470000             14.000000        4.000000       16.000000
# max       100.000000             14.000000       12.000000       28.000000
#
#        APQ_P_APQ_P_INV  APQ_P_APQ_P_OPD  APQ_P_APQ_P_PM  APQ_P_APQ_P_PP  \
# count      1118.000000      1118.000000     1118.000000     1118.000000
# mean         39.712880        17.931127       16.662791       25.454383
# std           4.821508         3.322382        5.183981        3.080126
# min          23.000000         7.000000        5.000000       13.000000
# 25%          36.000000        16.000000       13.000000       23.000000
# 50%          40.000000        18.000000       16.000000       26.000000
# 75%          43.000000        20.000000       20.000000       28.000000
# max          50.000000        28.000000       37.000000       30.000000
#
#        SDQ_SDQ_Conduct_Problems  SDQ_SDQ_Difficulties_Total  \
# count               1125.000000                 1125.000000
# mean                   2.046222                   12.095111
# std                    2.018067                    6.502725
# min                    0.000000                    0.000000
# 25%                    0.000000                    7.000000
# 50%                    2.000000                   12.000000
# 75%                    3.000000                   16.000000
# max                   10.000000                   34.000000
#
#        SDQ_SDQ_Emotional_Problems  SDQ_SDQ_Externalizing  \
# count                 1125.000000             1125.00000
# mean                     2.301333                7.52800
# std                      2.149412                4.12444
# min                      0.000000                0.00000
# 25%                      1.000000                4.00000
# 50%                      2.000000                7.00000
# 75%                      4.000000               10.00000
# max                     10.000000               20.00000
#
#        SDQ_SDQ_Generating_Impact  SDQ_SDQ_Hyperactivity  \
# count                1125.000000            1125.000000
# mean                    4.090667               5.481778
# std                     2.817515               2.802972
# min                     0.000000               0.000000
# 25%                     2.000000               3.000000
# 50%                     4.000000               5.000000
# 75%                     6.000000               8.000000
# max                    10.000000              10.000000
#
#        SDQ_SDQ_Internalizing  SDQ_SDQ_Peer_Problems  SDQ_SDQ_Prosocial  \
# count            1125.000000            1125.000000        1125.000000
# mean                4.567111               2.265778           7.728000
# std                 3.513343               2.086973           2.096593
# min                 0.000000               0.000000           0.000000
# 25%                 2.000000               0.000000           6.000000
# 50%                 4.000000               2.000000           8.000000
# 75%                 7.000000               4.000000          10.000000
# max                17.000000               9.000000          10.000000
#
#        MRI_Track_Age_at_Scan  ADHD_Outcome        Sex_F
# count             793.000000   1129.000000  1129.000000
# mean               11.248889      0.684677     0.346324
# std                 3.249396      0.464850     0.476009
# min                 0.000000      0.000000     0.000000
# 25%                 8.817362      0.000000     0.000000
# 50%                10.731234      1.000000     0.000000
# 75%                13.463381      1.000000     1.000000
# max                21.564453      1.000000     1.000000

# %% [markdown]
# Age:
#
# Until 6 years old brain is developing. At age 7 brain is 95% of size of adult brain.
#
# Proposed Age Groups for Brain Development:
#
# Infants & Toddlers (0-2 years)
#
# Rapid brain growth, synaptic overproduction, and pruning start.
# Development of sensory and motor functions.
#
# Early Childhood (3-6 years)
#
# Significant language development.
# Strengthening of neural pathways for movement and emotion regulation.
#
# Middle Childhood (6-10 years)
#
# Improved cognitive functions, attention, and problem-solving.
# Growth in prefrontal cortex for executive functioning.
#
# Early Adolescence (10-14 years)
#
# Onset of puberty, increased limbic system activity.
# Prefrontal cortex still developing, leading to risk-taking behaviors.
#
# Mid Adolescence (14-18 years)
#
# Strengthening of executive function, impulse control starts improving.
# Increasing white matter, pruning of unused neural connections.
#
# Late Adolescence & Early Adulthood (19-21 years)
#
# Continued maturation of the prefrontal cortex (responsible for decision-making and reasoning).
#
# Near-complete myelination, but emotional regulation still developing.
#
#
# These divisions align with key neurodevelopmental changes.
# They reflect cognitive, emotional, and behavioral transformations.
# They match findings from MRI studies on brain maturation.

# %% [markdown]
# **It makes sense to consider only group of age 6-18**

# %%
filtered_age = age_train[(age_train['MRI_Track_Age_at_Scan'] < 6) | (age_train['MRI_Track_Age_at_Scan'] > 19)]['participant_id'].tolist()
len(filtered_age)
# Out:
# 16

# %% [markdown]
# It less than 2 % of data base. Let's treat them as an outliers. And delete from database

# %%
filtered_data = age_train[age_train['participant_id'].isin(filtered_age)]

sex_counts = filtered_data['Sex_F'].value_counts()
adhd_counts = filtered_data['ADHD_Outcome'].value_counts()
print("Sex_F counts for filtered participants:\n", sex_counts)
print("\nADHD_Outcome counts for filtered participants:\n", adhd_counts)
# Out:
# Sex_F counts for filtered participants:
#  Sex_F
# 1    9
# 0    7
# Name: count, dtype: int64
#
# ADHD_Outcome counts for filtered participants:
#  ADHD_Outcome
# 1    11
# 0     5
# Name: count, dtype: int64

# %%
print("\nTRAIN_CATEGORICAL_METADATA.xlsx")
train_cat.info()
print("\nTRAIN_FUNCTIONAL_CONNECTOME_MATRICES.csv")
train_fcm.info()
print("\nTRAIN_QUANTITATIVE_METADATA.xlsx")
train_quan.info()
print("\nTRAINING_SOLUTIONS.xlsx")
train_sol.info()
# Out:
# TRAIN_CATEGORICAL_METADATA.xlsx
# <class 'pandas.DataFrame'>
# Index: 1129 entries, 0 to 1212
# Data columns (total 7 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   participant_id                    1129 non-null   str
#  1   PreInt_Demos_Fam_Child_Ethnicity  1129 non-null   float64
#  2   PreInt_Demos_Fam_Child_Race       1129 non-null   float64
#  3   Barratt_Barratt_P1_Edu            1115 non-null   float64
#  4   Barratt_Barratt_P1_Occ            1102 non-null   float64
#  5   Barratt_Barratt_P2_Edu            945 non-null    float64
#  6   Barratt_Barratt_P2_Occ            924 non-null    float64
# dtypes: float64(6), str(1)
# memory usage: 70.6 KB
#
# TRAIN_FUNCTIONAL_CONNECTOME_MATRICES.csv
# <class 'pandas.DataFrame'>
# Index: 1129 entries, 0 to 1212
# Columns: 19901 entries, participant_id to 198throw_199thcolumn
# dtypes: float64(19900), str(1)
# memory usage: 171.4 MB
#
# TRAIN_QUANTITATIVE_METADATA.xlsx
# <class 'pandas.DataFrame'>
# Index: 1129 entries, 0 to 1212
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   participant_id              1129 non-null   str
#  1   EHQ_EHQ_Total               1117 non-null   float64
#  2   ColorVision_CV_Score        1129 non-null   float64
#  3   APQ_P_APQ_P_CP              1118 non-null   float64
#  4   APQ_P_APQ_P_ID              1118 non-null   float64
#  5   APQ_P_APQ_P_INV             1118 non-null   float64
#  6   APQ_P_APQ_P_OPD             1118 non-null   float64
#  7   APQ_P_APQ_P_PM              1118 non-null   float64
#  8   APQ_P_APQ_P_PP              1118 non-null   float64
#  9   SDQ_SDQ_Conduct_Problems    1125 non-null   float64
#  10  SDQ_SDQ_Difficulties_Total  1125 non-null   float64
#  11  SDQ_SDQ_Emotional_Problems  1125 non-null   float64
#  12  SDQ_SDQ_Externalizing       1125 non-null   float64
#  13  SDQ_SDQ_Generating_Impact   1125 non-null   float64
#  14  SDQ_SDQ_Hyperactivity       1125 non-null   float64
#  15  SDQ_SDQ_Internalizing       1125 non-null   float64
#  16  SDQ_SDQ_Peer_Problems       1125 non-null   float64
#  17  SDQ_SDQ_Prosocial           1125 non-null   float64
#  18  MRI_Track_Age_at_Scan       793 non-null    float64
# dtypes: float64(18), str(1)
# memory usage: 176.4 KB
#
# TRAINING_SOLUTIONS.xlsx
# <class 'pandas.DataFrame'>
# Index: 1129 entries, 0 to 1212
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   participant_id  1129 non-null   str
#  1   ADHD_Outcome    1129 non-null   int64
#  2   Sex_F           1129 non-null   int64
# dtypes: int64(2), str(1)
# memory usage: 35.3 KB

# %%
filtered_participants = set(filtered_age)

train_cat = train_cat[~train_cat['participant_id'].isin(filtered_participants)]
train_fcm = train_fcm[~train_fcm['participant_id'].isin(filtered_participants)]
train_quan = train_quan[~train_quan['participant_id'].isin(filtered_participants)]
train_sol = train_sol[~train_sol['participant_id'].isin(filtered_participants)]

# %%
print("\nTRAIN_CATEGORICAL_METADATA.xlsx")
train_cat.info()
print("\nTRAIN_FUNCTIONAL_CONNECTOME_MATRICES.csv")
train_fcm.info()
print("\nTRAIN_QUANTITATIVE_METADATA.xlsx")
train_quan.info()
print("\nTRAINING_SOLUTIONS.xlsx")
train_sol.info()
# Out:
# TRAIN_CATEGORICAL_METADATA.xlsx
# <class 'pandas.DataFrame'>
# Index: 1113 entries, 0 to 1212
# Data columns (total 7 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   participant_id                    1113 non-null   str
#  1   PreInt_Demos_Fam_Child_Ethnicity  1113 non-null   float64
#  2   PreInt_Demos_Fam_Child_Race       1113 non-null   float64
#  3   Barratt_Barratt_P1_Edu            1099 non-null   float64
#  4   Barratt_Barratt_P1_Occ            1087 non-null   float64
#  5   Barratt_Barratt_P2_Edu            930 non-null    float64
#  6   Barratt_Barratt_P2_Occ            911 non-null    float64
# dtypes: float64(6), str(1)
# memory usage: 69.6 KB
#
# TRAIN_FUNCTIONAL_CONNECTOME_MATRICES.csv
# <class 'pandas.DataFrame'>
# Index: 1113 entries, 0 to 1212
# Columns: 19901 entries, participant_id to 198throw_199thcolumn
# dtypes: float64(19900), str(1)
# memory usage: 169.0 MB
#
# TRAIN_QUANTITATIVE_METADATA.xlsx
# <class 'pandas.DataFrame'>
# Index: 1113 entries, 0 to 1212
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   participant_id              1113 non-null   str
#  1   EHQ_EHQ_Total               1101 non-null   float64
#  2   ColorVision_CV_Score        1113 non-null   float64
#  3   APQ_P_APQ_P_CP              1105 non-null   float64
#  4   APQ_P_APQ_P_ID              1105 non-null   float64
#  5   APQ_P_APQ_P_INV             1105 non-null   float64
#  6   APQ_P_APQ_P_OPD             1105 non-null   float64
#  7   APQ_P_APQ_P_PM              1105 non-null   float64
#  8   APQ_P_APQ_P_PP              1105 non-null   float64
#  9   SDQ_SDQ_Conduct_Problems    1109 non-null   float64
#  10  SDQ_SDQ_Difficulties_Total  1109 non-null   float64
#  11  SDQ_SDQ_Emotional_Problems  1109 non-null   float64
#  12  SDQ_SDQ_Externalizing       1109 non-null   float64
#  13  SDQ_SDQ_Generating_Impact   1109 non-null   float64
#  14  SDQ_SDQ_Hyperactivity       1109 non-null   float64
#  15  SDQ_SDQ_Internalizing       1109 non-null   float64
#  16  SDQ_SDQ_Peer_Problems       1109 non-null   float64
#  17  SDQ_SDQ_Prosocial           1109 non-null   float64
#  18  MRI_Track_Age_at_Scan       777 non-null    float64
# dtypes: float64(18), str(1)
# memory usage: 173.9 KB
#
# TRAINING_SOLUTIONS.xlsx
# <class 'pandas.DataFrame'>
# Index: 1113 entries, 0 to 1212
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   participant_id  1113 non-null   str
#  1   ADHD_Outcome    1113 non-null   int64
#  2   Sex_F           1113 non-null   int64
# dtypes: int64(2), str(1)
# memory usage: 34.8 KB

# %% [markdown]
# **Checking Brain Development vs. Age**
#
# 01_eda.ipynb
#
# Correlations between age and brain development - moderate with few regions around 0.3
#
#     Correlation between 'MRI_Track_Age_at_Scan' and '21throw_89thcolumn': -0.311
#     Correlation between 'MRI_Track_Age_at_Scan' and '23throw_89thcolumn': -0.307
#     Correlation between 'MRI_Track_Age_at_Scan' and '23throw_139thcolumn': 0.317
#     Correlation between 'MRI_Track_Age_at_Scan' and '37throw_40thcolumn': 0.303
#     Correlation between 'MRI_Track_Age_at_Scan' and '37throw_41thcolumn': 0.317
#     Correlation between 'MRI_Track_Age_at_Scan' and '37throw_114thcolumn': 0.320
#     Correlation between 'MRI_Track_Age_at_Scan' and '37throw_145thcolumn': 0.306
#     Correlation between 'MRI_Track_Age_at_Scan' and '40throw_91thcolumn': -0.313
#     Correlation between 'MRI_Track_Age_at_Scan' and '40throw_138thcolumn': 0.317
#     Correlation between 'MRI_Track_Age_at_Scan' and '40throw_139thcolumn': 0.302
#     Correlation between 'MRI_Track_Age_at_Scan' and '41throw_89thcolumn': -0.332
#     Correlation between 'MRI_Track_Age_at_Scan' and '41throw_138thcolumn': 0.309
#     Correlation between 'MRI_Track_Age_at_Scan' and '41throw_139thcolumn': 0.336
#     Correlation between 'MRI_Track_Age_at_Scan' and '48throw_81thcolumn': -0.304
#     Correlation between 'MRI_Track_Age_at_Scan' and '48throw_91thcolumn': -0.309
#     Correlation between 'MRI_Track_Age_at_Scan' and '66throw_138thcolumn': -0.305
#     Correlation between 'MRI_Track_Age_at_Scan' and '68throw_138thcolumn': -0.323
#     Correlation between 'MRI_Track_Age_at_Scan' and '69throw_138thcolumn': -0.302
#     Correlation between 'MRI_Track_Age_at_Scan' and '69throw_159thcolumn': -0.317
#     Correlation between 'MRI_Track_Age_at_Scan' and '70throw_177thcolumn': -0.311
#     Correlation between 'MRI_Track_Age_at_Scan' and '74throw_138thcolumn': -0.303
#     Correlation between 'MRI_Track_Age_at_Scan' and '74throw_148thcolumn': -0.300
#     Correlation between 'MRI_Track_Age_at_Scan' and '76throw_158thcolumn': 0.310
#     Correlation between 'MRI_Track_Age_at_Scan' and '80throw_138thcolumn': -0.303
#     Correlation between 'MRI_Track_Age_at_Scan' and '80throw_151thcolumn': -0.377
#     Correlation between 'MRI_Track_Age_at_Scan' and '80throw_152thcolumn': -0.327
#     Correlation between 'MRI_Track_Age_at_Scan' and '80throw_159thcolumn': -0.316
#     Correlation between 'MRI_Track_Age_at_Scan' and '81throw_167thcolumn': -0.308
#     Correlation between 'MRI_Track_Age_at_Scan' and '84throw_151thcolumn': -0.321
#     Correlation between 'MRI_Track_Age_at_Scan' and '87throw_151thcolumn': -0.337
#     Correlation between 'MRI_Track_Age_at_Scan' and '88throw_151thcolumn': -0.348
#     Correlation between 'MRI_Track_Age_at_Scan' and '88throw_152thcolumn': -0.310
#     Correlation between 'MRI_Track_Age_at_Scan' and '114throw_139thcolumn': 0.303
#     Correlation between 'MRI_Track_Age_at_Scan' and '127throw_139thcolumn': 0.304
#     Correlation between 'MRI_Track_Age_at_Scan' and '138throw_145thcolumn': 0.329
#     Correlation between 'MRI_Track_Age_at_Scan' and '139throw_145thcolumn': 0.305

# %% [markdown]
# Correlation with other features:
#
# Correlation between 'APQ_P_APQ_P_PM' and 'MRI_Track_Age_at_Scan': 0.550
#
# `APQ_P_APQ_P_PM`: Poor Monitoring/Supervision Score (int)

# %% [markdown]
# ✅ No correlations with missing age and other quantity or categorical data

# %% [markdown]
# Dropping AGE column - Too many missing values. After analise it doesnt have impact on other data

# %%
train_quan.drop('MRI_Track_Age_at_Scan', axis = 1, inplace=True)

# %%
print(train_quan.isnull().sum())
print(train_cat.isnull().sum())
# Out:
# participant_id                 0
# EHQ_EHQ_Total                 12
# ColorVision_CV_Score           0
# APQ_P_APQ_P_CP                 8
# APQ_P_APQ_P_ID                 8
# APQ_P_APQ_P_INV                8
# APQ_P_APQ_P_OPD                8
# APQ_P_APQ_P_PM                 8
# APQ_P_APQ_P_PP                 8
# SDQ_SDQ_Conduct_Problems       4
# SDQ_SDQ_Difficulties_Total     4
# SDQ_SDQ_Emotional_Problems     4
# SDQ_SDQ_Externalizing          4
# SDQ_SDQ_Generating_Impact      4
# SDQ_SDQ_Hyperactivity          4
# SDQ_SDQ_Internalizing          4
# SDQ_SDQ_Peer_Problems          4
# SDQ_SDQ_Prosocial              4
# dtype: int64
# participant_id                        0
# PreInt_Demos_Fam_Child_Ethnicity      0
# PreInt_Demos_Fam_Child_Race           0
# Barratt_Barratt_P1_Edu               14
# Barratt_Barratt_P1_Occ               26
# Barratt_Barratt_P2_Edu              183
# Barratt_Barratt_P2_Occ              202
# dtype: int64

# %% [markdown]
#     Barratt_Barratt_P1_Edu
#     Barratt_Barratt_P1_Occ
#     Barratt_Barratt_P2_Edu
#     Barratt_Barratt_P2_Occ
#
# These features don’t correlate with ADHD or sex, they likely won’t help the model.
#
# Keeping them may just add noise and make the model overfit or slower.
#
# Deleting this columns

# %%
train_cat.drop('Barratt_Barratt_P1_Edu',  axis = 1, inplace=True)
train_cat.drop('Barratt_Barratt_P1_Occ', axis = 1, inplace=True)
train_cat.drop('Barratt_Barratt_P2_Edu',  axis = 1, inplace=True)
train_cat.drop('Barratt_Barratt_P2_Occ', axis = 1, inplace=True)

# %%
cols_to_check = [
    'EHQ_EHQ_Total', 'APQ_P_APQ_P_CP', 'APQ_P_APQ_P_ID', 'APQ_P_APQ_P_INV',
    'APQ_P_APQ_P_OPD', 'APQ_P_APQ_P_PM', 'APQ_P_APQ_P_PP',
    'SDQ_SDQ_Conduct_Problems', 'SDQ_SDQ_Difficulties_Total', 'SDQ_SDQ_Emotional_Problems',
    'SDQ_SDQ_Externalizing', 'SDQ_SDQ_Generating_Impact', 'SDQ_SDQ_Hyperactivity',
    'SDQ_SDQ_Internalizing', 'SDQ_SDQ_Peer_Problems', 'SDQ_SDQ_Prosocial'
]

participants_to_drop = train_quan[train_quan[cols_to_check].isnull().any(axis=1)]['participant_id']

train_cat = train_cat[~train_cat['participant_id'].isin(participants_to_drop)]
train_fcm = train_fcm[~train_fcm['participant_id'].isin(participants_to_drop)]
train_quan = train_quan[~train_quan['participant_id'].isin(participants_to_drop)]

train_sol = train_sol[~train_sol['participant_id'].isin(participants_to_drop)]

# %%
print(train_quan.isnull().sum())
print(train_cat.isnull().sum())
print(train_sol.isnull().sum())
print(train_fcm.isnull().sum())
# Out:
# participant_id                0
# EHQ_EHQ_Total                 0
# ColorVision_CV_Score          0
# APQ_P_APQ_P_CP                0
# APQ_P_APQ_P_ID                0
# APQ_P_APQ_P_INV               0
# APQ_P_APQ_P_OPD               0
# APQ_P_APQ_P_PM                0
# APQ_P_APQ_P_PP                0
# SDQ_SDQ_Conduct_Problems      0
# SDQ_SDQ_Difficulties_Total    0
# SDQ_SDQ_Emotional_Problems    0
# SDQ_SDQ_Externalizing         0
# SDQ_SDQ_Generating_Impact     0
# SDQ_SDQ_Hyperactivity         0
# SDQ_SDQ_Internalizing         0
# SDQ_SDQ_Peer_Problems         0
# SDQ_SDQ_Prosocial             0
# dtype: int64
# participant_id                      0
# PreInt_Demos_Fam_Child_Ethnicity    0
# PreInt_Demos_Fam_Child_Race         0
# dtype: int64
# participant_id    0
# ADHD_Outcome      0
# Sex_F             0
# dtype: int64
# participant_id          0
# 0throw_1thcolumn        0
# 0throw_2thcolumn        0
# 0throw_3thcolumn        0
# 0throw_4thcolumn        0
#                        ..
# 196throw_198thcolumn    0
# 196throw_199thcolumn    0
# 197throw_198thcolumn    0
# 197throw_199thcolumn    0
# 198throw_199thcolumn    0
# Length: 19901, dtype: int64

# %% [markdown]
# ✅ no NULL values in TRAIN DATASET

# %% [markdown]
#     Correlation between 'SDQ_SDQ_Conduct_Problems' and 'SDQ_SDQ_Difficulties_Total': 0.706
#     Correlation between 'SDQ_SDQ_Conduct_Problems' and 'SDQ_SDQ_Externalizing': 0.780
#     Correlation between 'SDQ_SDQ_Difficulties_Total' and 'SDQ_SDQ_Externalizing': 0.877
#     Correlation between 'SDQ_SDQ_Difficulties_Total' and 'SDQ_SDQ_Generating_Impact': 0.716
#     Correlation between 'SDQ_SDQ_Difficulties_Total' and 'SDQ_SDQ_Hyperactivity': 0.777
#     Correlation between 'SDQ_SDQ_Difficulties_Total' and 'SDQ_SDQ_Internalizing': 0.816
#     Correlation between 'SDQ_SDQ_Emotional_Problems' and 'SDQ_SDQ_Internalizing': 0.816
#     Correlation between 'SDQ_SDQ_Externalizing' and 'SDQ_SDQ_Hyperactivity': 0.904
#     Correlation between 'SDQ_SDQ_Internalizing' and 'SDQ_SDQ_Peer_Problems': 0.822

# %% [markdown]
# * **Strength and Difficulties Questionnaire**
#     * `SDQ_SDQ_Conduct_Problems`: Conduct problems scale (int)
#     * `SDQ_SDQ_Difficulties_Total`: Total Difficulties Score (int)
#     * `SDQ_SDQ_Emotional_Problems`: Emotional Problems Scale (int)
#     * `SDQ_SDQ_Externalizing`: Externalizing Score (int)
#     * `SDQ_SDQ_Generating_Impact`: Generating Impact Scores (int)
#     * `SDQ_SDQ_Hyperactivity`: Hyperactivity Scale (int)
#     * `SDQ_SDQ_Internalizing`: Internalizing Score (int)
#     * `SDQ_SDQ_Peer_Problems`: Peer Problems Scale (int)
#     * `SDQ_SDQ_Prosocial`: Prosocial Scale (int)
#
# Keeping the 5 original SDQ subscales:
#
#     SDQ_Emotional_Problems
#     SDQ_Conduct_Problems
#     SDQ_Hyperactivity
#     SDQ_Peer_Problems
#     SDQ_Prosocial
#     SDQ_Generating_Impact
#
# And droping:
#
#     SDQ_Externalizing (it's sum of Conduct + Hyperactivity)
#     SDQ_Internalizing (Emotional + Peer)
#     SDQ_Difficulties_Total (sum of all except Prosocial)
#
# Why? Because we don’t want to duplicate signal — that just inflates importance and adds collinearity.

# %%
train_quan.drop('SDQ_SDQ_Externalizing',  axis = 1, inplace=True)
train_quan.drop('SDQ_SDQ_Internalizing',  axis = 1, inplace=True)
train_quan.drop('SDQ_SDQ_Difficulties_Total',  axis = 1, inplace=True)

# %%
train_quan.info()
train_cat.info()
train_sol.info()
train_fcm.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1090 entries, 0 to 1212
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   participant_id              1090 non-null   str
#  1   EHQ_EHQ_Total               1090 non-null   float64
#  2   ColorVision_CV_Score        1090 non-null   float64
#  3   APQ_P_APQ_P_CP              1090 non-null   float64
#  4   APQ_P_APQ_P_ID              1090 non-null   float64
#  5   APQ_P_APQ_P_INV             1090 non-null   float64
#  6   APQ_P_APQ_P_OPD             1090 non-null   float64
#  7   APQ_P_APQ_P_PM              1090 non-null   float64
#  8   APQ_P_APQ_P_PP              1090 non-null   float64
#  9   SDQ_SDQ_Conduct_Problems    1090 non-null   float64
#  10  SDQ_SDQ_Emotional_Problems  1090 non-null   float64
#  11  SDQ_SDQ_Generating_Impact   1090 non-null   float64
#  12  SDQ_SDQ_Hyperactivity       1090 non-null   float64
#  13  SDQ_SDQ_Peer_Problems       1090 non-null   float64
#  14  SDQ_SDQ_Prosocial           1090 non-null   float64
# dtypes: float64(14), str(1)
# memory usage: 136.2 KB
# <class 'pandas.DataFrame'>
# Index: 1090 entries, 0 to 1212
# Data columns (total 3 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   participant_id                    1090 non-null   str
#  1   PreInt_Demos_Fam_Child_Ethnicity  1090 non-null   float64
#  2   PreInt_Demos_Fam_Child_Race       1090 non-null   float64
# dtypes: float64(2), str(1)
# memory usage: 34.1 KB
# <class 'pandas.DataFrame'>
# Index: 1090 entries, 0 to 1212
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   participant_id  1090 non-null   str
#  1   ADHD_Outcome    1090 non-null   int64
#  2   Sex_F           1090 non-null   int64
# dtypes: int64(2), str(1)
# memory usage: 34.1 KB
# <class 'pandas.DataFrame'>
# Index: 1090 entries, 0 to 1212
# Columns: 19901 entries, participant_id to 198throw_199thcolumn
# dtypes: float64(19900), str(1)
# memory usage: 165.5 MB

# %% [markdown]
# We have 1082 participants from 1213 of whole package = 89,2 %

# %% [markdown]
# We have to now transform test dataset so it will have same amount of features

# %%
import pandas as pd

base_path = r"C:\Users\Admin\Downloads\model_adhd\widsdatathon2025"

test_cat = pd.read_excel(base_path + r"\TEST\TEST_CATEGORICAL.xlsx")
test_fcm = pd.read_csv(base_path + r"\TEST\TEST_FUNCTIONAL_CONNECTOME_MATRICES.csv")
test_quan = pd.read_excel(base_path + r"\TEST\TEST_QUANTITATIVE_METADATA.xlsx")

# %%
cat_columns = train_cat.columns
quan_columns = train_quan.columns

# %%
test_cat = test_cat[cat_columns]
test_quan = test_quan[quan_columns]

# %%
train_quan.info()
train_cat.info()
test_quan.info()
test_cat.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1090 entries, 0 to 1212
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   participant_id              1090 non-null   str
#  1   EHQ_EHQ_Total               1090 non-null   float64
#  2   ColorVision_CV_Score        1090 non-null   float64
#  3   APQ_P_APQ_P_CP              1090 non-null   float64
#  4   APQ_P_APQ_P_ID              1090 non-null   float64
#  5   APQ_P_APQ_P_INV             1090 non-null   float64
#  6   APQ_P_APQ_P_OPD             1090 non-null   float64
#  7   APQ_P_APQ_P_PM              1090 non-null   float64
#  8   APQ_P_APQ_P_PP              1090 non-null   float64
#  9   SDQ_SDQ_Conduct_Problems    1090 non-null   float64
#  10  SDQ_SDQ_Emotional_Problems  1090 non-null   float64
#  11  SDQ_SDQ_Generating_Impact   1090 non-null   float64
#  12  SDQ_SDQ_Hyperactivity       1090 non-null   float64
#  13  SDQ_SDQ_Peer_Problems       1090 non-null   float64
#  14  SDQ_SDQ_Prosocial           1090 non-null   float64
# dtypes: float64(14), str(1)
# memory usage: 136.2 KB
# <class 'pandas.DataFrame'>
# Index: 1090 entries, 0 to 1212
# Data columns (total 3 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   participant_id                    1090 non-null   str
#  1   PreInt_Demos_Fam_Child_Ethnicity  1090 non-null   float64
#  2   PreInt_Demos_Fam_Child_Race       1090 non-null   float64
# dtypes: float64(2), str(1)
# memory usage: 34.1 KB
# <class 'pandas.DataFrame'>
# RangeIndex: 304 entries, 0 to 303
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   participant_id              304 non-null    str
#  1   EHQ_EHQ_Total               303 non-null    float64
#  2   ColorVision_CV_Score        295 non-null    float64
#  3   APQ_P_APQ_P_CP              289 non-null    float64
#  4   APQ_P_APQ_P_ID              289 non-null    float64
#  5   APQ_P_APQ_P_INV             289 non-null    float64
#  6   APQ_P_APQ_P_OPD             289 non-null    float64
#  7   APQ_P_APQ_P_PM              289 non-null    float64
#  8   APQ_P_APQ_P_PP              289 non-null    float64
#  9   SDQ_SDQ_Conduct_Problems    274 non-null    float64
#  10  SDQ_SDQ_Emotional_Problems  274 non-null    float64
#  11  SDQ_SDQ_Generating_Impact   274 non-null    float64
#  12  SDQ_SDQ_Hyperactivity       274 non-null    float64
#  13  SDQ_SDQ_Peer_Problems       274 non-null    float64
#  14  SDQ_SDQ_Prosocial           274 non-null    float64
# dtypes: float64(14), str(1)
# memory usage: 35.8 KB
# <class 'pandas.DataFrame'>
# RangeIndex: 304 entries, 0 to 303
# Data columns (total 3 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   participant_id                    304 non-null    str
#  1   PreInt_Demos_Fam_Child_Ethnicity  301 non-null    float64
#  2   PreInt_Demos_Fam_Child_Race       298 non-null    float64
# dtypes: float64(2), str(1)
# memory usage: 7.2 KB

# %% [markdown]
# A lot of MRI features are highly correlated.
#
# Highly correlated features (corr > 0.8) to cut of redundancy.
#
# That can be a very good step, especially for:
#
# ✅ Model performance (faster training, lower overfitting risk)
# ✅ Interpretability
# ✅ Memory + computation savings

# %%
def find_significant_correlations(corr_matrix, threshold=0.3):
    significant_corrs = []
    for i in range(len(corr_matrix.columns)):
        for j in range(i + 1, len(corr_matrix.columns)):
            if abs(corr_matrix.iloc[i, j]) > threshold:
                significant_corrs.append({
                    'feature1': corr_matrix.columns[i],
                    'feature2': corr_matrix.columns[j],
                    'correlation': corr_matrix.iloc[i, j]
                })
    return significant_corrs

# %%
import numpy as np
import pandas as pd
import time

# استخراج الأعمدة الرقمية فقط
numerical_data_fcm = train_fcm.select_dtypes(include=np.number).copy()

# حذف الأعمدة الثابتة (التي تحتوي على قيمة واحدة فقط)
numerical_data_fcm = numerical_data_fcm.loc[:, numerical_data_fcm.nunique() > 1]

# تقليل استهلاك الذاكرة
numerical_data_fcm = numerical_data_fcm.astype("float32")

# إذا كانت البيانات كبيرة جداً، استخدم عينة
if len(numerical_data_fcm) > 10000:
    numerical_data_fcm = numerical_data_fcm.sample(
        n=10000,
        random_state=42
    )

print(f"Data Shape: {numerical_data_fcm.shape}")

# حساب Spearman Correlation
start = time.time()

spearman_corr_fcm = numerical_data_fcm.corr(method="spearman")

print(f"Correlation Matrix Finished in {time.time()-start:.2f} seconds")

# استخراج الارتباطات العالية
threshold = 0.7

significant_spearman_fcm = []

mask = np.triu(np.ones_like(spearman_corr_fcm, dtype=bool), k=1)

rows, cols = np.where(
    (np.abs(spearman_corr_fcm.values) >= threshold) & mask
)

for r, c in zip(rows, cols):
    significant_spearman_fcm.append({
        "feature1": spearman_corr_fcm.index[r],
        "feature2": spearman_corr_fcm.columns[c],
        "correlation": spearman_corr_fcm.iloc[r, c]
    })

print("\nSignificant Spearman Correlations:")

if len(significant_spearman_fcm) == 0:
    print("No significant correlations found.")
else:
    for corr in significant_spearman_fcm:
        print(
            f"{corr['feature1']} <--> {corr['feature2']} : {corr['correlation']:.4f}"
        )
# Out:
# Data Shape: (1090, 19900)
# Correlation Matrix Finished in 1308.99 seconds
#
# Significant Spearman Correlations:
# 0throw_1thcolumn <--> 1throw_100thcolumn : 0.7484
# 0throw_2thcolumn <--> 2throw_100thcolumn : 0.7642
# 0throw_3thcolumn <--> 3throw_100thcolumn : 0.8212
# 0throw_4thcolumn <--> 4throw_100thcolumn : 0.8169
# 0throw_5thcolumn <--> 0throw_105thcolumn : 0.7375
# 0throw_5thcolumn <--> 5throw_100thcolumn : 0.7780
# 0throw_7thcolumn <--> 0throw_9thcolumn : 0.7575
# 0throw_7thcolumn <--> 0throw_106thcolumn : 0.7266
# 0throw_7thcolumn <--> 7throw_100thcolumn : 0.7019
# 0throw_8thcolumn <--> 0throw_107thcolumn : 0.7469
# 0throw_8thcolumn <--> 8throw_100thcolumn : 0.7998
# 0throw_9thcolumn <--> 0throw_108thcolumn : 0.8324
# 0throw_9thcolumn <--> 0throw_109thcolumn : 0.7930
# 0throw_9thcolumn <--> 0throw_110thcolumn : 0.7428
# 0throw_9thcolumn <--> 9throw_100thcolumn : 0.7674
# 0throw_10thcolumn <--> 0throw_110thcolumn : 0.7731
# 0throw_10thcolumn <--> 10throw_100thcolumn : 0.7698
# 0throw_11thcolumn <--> 0throw_105thcolumn : 0.7141
# 0throw_11thcolumn <--> 0throw_110thcolumn : 0.7277
# 0throw_11thcolumn <--> 0throw_111thcolumn : 0.7618
# 0throw_11thcolumn <--> 11throw_100thcolumn : 0.7655
# 0throw_12thcolumn <--> 0throw_114thcolumn : 0.7358
# 0throw_12thcolumn <--> 12throw_100thcolumn : 0.7749
# 0throw_13thcolumn <--> 13throw_100thcolumn : 0.7937
# 0throw_14thcolumn <--> 0throw_15thcolumn : 0.7728
# 0throw_14thcolumn <--> 14throw_100thcolumn : 0.7849
# 0throw_15thcolumn <--> 15throw_100thcolumn : 0.7833
# 0throw_16thcolumn <--> 16throw_100thcolumn : 0.7975
# 0throw_17thcolumn <--> 17throw_100thcolumn : 0.7934
# 0throw_18thcolumn <--> 0throw_120thcolumn : 0.7204
# 0throw_18thcolumn <--> 0throw_121thcolumn : 0.8150
# 0throw_18thcolumn <--> 18throw_100thcolumn : 0.8074
# 0throw_19thcolumn <--> 0throw_122thcolumn : 0.7873
# 0throw_19thcolumn <--> 19throw_100thcolumn : 0.7890
# 0throw_20thcolumn <--> 20throw_100thcolumn : 0.7854
# 0throw_21thcolumn <--> 0throw_123thcolumn : 0.7157
# 0throw_21thcolumn <--> 21throw_100thcolumn : 0.8197
# 0throw_22thcolumn <--> 22throw_100thcolumn : 0.7826
# 0throw_23thcolumn <--> 0throw_25thcolumn : 0.7114
# 0throw_23thcolumn <--> 0throw_127thcolumn : 0.7185
# 0throw_23thcolumn <--> 0throw_128thcolumn : 0.7097
# 0throw_23thcolumn <--> 23throw_100thcolumn : 0.8025
# 0throw_24thcolumn <--> 24throw_100thcolumn : 0.8138
# 0throw_25thcolumn <--> 0throw_39thcolumn : 0.7073
# 0throw_25thcolumn <--> 25throw_100thcolumn : 0.7974
# 0throw_26thcolumn <--> 0throw_129thcolumn : 0.8995
# 0throw_26thcolumn <--> 26throw_100thcolumn : 0.7794
# 0throw_26thcolumn <--> 100throw_129thcolumn : 0.7131
# 0throw_27thcolumn <--> 27throw_100thcolumn : 0.7993
# 0throw_28thcolumn <--> 28throw_100thcolumn : 0.8001
# 0throw_29thcolumn <--> 29throw_100thcolumn : 0.7463
# 0throw_30thcolumn <--> 5throw_30thcolumn : 0.7012
# 0throw_30thcolumn <--> 30throw_100thcolumn : 0.8346
# 0throw_31thcolumn <--> 6throw_31thcolumn : 0.7096
# 0throw_31thcolumn <--> 31throw_100thcolumn : 0.8682
# 0throw_32thcolumn <--> 32throw_100thcolumn : 0.8585
# 0throw_33thcolumn <--> 5throw_33thcolumn : 0.7219
# 0throw_33thcolumn <--> 6throw_33thcolumn : 0.7337
# 0throw_33thcolumn <--> 33throw_100thcolumn : 0.8679
# 0throw_33thcolumn <--> 33throw_105thcolumn : 0.7193
# 0throw_34thcolumn <--> 0throw_35thcolumn : 0.7565
# 0throw_34thcolumn <--> 0throw_39thcolumn : 0.7016
# 0throw_34thcolumn <--> 34throw_100thcolumn : 0.7786
# 0throw_35thcolumn <--> 35throw_100thcolumn : 0.7893
# 0throw_36thcolumn <--> 36throw_100thcolumn : 0.8224
# 0throw_37thcolumn <--> 0throw_139thcolumn : 0.7232
# 0throw_37thcolumn <--> 37throw_100thcolumn : 0.8200
# 0throw_38thcolumn <--> 6throw_38thcolumn : 0.7023
# 0throw_38thcolumn <--> 38throw_100thcolumn : 0.8377
# 0throw_39thcolumn <--> 0throw_141thcolumn : 0.7674
# 0throw_39thcolumn <--> 39throw_100thcolumn : 0.7924
# 0throw_40thcolumn <--> 40throw_100thcolumn : 0.7608
# 0throw_41thcolumn <--> 41throw_100thcolumn : 0.7432
# 0throw_42thcolumn <--> 42throw_100thcolumn : 0.7682
# 0throw_43thcolumn <--> 0throw_148thcolumn : 0.7285
# 0throw_43thcolumn <--> 43throw_100thcolumn : 0.8003
# 0throw_44thcolumn <--> 0throw_146thcolumn : 0.8148
# 0throw_44thcolumn <--> 44throw_100thcolumn : 0.8072
# 0throw_45thcolumn <--> 45throw_100thcolumn : 0.7880
# 0throw_46thcolumn <--> 46throw_100thcolumn : 0.8144
# 0throw_47thcolumn <--> 47throw_100thcolumn : 0.7590
# 0throw_48thcolumn <--> 0throw_154thcolumn : 0.7382
# 0throw_48thcolumn <--> 48throw_100thcolumn : 0.7669
# 0throw_49thcolumn <--> 0throw_155thcolumn : 0.7590
# 0throw_49thcolumn <--> 49throw_100thcolumn : 0.7666
# 0throw_50thcolumn <--> 50throw_100thcolumn : 0.7574
# 0throw_51thcolumn <--> 51throw_100thcolumn : 0.7570
# 0throw_52thcolumn <--> 52throw_100thcolumn : 0.7671
# 0throw_53thcolumn <--> 53throw_100thcolumn : 0.7884
# 0throw_54thcolumn <--> 54throw_100thcolumn : 0.7633
# 0throw_55thcolumn <--> 55throw_100thcolumn : 0.7303
# 0throw_56thcolumn <--> 56throw_100thcolumn : 0.8256
# 0throw_57thcolumn <--> 57throw_100thcolumn : 0.8372
# 0throw_58thcolumn <--> 58throw_100thcolumn : 0.8070
# 0throw_59thcolumn <--> 5throw_59thcolumn : 0.7224
# 0throw_59thcolumn <--> 6throw_59thcolumn : 0.7265
# 0throw_59thcolumn <--> 59throw_100thcolumn : 0.8503
# 0throw_59thcolumn <--> 59throw_105thcolumn : 0.7121
# 0throw_60thcolumn <--> 60throw_100thcolumn : 0.7942
# 0throw_61thcolumn <--> 61throw_100thcolumn : 0.7747
# 0throw_62thcolumn <--> 62throw_100thcolumn : 0.8031
# 0throw_63thcolumn <--> 63throw_100thcolumn : 0.8138
# 0throw_64thcolumn <--> 64throw_100thcolumn : 0.8097
# 0throw_65thcolumn <--> 65throw_100thcolumn : 0.7733
# 0throw_66thcolumn <--> 66throw_100thcolumn : 0.7982
# 0throw_67thcolumn <--> 67throw_100thcolumn : 0.8158
# 0throw_68thcolumn <--> 68throw_100thcolumn : 0.7797
# 0throw_69thcolumn <--> 69throw_100thcolumn : 0.7783
# 0throw_70thcolumn <--> 70throw_100thcolumn : 0.7839
# 0throw_71thcolumn <--> 0throw_180thcolumn : 0.7234
# 0throw_71thcolumn <--> 71throw_100thcolumn : 0.8314
# 0throw_72thcolumn <--> 0throw_138thcolumn : 0.7042
# 0throw_72thcolumn <--> 72throw_100thcolumn : 0.7917
# 0throw_73thcolumn <--> 0throw_182thcolumn : 0.7939
# 0throw_73thcolumn <--> 73throw_100thcolumn : 0.7613
# 0throw_74thcolumn <--> 74throw_100thcolumn : 0.7958
# 0throw_75thcolumn <--> 75throw_100thcolumn : 0.7614
# 0throw_76thcolumn <--> 0throw_185thcolumn : 0.8221
# 0throw_76thcolumn <--> 76throw_100thcolumn : 0.7889
# 0throw_77thcolumn <--> 77throw_100thcolumn : 0.7792
# 0throw_78thcolumn <--> 78throw_100thcolumn : 0.7907
# 0throw_79thcolumn <--> 0throw_158thcolumn : 0.7819
# 0throw_79thcolumn <--> 79throw_100thcolumn : 0.7750
# 0throw_80thcolumn <--> 80throw_100thcolumn : 0.7867
# 0throw_81thcolumn <--> 0throw_186thcolumn : 0.8272
# 0throw_81thcolumn <--> 81throw_100thcolumn : 0.7666
# 0throw_82thcolumn <--> 82throw_100thcolumn : 0.7444
# 0throw_83thcolumn <--> 83throw_100thcolumn : 0.7920
# 0throw_84thcolumn <--> 84throw_100thcolumn : 0.7734
# 0throw_85thcolumn <--> 85throw_100thcolumn : 0.7918
# 0throw_86thcolumn <--> 86throw_100thcolumn : 0.7978
# 0throw_87thcolumn <--> 0throw_88thcolumn : 0.7329
# 0throw_87thcolumn <--> 0throw_188thcolumn : 0.7406
# 0throw_87thcolumn <--> 87throw_100thcolumn : 0.7689
# 0throw_88thcolumn <--> 88throw_100thcolumn : 0.7675
# 0throw_89thcolumn <--> 89throw_100thcolumn : 0.7640
# 0throw_90thcolumn <--> 90throw_100thcolumn : 0.7812
# 0throw_91thcolumn <--> 91throw_100thcolumn : 0.7398
# 0throw_92thcolumn <--> 92throw_100thcolumn : 0.7707
# 0throw_93thcolumn <--> 93throw_100thcolumn : 0.7734
# 0throw_94thcolumn <--> 94throw_100thcolumn : 0.7959
# 0throw_95thcolumn <--> 95throw_100thcolumn : 0.8512
# 0throw_96thcolumn <--> 0throw_194thcolumn : 0.8250
# 0throw_96thcolumn <--> 96throw_100thcolumn : 0.8143
# 0throw_97thcolumn <--> 97throw_100thcolumn : 0.7932
# 0throw_98thcolumn <--> 98throw_100thcolumn : 0.8158
# 0throw_99thcolumn <--> 99throw_100thcolumn : 0.8141
# 0throw_101thcolumn <--> 100throw_101thcolumn : 0.7549
# 0throw_102thcolumn <--> 100throw_102thcolumn : 0.7886
# 0throw_103thcolumn <--> 100throw_103thcolumn : 0.7633
# 0throw_104thcolumn <--> 100throw_104thcolumn : 0.7658
# 0throw_105thcolumn <--> 100throw_105thcolumn : 0.7556
# 0throw_106thcolumn <--> 0throw_108thcolumn : 0.7495
# 0throw_107thcolumn <--> 0throw_109thcolumn : 0.8029
# 0throw_107thcolumn <--> 100throw_107thcolumn : 0.7863
# 0throw_108thcolumn <--> 0throw_109thcolumn : 0.7240
# 0throw_108thcolumn <--> 100throw_108thcolumn : 0.7517
# 0throw_109thcolumn <--> 0throw_110thcolumn : 0.7336
# 0throw_109thcolumn <--> 100throw_109thcolumn : 0.7681
# 0throw_110thcolumn <--> 0throw_111thcolumn : 0.7039
# 0throw_110thcolumn <--> 100throw_110thcolumn : 0.7800
# 0throw_111thcolumn <--> 100throw_111thcolumn : 0.8325
# 0throw_112thcolumn <--> 100throw_112thcolumn : 0.7714
# 0throw_113thcolumn <--> 100throw_113thcolumn : 0.7870
# 0throw_114thcolumn <--> 100throw_114thcolumn : 0.7845
# 0throw_115thcolumn <--> 0throw_117thcolumn : 0.7200
# 0throw_115thcolumn <--> 100throw_115thcolumn : 0.7721
# 0throw_116thcolumn <--> 100throw_116thcolumn : 0.8168
# 0throw_117thcolumn <--> 100throw_117thcolumn : 0.7631
# 0throw_118thcolumn <--> 100throw_118thcolumn : 0.7914
# 0throw_119thcolumn <--> 100throw_119thcolumn : 0.8170
# 0throw_120thcolumn <--> 100throw_120thcolumn : 0.8097
# 0throw_121thcolumn <--> 100throw_121thcolumn : 0.8018
# 0throw_122thcolumn <--> 100throw_122thcolumn : 0.7935
# 0throw_123thcolumn <--> 0throw_124thcolumn : 0.7060
# 0throw_123thcolumn <--> 100throw_123thcolumn : 0.8103
# 0throw_124thcolumn <--> 100throw_124thcolumn : 0.8166
# 0throw_125thcolumn <--> 100throw_125thcolumn : 0.7498
# 0throw_126thcolumn <--> 100throw_126thcolumn : 0.7760
# 0throw_127thcolumn <--> 100throw_127thcolumn : 0.7776
# 0throw_128thcolumn <--> 100throw_128thcolumn : 0.7795
# 0throw_129thcolumn <--> 26throw_100thcolumn : 0.7209
# 0throw_129thcolumn <--> 100throw_129thcolumn : 0.7833
# 0throw_130thcolumn <--> 100throw_130thcolumn : 0.7682
# 0throw_131thcolumn <--> 5throw_131thcolumn : 0.7289
# 0throw_131thcolumn <--> 100throw_131thcolumn : 0.8385
# 0throw_131thcolumn <--> 105throw_131thcolumn : 0.7075
# 0throw_132thcolumn <--> 6throw_132thcolumn : 0.7097
# 0throw_132thcolumn <--> 100throw_132thcolumn : 0.8429
# 0throw_133thcolumn <--> 100throw_133thcolumn : 0.8341
# 0throw_134thcolumn <--> 6throw_134thcolumn : 0.7172
# 0throw_134thcolumn <--> 100throw_134thcolumn : 0.8406
# 0throw_135thcolumn <--> 6throw_135thcolumn : 0.7161
# 0throw_135thcolumn <--> 100throw_135thcolumn : 0.8333
# 0throw_136thcolumn <--> 100throw_136thcolumn : 0.7883
# 0throw_137thcolumn <--> 100throw_137thcolumn : 0.8063
# 0throw_138thcolumn <--> 100throw_138thcolumn : 0.8084
# 0throw_139thcolumn <--> 100throw_139thcolumn : 0.8090
# 0throw_140thcolumn <--> 5throw_140thcolumn : 0.7038
# 0throw_140thcolumn <--> 100throw_140thcolumn : 0.8471
# 0throw_140thcolumn <--> 105throw_140thcolumn : 0.7053
# 0throw_141thcolumn <--> 100throw_141thcolumn : 0.7982
# 0throw_142thcolumn <--> 6throw_142thcolumn : 0.7121
# 0throw_142thcolumn <--> 100throw_142thcolumn : 0.8282
# 0throw_143thcolumn <--> 100throw_143thcolumn : 0.7168
# 0throw_144thcolumn <--> 100throw_144thcolumn : 0.7826
# 0throw_145thcolumn <--> 0throw_146thcolumn : 0.7128
# 0throw_145thcolumn <--> 100throw_145thcolumn : 0.7802
# 0throw_146thcolumn <--> 100throw_146thcolumn : 0.8014
# 0throw_147thcolumn <--> 100throw_147thcolumn : 0.7850
# 0throw_148thcolumn <--> 100throw_148thcolumn : 0.8063
# 0throw_149thcolumn <--> 100throw_149thcolumn : 0.8148
# 0throw_150thcolumn <--> 100throw_150thcolumn : 0.8081
# 0throw_151thcolumn <--> 100throw_151thcolumn : 0.7809
# 0throw_152thcolumn <--> 100throw_152thcolumn : 0.7659
# 0throw_153thcolumn <--> 100throw_153thcolumn : 0.7333
# 0throw_154thcolumn <--> 100throw_154thcolumn : 0.7736
# 0throw_155thcolumn <--> 100throw_155thcolumn : 0.7737
# 0throw_156thcolumn <--> 100throw_156thcolumn : 0.7579
# 0throw_157thcolumn <--> 100throw_157thcolumn : 0.7639
# 0throw_158thcolumn <--> 100throw_158thcolumn : 0.7945
# 0throw_159thcolumn <--> 100throw_159thcolumn : 0.7677
# 0throw_160thcolumn <--> 100throw_160thcolumn : 0.7887
# 0throw_161thcolumn <--> 100throw_161thcolumn : 0.8082
# 0throw_162thcolumn <--> 100throw_162thcolumn : 0.7759
# 0throw_163thcolumn <--> 100throw_163thcolumn : 0.8217
# 0throw_164thcolumn <--> 100throw_164thcolumn : 0.8373
# 0throw_165thcolumn <--> 100throw_165thcolumn : 0.7937
# 0throw_166thcolumn <--> 100throw_166thcolumn : 0.8006
# 0throw_167thcolumn <--> 100throw_167thcolumn : 0.7900
# 0throw_168thcolumn <--> 100throw_168thcolumn : 0.8104
# 0throw_169thcolumn <--> 100throw_169thcolumn : 0.7531
# 0throw_170thcolumn <--> 100throw_170thcolumn : 0.7836
# 0throw_171thcolumn <--> 100throw_171thcolumn : 0.7854
# 0throw_172thcolumn <--> 100throw_172thcolumn : 0.8052
# 0throw_173thcolumn <--> 100throw_173thcolumn : 0.7975
# 0throw_174thcolumn <--> 100throw_174thcolumn : 0.7793
# 0throw_175thcolumn <--> 100throw_175thcolumn : 0.7828
# 0throw_176thcolumn <--> 100throw_176thcolumn : 0.7726
# 0throw_177thcolumn <--> 100throw_177thcolumn : 0.7855
# 0throw_178thcolumn <--> 100throw_178thcolumn : 0.7780
# 0throw_179thcolumn <--> 100throw_179thcolumn : 0.7747
# 0throw_180thcolumn <--> 100throw_180thcolumn : 0.8172
# 0throw_181thcolumn <--> 100throw_181thcolumn : 0.7997
# 0throw_182thcolumn <--> 100throw_182thcolumn : 0.7774
# 0throw_183thcolumn <--> 100throw_183thcolumn : 0.7910
# 0throw_184thcolumn <--> 100throw_184thcolumn : 0.7685
# 0throw_185thcolumn <--> 100throw_185thcolumn : 0.7795
# 0throw_186thcolumn <--> 100throw_186thcolumn : 0.7834
# 0throw_187thcolumn <--> 100throw_187thcolumn : 0.7486
# 0throw_188thcolumn <--> 0throw_191thcolumn : 0.7285
# 0throw_188thcolumn <--> 100throw_188thcolumn : 0.7792
# 0throw_189thcolumn <--> 100throw_189thcolumn : 0.7845
# 0throw_190thcolumn <--> 100throw_190thcolumn : 0.7549
# 0throw_191thcolumn <--> 100throw_191thcolumn : 0.7635
# 0throw_192thcolumn <--> 100throw_192thcolumn : 0.7769
# 0throw_193thcolumn <--> 100throw_193thcolumn : 0.8250
# 0throw_194thcolumn <--> 100throw_194thcolumn : 0.8055
# 0throw_195thcolumn <--> 100throw_195thcolumn : 0.7817
# 0throw_196thcolumn <--> 100throw_196thcolumn : 0.7684
# 0throw_197thcolumn <--> 100throw_197thcolumn : 0.8019
# 0throw_198thcolumn <--> 6throw_198thcolumn : 0.7004
# 0throw_198thcolumn <--> 100throw_198thcolumn : 0.8246
# 0throw_199thcolumn <--> 100throw_199thcolumn : 0.8037
# 1throw_5thcolumn <--> 1throw_11thcolumn : 0.7375
# 1throw_5thcolumn <--> 1throw_105thcolumn : 0.7787
# 1throw_7thcolumn <--> 1throw_9thcolumn : 0.8101
# 1throw_7thcolumn <--> 1throw_11thcolumn : 0.7182
# 1throw_7thcolumn <--> 1throw_106thcolumn : 0.8121
# 1throw_7thcolumn <--> 1throw_108thcolumn : 0.7552
# 1throw_7thcolumn <--> 1throw_109thcolumn : 0.7119
# 1throw_8thcolumn <--> 1throw_107thcolumn : 0.7499
# 1throw_9thcolumn <--> 1throw_11thcolumn : 0.7551
# 1throw_9thcolumn <--> 1throw_106thcolumn : 0.7256
# 1throw_9thcolumn <--> 1throw_108thcolumn : 0.8806
# 1throw_9thcolumn <--> 1throw_109thcolumn : 0.7922
# 1throw_9thcolumn <--> 1throw_110thcolumn : 0.7328
# 1throw_10thcolumn <--> 1throw_110thcolumn : 0.8002
# 1throw_10thcolumn <--> 10throw_103thcolumn : 0.7095
# 1throw_11thcolumn <--> 1throw_105thcolumn : 0.7723
# 1throw_11thcolumn <--> 1throw_108thcolumn : 0.7365
# 1throw_11thcolumn <--> 1throw_110thcolumn : 0.7521
# 1throw_11thcolumn <--> 1throw_111thcolumn : 0.7536
# 1throw_12thcolumn <--> 1throw_114thcolumn : 0.7036
# 1throw_14thcolumn <--> 14throw_103thcolumn : 0.7076
# 1throw_15thcolumn <--> 15throw_103thcolumn : 0.7078
# 1throw_17thcolumn <--> 17throw_103thcolumn : 0.7079
# 1throw_18thcolumn <--> 1throw_121thcolumn : 0.7916
# 1throw_19thcolumn <--> 1throw_122thcolumn : 0.7455
# 1throw_19thcolumn <--> 19throw_103thcolumn : 0.7179
# 1throw_26thcolumn <--> 1throw_129thcolumn : 0.8769
# 1throw_27thcolumn <--> 27throw_103thcolumn : 0.7084
# 1throw_30thcolumn <--> 30throw_103thcolumn : 0.7138
# 1throw_32thcolumn <--> 32throw_103thcolumn : 0.7158
# 1throw_34thcolumn <--> 1throw_35thcolumn : 0.7629
# 1throw_36thcolumn <--> 36throw_103thcolumn : 0.7140
# 1throw_37thcolumn <--> 1throw_139thcolumn : 0.7095
# 1throw_44thcolumn <--> 1throw_146thcolumn : 0.7942
# 1throw_44thcolumn <--> 44throw_103thcolumn : 0.7138
# 1throw_47thcolumn <--> 47throw_103thcolumn : 0.7098
# 1throw_49thcolumn <--> 1throw_155thcolumn : 0.7752
# 1throw_49thcolumn <--> 49throw_103thcolumn : 0.7347
# 1throw_51thcolumn <--> 51throw_103thcolumn : 0.7061
# 1throw_52thcolumn <--> 52throw_103thcolumn : 0.7092
# 1throw_53thcolumn <--> 53throw_103thcolumn : 0.7002
# 1throw_56thcolumn <--> 56throw_103thcolumn : 0.7229
# 1throw_65thcolumn <--> 65throw_103thcolumn : 0.7073
# 1throw_69thcolumn <--> 69throw_103thcolumn : 0.7027
# 1throw_70thcolumn <--> 70throw_103thcolumn : 0.7119
# 1throw_71thcolumn <--> 1throw_180thcolumn : 0.7746
# 1throw_71thcolumn <--> 71throw_103thcolumn : 0.7069
# 1throw_72thcolumn <--> 1throw_138thcolumn : 0.7235
# 1throw_73thcolumn <--> 1throw_182thcolumn : 0.7666
# 1throw_76thcolumn <--> 1throw_185thcolumn : 0.7904
# 1throw_79thcolumn <--> 1throw_158thcolumn : 0.7497
# 1throw_80thcolumn <--> 1throw_159thcolumn : 0.7018
# 1throw_80thcolumn <--> 80throw_103thcolumn : 0.7448
# 1throw_81thcolumn <--> 1throw_186thcolumn : 0.8383
# 1throw_87thcolumn <--> 1throw_88thcolumn : 0.7324
# 1throw_87thcolumn <--> 1throw_188thcolumn : 0.7646
# 1throw_95thcolumn <--> 95throw_103thcolumn : 0.7262
# 1throw_96thcolumn <--> 1throw_194thcolumn : 0.8406
# 1throw_96thcolumn <--> 96throw_103thcolumn : 0.7021
# 1throw_104thcolumn <--> 103throw_104thcolumn : 0.7038
# 1throw_106thcolumn <--> 1throw_108thcolumn : 0.7788
# 1throw_106thcolumn <--> 1throw_109thcolumn : 0.7274
# 1throw_106thcolumn <--> 1throw_110thcolumn : 0.7182
# 1throw_107thcolumn <--> 1throw_109thcolumn : 0.7729
# 1throw_108thcolumn <--> 1throw_109thcolumn : 0.7248
# 1throw_109thcolumn <--> 1throw_110thcolumn : 0.7585
# 1throw_110thcolumn <--> 1throw_111thcolumn : 0.7429
# 1throw_110thcolumn <--> 103throw_110thcolumn : 0.7263
# 1throw_111thcolumn <--> 103throw_111thcolumn : 0.7275
# 1throw_116thcolumn <--> 103throw_116thcolumn : 0.7309
# 1throw_117thcolumn <--> 103throw_117thcolumn : 0.7171
# 1throw_118thcolumn <--> 103throw_118thcolumn : 0.7047
# 1throw_122thcolumn <--> 103throw_122thcolumn : 0.7100
# 1throw_126thcolumn <--> 103throw_126thcolumn : 0.7055
# 1throw_131thcolumn <--> 103throw_131thcolumn : 0.7087
# 1throw_133thcolumn <--> 103throw_133thcolumn : 0.7153
# 1throw_134thcolumn <--> 1throw_165thcolumn : 0.7008
# 1throw_134thcolumn <--> 103throw_134thcolumn : 0.7316
# 1throw_135thcolumn <--> 103throw_135thcolumn : 0.7003
# 1throw_140thcolumn <--> 103throw_140thcolumn : 0.7218
# 1throw_142thcolumn <--> 103throw_142thcolumn : 0.7034
# 1throw_143thcolumn <--> 103throw_143thcolumn : 0.7005
# 1throw_147thcolumn <--> 103throw_147thcolumn : 0.7026
# 1throw_149thcolumn <--> 103throw_149thcolumn : 0.7082
# 1throw_151thcolumn <--> 103throw_151thcolumn : 0.7282
# 1throw_152thcolumn <--> 103throw_152thcolumn : 0.7209
# 1throw_155thcolumn <--> 103throw_155thcolumn : 0.7147
# 1throw_156thcolumn <--> 103throw_156thcolumn : 0.7050
# 1throw_159thcolumn <--> 103throw_159thcolumn : 0.7406
# 1throw_165thcolumn <--> 103throw_165thcolumn : 0.7018
# 1throw_167thcolumn <--> 103throw_167thcolumn : 0.7082
# 1throw_168thcolumn <--> 103throw_168thcolumn : 0.7245
# 1throw_169thcolumn <--> 103throw_169thcolumn : 0.7080
# 1throw_176thcolumn <--> 103throw_176thcolumn : 0.7021
# 1throw_177thcolumn <--> 103throw_177thcolumn : 0.7141
# 1throw_180thcolumn <--> 103throw_180thcolumn : 0.7089
# 2throw_4thcolumn <--> 2throw_104thcolumn : 0.7212
# 2throw_4thcolumn <--> 4throw_102thcolumn : 0.7167
# 2throw_5thcolumn <--> 2throw_105thcolumn : 0.7148
# 2throw_6thcolumn <--> 2throw_7thcolumn : 0.7239
# 2throw_6thcolumn <--> 2throw_100thcolumn : 0.7120
# 2throw_6thcolumn <--> 2throw_106thcolumn : 0.7212
# 2throw_6thcolumn <--> 2throw_195thcolumn : 0.7150
# 2throw_7thcolumn <--> 2throw_9thcolumn : 0.7289
# 2throw_7thcolumn <--> 2throw_106thcolumn : 0.7886
# 2throw_8thcolumn <--> 2throw_107thcolumn : 0.7732
# 2throw_9thcolumn <--> 2throw_11thcolumn : 0.7090
# 2throw_9thcolumn <--> 2throw_108thcolumn : 0.8345
# 2throw_9thcolumn <--> 2throw_109thcolumn : 0.7919
# 2throw_9thcolumn <--> 2throw_110thcolumn : 0.7488
# 2throw_10thcolumn <--> 2throw_110thcolumn : 0.8082
# 2throw_11thcolumn <--> 2throw_110thcolumn : 0.7572
# 2throw_11thcolumn <--> 2throw_111thcolumn : 0.7262
# 2throw_12thcolumn <--> 2throw_114thcolumn : 0.7485
# 2throw_14thcolumn <--> 2throw_15thcolumn : 0.7890
# 2throw_14thcolumn <--> 14throw_102thcolumn : 0.7035
# 2throw_15thcolumn <--> 15throw_102thcolumn : 0.7127
# 2throw_16thcolumn <--> 16throw_102thcolumn : 0.7234
# 2throw_17thcolumn <--> 2throw_119thcolumn : 0.7178
# 2throw_17thcolumn <--> 17throw_102thcolumn : 0.7114
# 2throw_18thcolumn <--> 2throw_120thcolumn : 0.7314
# 2throw_18thcolumn <--> 2throw_121thcolumn : 0.8279
# 2throw_18thcolumn <--> 18throw_102thcolumn : 0.7265
# 2throw_19thcolumn <--> 2throw_122thcolumn : 0.8005
# 2throw_19thcolumn <--> 19throw_102thcolumn : 0.7310
# 2throw_20thcolumn <--> 20throw_102thcolumn : 0.7201
# 2throw_22thcolumn <--> 2throw_125thcolumn : 0.7124
# 2throw_23thcolumn <--> 2throw_25thcolumn : 0.7179
# 2throw_23thcolumn <--> 2throw_127thcolumn : 0.7492
# 2throw_23thcolumn <--> 2throw_128thcolumn : 0.7221
# 2throw_23thcolumn <--> 23throw_102thcolumn : 0.7145
# 2throw_24thcolumn <--> 24throw_102thcolumn : 0.7168
# 2throw_26thcolumn <--> 2throw_129thcolumn : 0.9110
# 2throw_26thcolumn <--> 26throw_102thcolumn : 0.7077
# 2throw_27thcolumn <--> 2throw_113thcolumn : 0.7132
# 2throw_28thcolumn <--> 28throw_102thcolumn : 0.7366
# 2throw_29thcolumn <--> 29throw_102thcolumn : 0.7549
# 2throw_29thcolumn <--> 29throw_108thcolumn : 0.7271
# 2throw_30thcolumn <--> 30throw_102thcolumn : 0.7471
# 2throw_31thcolumn <--> 2throw_132thcolumn : 0.7239
# 2throw_31thcolumn <--> 31throw_102thcolumn : 0.7629
# 2throw_31thcolumn <--> 31throw_108thcolumn : 0.7049
# 2throw_32thcolumn <--> 2throw_133thcolumn : 0.7017
# 2throw_32thcolumn <--> 32throw_102thcolumn : 0.7535
# 2throw_33thcolumn <--> 33throw_102thcolumn : 0.7335
# 2throw_33thcolumn <--> 33throw_108thcolumn : 0.7130
# 2throw_34thcolumn <--> 2throw_35thcolumn : 0.7577
# 2throw_36thcolumn <--> 36throw_102thcolumn : 0.7272
# 2throw_37thcolumn <--> 2throw_139thcolumn : 0.7349
# 2throw_38thcolumn <--> 38throw_102thcolumn : 0.7397
# 2throw_39thcolumn <--> 2throw_141thcolumn : 0.7781
# 2throw_43thcolumn <--> 2throw_148thcolumn : 0.7475
# 2throw_44thcolumn <--> 2throw_146thcolumn : 0.8344
# 2throw_44thcolumn <--> 44throw_102thcolumn : 0.7214
# 2throw_45thcolumn <--> 45throw_102thcolumn : 0.7123
# 2throw_46thcolumn <--> 46throw_102thcolumn : 0.7338
# 2throw_48thcolumn <--> 2throw_154thcolumn : 0.7315
# 2throw_49thcolumn <--> 2throw_155thcolumn : 0.7693
# 2throw_50thcolumn <--> 50throw_102thcolumn : 0.7180
# 2throw_56thcolumn <--> 56throw_102thcolumn : 0.7341
# 2throw_57thcolumn <--> 57throw_102thcolumn : 0.7071
# 2throw_59thcolumn <--> 59throw_102thcolumn : 0.7348
# 2throw_71thcolumn <--> 2throw_180thcolumn : 0.7588
# 2throw_72thcolumn <--> 2throw_138thcolumn : 0.7059
# 2throw_73thcolumn <--> 2throw_182thcolumn : 0.7983
# 2throw_73thcolumn <--> 73throw_102thcolumn : 0.7132
# 2throw_74thcolumn <--> 74throw_102thcolumn : 0.7154
# 2throw_76thcolumn <--> 2throw_185thcolumn : 0.8046
# 2throw_76thcolumn <--> 76throw_102thcolumn : 0.7004
# 2throw_77thcolumn <--> 77throw_102thcolumn : 0.7072
# 2throw_79thcolumn <--> 2throw_158thcolumn : 0.7945
# 2throw_79thcolumn <--> 79throw_102thcolumn : 0.7135
# 2throw_80thcolumn <--> 80throw_102thcolumn : 0.7126
# 2throw_81thcolumn <--> 2throw_186thcolumn : 0.8049
# 2throw_83thcolumn <--> 83throw_102thcolumn : 0.7160
# 2throw_87thcolumn <--> 2throw_88thcolumn : 0.7510
# 2throw_87thcolumn <--> 2throw_188thcolumn : 0.7730
# 2throw_87thcolumn <--> 87throw_102thcolumn : 0.7018
# 2throw_88thcolumn <--> 88throw_102thcolumn : 0.7133
# 2throw_90thcolumn <--> 90throw_102thcolumn : 0.7063
# 2throw_92thcolumn <--> 92throw_102thcolumn : 0.7185
# 2throw_95thcolumn <--> 95throw_102thcolumn : 0.7517
# 2throw_96thcolumn <--> 2throw_194thcolumn : 0.8145
# 2throw_101thcolumn <--> 101throw_102thcolumn : 0.7494
# 2throw_104thcolumn <--> 102throw_104thcolumn : 0.7066
# 2throw_106thcolumn <--> 2throw_107thcolumn : 0.7362
# 2throw_106thcolumn <--> 2throw_108thcolumn : 0.7266
# 2throw_106thcolumn <--> 2throw_109thcolumn : 0.7255
# 2throw_106thcolumn <--> 2throw_110thcolumn : 0.7174
# 2throw_107thcolumn <--> 2throw_109thcolumn : 0.8253
# 2throw_107thcolumn <--> 2throw_110thcolumn : 0.7064
# 2throw_108thcolumn <--> 2throw_109thcolumn : 0.7301
# 2throw_108thcolumn <--> 2throw_110thcolumn : 0.7147
# 2throw_109thcolumn <--> 2throw_110thcolumn : 0.7507
# 2throw_110thcolumn <--> 2throw_111thcolumn : 0.7329
# 2throw_111thcolumn <--> 102throw_111thcolumn : 0.7028
# 2throw_115thcolumn <--> 2throw_117thcolumn : 0.7277
# 2throw_115thcolumn <--> 102throw_115thcolumn : 0.7145
# 2throw_116thcolumn <--> 102throw_116thcolumn : 0.7365
# 2throw_118thcolumn <--> 102throw_118thcolumn : 0.7025
# 2throw_119thcolumn <--> 102throw_119thcolumn : 0.7267
# 2throw_120thcolumn <--> 2throw_121thcolumn : 0.7020
# 2throw_120thcolumn <--> 102throw_120thcolumn : 0.7293
# 2throw_121thcolumn <--> 102throw_121thcolumn : 0.7205
# 2throw_122thcolumn <--> 102throw_122thcolumn : 0.7390
# 2throw_127thcolumn <--> 102throw_127thcolumn : 0.7184
# 2throw_129thcolumn <--> 102throw_129thcolumn : 0.7197
# 2throw_130thcolumn <--> 102throw_130thcolumn : 0.7549
# 2throw_131thcolumn <--> 102throw_131thcolumn : 0.7812
# 2throw_131thcolumn <--> 108throw_131thcolumn : 0.7149
# 2throw_132thcolumn <--> 102throw_132thcolumn : 0.7574
# 2throw_132thcolumn <--> 108throw_132thcolumn : 0.7138
# 2throw_133thcolumn <--> 102throw_133thcolumn : 0.7373
# 2throw_134thcolumn <--> 102throw_134thcolumn : 0.7090
# 2throw_135thcolumn <--> 102throw_135thcolumn : 0.7562
# 2throw_135thcolumn <--> 108throw_135thcolumn : 0.7169
# 2throw_139thcolumn <--> 102throw_139thcolumn : 0.7252
# 2throw_140thcolumn <--> 102throw_140thcolumn : 0.7218
# 2throw_141thcolumn <--> 102throw_141thcolumn : 0.7169
# 2throw_142thcolumn <--> 102throw_142thcolumn : 0.7074
# 2throw_145thcolumn <--> 2throw_146thcolumn : 0.7142
# 2throw_146thcolumn <--> 102throw_146thcolumn : 0.7054
# 2throw_148thcolumn <--> 102throw_148thcolumn : 0.7238
# 2throw_149thcolumn <--> 102throw_149thcolumn : 0.7347
# 2throw_150thcolumn <--> 102throw_150thcolumn : 0.7353
# 2throw_152thcolumn <--> 102throw_152thcolumn : 0.7089
# 2throw_158thcolumn <--> 102throw_158thcolumn : 0.7042
# 2throw_159thcolumn <--> 102throw_159thcolumn : 0.7067
# 2throw_161thcolumn <--> 102throw_161thcolumn : 0.7058
# 2throw_163thcolumn <--> 102throw_163thcolumn : 0.7087
# 2throw_164thcolumn <--> 102throw_164thcolumn : 0.7150
# 2throw_168thcolumn <--> 102throw_168thcolumn : 0.7194
# 2throw_170thcolumn <--> 102throw_170thcolumn : 0.7297
# 2throw_172thcolumn <--> 102throw_172thcolumn : 0.7205
# 2throw_182thcolumn <--> 102throw_182thcolumn : 0.7015
# 2throw_183thcolumn <--> 102throw_183thcolumn : 0.7124
# 2throw_188thcolumn <--> 2throw_191thcolumn : 0.7477
# 2throw_188thcolumn <--> 102throw_188thcolumn : 0.7178
# 2throw_191thcolumn <--> 102throw_191thcolumn : 0.7192
# 2throw_193thcolumn <--> 102throw_193thcolumn : 0.7303
# 2throw_198thcolumn <--> 102throw_198thcolumn : 0.7462
# 2throw_199thcolumn <--> 102throw_199thcolumn : 0.7170
# 3throw_5thcolumn <--> 3throw_105thcolumn : 0.7108
# 3throw_6thcolumn <--> 3throw_7thcolumn : 0.7613
# 3throw_6thcolumn <--> 3throw_100thcolumn : 0.7437
# 3throw_6thcolumn <--> 3throw_106thcolumn : 0.7542
# 3throw_6thcolumn <--> 3throw_107thcolumn : 0.7018
# 3throw_6thcolumn <--> 3throw_195thcolumn : 0.7290
# 3throw_7thcolumn <--> 3throw_9thcolumn : 0.8177
# 3throw_7thcolumn <--> 3throw_106thcolumn : 0.8416
# 3throw_7thcolumn <--> 3throw_107thcolumn : 0.7423
# 3throw_7thcolumn <--> 3throw_108thcolumn : 0.7638
# 3throw_7thcolumn <--> 3throw_109thcolumn : 0.7513
# 3throw_7thcolumn <--> 3throw_110thcolumn : 0.7076
# 3throw_8thcolumn <--> 3throw_107thcolumn : 0.7960
# 3throw_8thcolumn <--> 3throw_109thcolumn : 0.7205
# 3throw_9thcolumn <--> 3throw_10thcolumn : 0.7002
# 3throw_9thcolumn <--> 3throw_11thcolumn : 0.7392
# 3throw_9thcolumn <--> 3throw_106thcolumn : 0.7288
# 3throw_9thcolumn <--> 3throw_107thcolumn : 0.7483
# 3throw_9thcolumn <--> 3throw_108thcolumn : 0.8776
# 3throw_9thcolumn <--> 3throw_109thcolumn : 0.8528
# 3throw_9thcolumn <--> 3throw_110thcolumn : 0.7839
# 3throw_10thcolumn <--> 3throw_109thcolumn : 0.7248
# 3throw_10thcolumn <--> 3throw_110thcolumn : 0.8262
# 3throw_11thcolumn <--> 3throw_105thcolumn : 0.7072
# 3throw_11thcolumn <--> 3throw_108thcolumn : 0.7229
# 3throw_11thcolumn <--> 3throw_110thcolumn : 0.7821
# 3throw_11thcolumn <--> 3throw_111thcolumn : 0.7424
# 3throw_12thcolumn <--> 3throw_114thcolumn : 0.7465
# 3throw_14thcolumn <--> 3throw_15thcolumn : 0.7547
# 3throw_17thcolumn <--> 3throw_119thcolumn : 0.7031
# 3throw_18thcolumn <--> 3throw_120thcolumn : 0.7043
# 3throw_18thcolumn <--> 3throw_121thcolumn : 0.8210
# 3throw_19thcolumn <--> 3throw_122thcolumn : 0.7875
# 3throw_21thcolumn <--> 3throw_123thcolumn : 0.7288
# 3throw_23thcolumn <--> 3throw_127thcolumn : 0.7594
# 3throw_26thcolumn <--> 3throw_129thcolumn : 0.8998
# 3throw_27thcolumn <--> 3throw_113thcolumn : 0.7299
# 3throw_34thcolumn <--> 3throw_35thcolumn : 0.7592
# 3throw_37thcolumn <--> 3throw_139thcolumn : 0.7073
# 3throw_39thcolumn <--> 3throw_141thcolumn : 0.7509
# 3throw_43thcolumn <--> 3throw_148thcolumn : 0.7018
# 3throw_44thcolumn <--> 3throw_146thcolumn : 0.8128
# 3throw_48thcolumn <--> 3throw_154thcolumn : 0.7370
# 3throw_49thcolumn <--> 3throw_155thcolumn : 0.7711
# 3throw_71thcolumn <--> 3throw_180thcolumn : 0.7841
# 3throw_72thcolumn <--> 3throw_138thcolumn : 0.7075
# 3throw_73thcolumn <--> 3throw_182thcolumn : 0.7972
# 3throw_76thcolumn <--> 3throw_185thcolumn : 0.8040
# 3throw_79thcolumn <--> 3throw_158thcolumn : 0.7917
# 3throw_81thcolumn <--> 3throw_186thcolumn : 0.8167
# 3throw_82thcolumn <--> 3throw_190thcolumn : 0.7076
# 3throw_87thcolumn <--> 3throw_88thcolumn : 0.7497
# 3throw_87thcolumn <--> 3throw_188thcolumn : 0.7477
# 3throw_96thcolumn <--> 3throw_194thcolumn : 0.8547
# 3throw_97thcolumn <--> 3throw_195thcolumn : 0.7035
# 3throw_100thcolumn <--> 3throw_106thcolumn : 0.7115
# 3throw_106thcolumn <--> 3throw_107thcolumn : 0.7646
# 3throw_106thcolumn <--> 3throw_108thcolumn : 0.8094
# 3throw_106thcolumn <--> 3throw_109thcolumn : 0.7687
# 3throw_106thcolumn <--> 3throw_110thcolumn : 0.7290
# 3throw_107thcolumn <--> 3throw_108thcolumn : 0.7069
# 3throw_107thcolumn <--> 3throw_109thcolumn : 0.8392
# 3throw_107thcolumn <--> 3throw_110thcolumn : 0.7166
# 3throw_108thcolumn <--> 3throw_109thcolumn : 0.7956
# 3throw_108thcolumn <--> 3throw_110thcolumn : 0.7554
# 3throw_109thcolumn <--> 3throw_110thcolumn : 0.7922
# 3throw_110thcolumn <--> 3throw_111thcolumn : 0.7279
# 3throw_112thcolumn <--> 3throw_137thcolumn : 0.7028
# 3throw_113thcolumn <--> 103throw_113thcolumn : 0.7015
# 3throw_115thcolumn <--> 3throw_117thcolumn : 0.7380
# 3throw_120thcolumn <--> 3throw_121thcolumn : 0.7030
# 3throw_145thcolumn <--> 3throw_146thcolumn : 0.7006
# 3throw_188thcolumn <--> 3throw_191thcolumn : 0.7064
# 4throw_6thcolumn <--> 4throw_195thcolumn : 0.7328
# 4throw_6thcolumn <--> 6throw_104thcolumn : 0.7369
# 4throw_7thcolumn <--> 4throw_9thcolumn : 0.8155
# 4throw_7thcolumn <--> 4throw_106thcolumn : 0.8483
# 4throw_7thcolumn <--> 4throw_107thcolumn : 0.7435
# 4throw_7thcolumn <--> 4throw_108thcolumn : 0.7713
# 4throw_7thcolumn <--> 4throw_109thcolumn : 0.7618
# 4throw_7thcolumn <--> 4throw_110thcolumn : 0.7033
# 4throw_7thcolumn <--> 7throw_104thcolumn : 0.7650
# 4throw_8thcolumn <--> 4throw_107thcolumn : 0.8050
# 4throw_8thcolumn <--> 4throw_109thcolumn : 0.7088
# 4throw_8thcolumn <--> 5throw_8thcolumn : 0.7213
# 4throw_8thcolumn <--> 8throw_104thcolumn : 0.7400
# 4throw_9thcolumn <--> 4throw_11thcolumn : 0.7545
# 4throw_9thcolumn <--> 4throw_106thcolumn : 0.7541
# 4throw_9thcolumn <--> 4throw_107thcolumn : 0.7616
# 4throw_9thcolumn <--> 4throw_108thcolumn : 0.8958
# 4throw_9thcolumn <--> 4throw_109thcolumn : 0.8401
# 4throw_9thcolumn <--> 4throw_110thcolumn : 0.7811
# 4throw_9thcolumn <--> 9throw_104thcolumn : 0.7499
# 4throw_10thcolumn <--> 4throw_109thcolumn : 0.7022
# 4throw_10thcolumn <--> 4throw_110thcolumn : 0.8121
# 4throw_10thcolumn <--> 10throw_104thcolumn : 0.7464
# 4throw_11thcolumn <--> 4throw_108thcolumn : 0.7252
# 4throw_11thcolumn <--> 4throw_110thcolumn : 0.7925
# 4throw_11thcolumn <--> 4throw_111thcolumn : 0.7393
# 4throw_11thcolumn <--> 11throw_104thcolumn : 0.7074
# 4throw_12thcolumn <--> 4throw_114thcolumn : 0.7410
# 4throw_13thcolumn <--> 5throw_13thcolumn : 0.7312
# 4throw_13thcolumn <--> 13throw_104thcolumn : 0.7290
# 4throw_14thcolumn <--> 4throw_15thcolumn : 0.7880
# 4throw_14thcolumn <--> 5throw_14thcolumn : 0.7270
# 4throw_14thcolumn <--> 14throw_104thcolumn : 0.7383
# 4throw_15thcolumn <--> 15throw_104thcolumn : 0.7331
# 4throw_16thcolumn <--> 5throw_16thcolumn : 0.7063
# 4throw_16thcolumn <--> 16throw_104thcolumn : 0.7417
# 4throw_17thcolumn <--> 17throw_104thcolumn : 0.7327
# 4throw_18thcolumn <--> 4throw_120thcolumn : 0.7044
# 4throw_18thcolumn <--> 4throw_121thcolumn : 0.8499
# 4throw_18thcolumn <--> 5throw_18thcolumn : 0.7298
# 4throw_18thcolumn <--> 18throw_104thcolumn : 0.7486
# 4throw_19thcolumn <--> 4throw_122thcolumn : 0.7946
# 4throw_19thcolumn <--> 5throw_19thcolumn : 0.7213
# 4throw_19thcolumn <--> 19throw_104thcolumn : 0.7470
# 4throw_20thcolumn <--> 5throw_20thcolumn : 0.7134
# 4throw_20thcolumn <--> 20throw_104thcolumn : 0.7022
# 4throw_21thcolumn <--> 5throw_21thcolumn : 0.7248
# 4throw_21thcolumn <--> 21throw_104thcolumn : 0.7367
# 4throw_22thcolumn <--> 5throw_22thcolumn : 0.7043
# 4throw_22thcolumn <--> 22throw_104thcolumn : 0.7028
# 4throw_23thcolumn <--> 4throw_127thcolumn : 0.7299
# 4throw_23thcolumn <--> 23throw_104thcolumn : 0.7081
# 4throw_24thcolumn <--> 5throw_24thcolumn : 0.7066
# 4throw_24thcolumn <--> 24throw_104thcolumn : 0.7061
# 4throw_25thcolumn <--> 25throw_104thcolumn : 0.7156
# 4throw_26thcolumn <--> 4throw_129thcolumn : 0.8840
# 4throw_26thcolumn <--> 26throw_104thcolumn : 0.7114
# 4throw_27thcolumn <--> 5throw_27thcolumn : 0.7209
# 4throw_27thcolumn <--> 27throw_104thcolumn : 0.7504
# 4throw_28thcolumn <--> 5throw_28thcolumn : 0.7030
# 4throw_28thcolumn <--> 28throw_104thcolumn : 0.7651
# 4throw_31thcolumn <--> 31throw_104thcolumn : 0.7626
# 4throw_32thcolumn <--> 32throw_104thcolumn : 0.7504
# 4throw_33thcolumn <--> 5throw_33thcolumn : 0.7622
# 4throw_33thcolumn <--> 33throw_104thcolumn : 0.8201
# 4throw_34thcolumn <--> 4throw_35thcolumn : 0.7697
# 4throw_34thcolumn <--> 34throw_104thcolumn : 0.7488
# 4throw_35thcolumn <--> 35throw_104thcolumn : 0.7546
# 4throw_36thcolumn <--> 5throw_36thcolumn : 0.7238
# 4throw_36thcolumn <--> 36throw_104thcolumn : 0.7907
# 4throw_37thcolumn <--> 37throw_104thcolumn : 0.7289
# 4throw_38thcolumn <--> 5throw_38thcolumn : 0.7410
# 4throw_38thcolumn <--> 38throw_104thcolumn : 0.7740
# 4throw_39thcolumn <--> 4throw_141thcolumn : 0.7478
# 4throw_39thcolumn <--> 5throw_39thcolumn : 0.7076
# 4throw_39thcolumn <--> 39throw_104thcolumn : 0.7184
# 4throw_42thcolumn <--> 42throw_104thcolumn : 0.7232
# 4throw_43thcolumn <--> 4throw_148thcolumn : 0.7373
# 4throw_44thcolumn <--> 4throw_146thcolumn : 0.7932
# 4throw_44thcolumn <--> 44throw_104thcolumn : 0.7159
# 4throw_45thcolumn <--> 45throw_104thcolumn : 0.7261
# 4throw_46thcolumn <--> 5throw_46thcolumn : 0.7138
# 4throw_46thcolumn <--> 46throw_104thcolumn : 0.7204
# 4throw_47thcolumn <--> 5throw_47thcolumn : 0.7014
# 4throw_47thcolumn <--> 47throw_104thcolumn : 0.7345
# 4throw_48thcolumn <--> 4throw_154thcolumn : 0.7099
# 4throw_48thcolumn <--> 5throw_48thcolumn : 0.7024
# 4throw_48thcolumn <--> 48throw_104thcolumn : 0.7189
# 4throw_49thcolumn <--> 4throw_155thcolumn : 0.7405
# 4throw_54thcolumn <--> 5throw_54thcolumn : 0.7051
# 4throw_56thcolumn <--> 5throw_56thcolumn : 0.7045
# 4throw_56thcolumn <--> 56throw_104thcolumn : 0.7444
# 4throw_57thcolumn <--> 5throw_57thcolumn : 0.7760
# 4throw_57thcolumn <--> 57throw_104thcolumn : 0.8069
# 4throw_58thcolumn <--> 58throw_104thcolumn : 0.7559
# 4throw_59thcolumn <--> 5throw_59thcolumn : 0.7233
# 4throw_59thcolumn <--> 59throw_104thcolumn : 0.8004
# 4throw_60thcolumn <--> 60throw_104thcolumn : 0.7184
# 4throw_61thcolumn <--> 61throw_104thcolumn : 0.7138
# 4throw_62thcolumn <--> 62throw_104thcolumn : 0.7011
# 4throw_63thcolumn <--> 63throw_104thcolumn : 0.7374
# 4throw_64thcolumn <--> 5throw_64thcolumn : 0.7219
# 4throw_64thcolumn <--> 64throw_104thcolumn : 0.7413
# 4throw_66thcolumn <--> 66throw_104thcolumn : 0.7256
# 4throw_67thcolumn <--> 5throw_67thcolumn : 0.7262
# 4throw_67thcolumn <--> 67throw_104thcolumn : 0.7268
# 4throw_69thcolumn <--> 69throw_104thcolumn : 0.7146
# 4throw_70thcolumn <--> 70throw_104thcolumn : 0.7076
# 4throw_71thcolumn <--> 4throw_180thcolumn : 0.7451
# 4throw_71thcolumn <--> 5throw_71thcolumn : 0.7054
# 4throw_71thcolumn <--> 71throw_104thcolumn : 0.7584
# 4throw_72thcolumn <--> 4throw_138thcolumn : 0.7449
# 4throw_72thcolumn <--> 72throw_104thcolumn : 0.7366
# 4throw_73thcolumn <--> 4throw_182thcolumn : 0.7729
# 4throw_74thcolumn <--> 5throw_74thcolumn : 0.7357
# 4throw_74thcolumn <--> 74throw_104thcolumn : 0.7164
# 4throw_75thcolumn <--> 75throw_104thcolumn : 0.7125
# 4throw_76thcolumn <--> 4throw_185thcolumn : 0.8009
# 4throw_76thcolumn <--> 5throw_76thcolumn : 0.7182
# 4throw_76thcolumn <--> 76throw_104thcolumn : 0.7391
# 4throw_77thcolumn <--> 5throw_77thcolumn : 0.7059
# 4throw_77thcolumn <--> 77throw_104thcolumn : 0.7158
# 4throw_78thcolumn <--> 4throw_181thcolumn : 0.7128
# 4throw_78thcolumn <--> 5throw_78thcolumn : 0.7042
# 4throw_78thcolumn <--> 78throw_104thcolumn : 0.7343
# 4throw_79thcolumn <--> 4throw_158thcolumn : 0.7841
# 4throw_80thcolumn <--> 5throw_80thcolumn : 0.7149
# 4throw_80thcolumn <--> 80throw_104thcolumn : 0.7314
# 4throw_81thcolumn <--> 4throw_186thcolumn : 0.8137
# 4throw_81thcolumn <--> 81throw_104thcolumn : 0.7157
# 4throw_83thcolumn <--> 5throw_83thcolumn : 0.7142
# 4throw_83thcolumn <--> 83throw_104thcolumn : 0.7013
# 4throw_85thcolumn <--> 5throw_85thcolumn : 0.7067
# 4throw_86thcolumn <--> 5throw_86thcolumn : 0.7054
# 4throw_87thcolumn <--> 4throw_88thcolumn : 0.7262
# 4throw_87thcolumn <--> 4throw_188thcolumn : 0.7549
# 4throw_87thcolumn <--> 87throw_104thcolumn : 0.7033
# 4throw_88thcolumn <--> 88throw_104thcolumn : 0.7068
# 4throw_90thcolumn <--> 5throw_90thcolumn : 0.7054
# 4throw_90thcolumn <--> 90throw_104thcolumn : 0.7034
# 4throw_92thcolumn <--> 92throw_104thcolumn : 0.7065
# 4throw_93thcolumn <--> 4throw_94thcolumn : 0.7014
# 4throw_93thcolumn <--> 93throw_104thcolumn : 0.7001
# 4throw_95thcolumn <--> 5throw_95thcolumn : 0.7358
# 4throw_95thcolumn <--> 95throw_104thcolumn : 0.7697
# 4throw_96thcolumn <--> 4throw_194thcolumn : 0.8430
# 4throw_96thcolumn <--> 96throw_104thcolumn : 0.7292
# 4throw_97thcolumn <--> 97throw_104thcolumn : 0.7057
# 4throw_98thcolumn <--> 5throw_98thcolumn : 0.7143
# 4throw_98thcolumn <--> 98throw_104thcolumn : 0.7218
# 4throw_99thcolumn <--> 5throw_99thcolumn : 0.7091
# 4throw_99thcolumn <--> 99throw_104thcolumn : 0.7095
# 4throw_106thcolumn <--> 4throw_107thcolumn : 0.7543
# 4throw_106thcolumn <--> 4throw_108thcolumn : 0.8070
# 4throw_106thcolumn <--> 4throw_109thcolumn : 0.7695
# 4throw_106thcolumn <--> 4throw_110thcolumn : 0.7137
# 4throw_106thcolumn <--> 104throw_106thcolumn : 0.7600
# 4throw_107thcolumn <--> 4throw_109thcolumn : 0.8425
# 4throw_107thcolumn <--> 4throw_110thcolumn : 0.7266
# 4throw_107thcolumn <--> 5throw_107thcolumn : 0.7099
# 4throw_107thcolumn <--> 104throw_107thcolumn : 0.7568
# 4throw_108thcolumn <--> 4throw_109thcolumn : 0.7701
# 4throw_108thcolumn <--> 4throw_110thcolumn : 0.7374
# 4throw_108thcolumn <--> 104throw_108thcolumn : 0.7470
# 4throw_109thcolumn <--> 4throw_110thcolumn : 0.7884
# 4throw_109thcolumn <--> 104throw_109thcolumn : 0.7303
# 4throw_110thcolumn <--> 104throw_110thcolumn : 0.7298
# 4throw_111thcolumn <--> 104throw_111thcolumn : 0.7278
# 4throw_112thcolumn <--> 104throw_112thcolumn : 0.7163
# 4throw_113thcolumn <--> 5throw_113thcolumn : 0.7280
# 4throw_113thcolumn <--> 104throw_113thcolumn : 0.7475
# 4throw_114thcolumn <--> 5throw_114thcolumn : 0.7111
# 4throw_114thcolumn <--> 104throw_114thcolumn : 0.7376
# 4throw_115thcolumn <--> 4throw_117thcolumn : 0.7335
# 4throw_115thcolumn <--> 5throw_115thcolumn : 0.7130
# 4throw_115thcolumn <--> 104throw_115thcolumn : 0.7380
# 4throw_116thcolumn <--> 5throw_116thcolumn : 0.7249
# 4throw_116thcolumn <--> 104throw_116thcolumn : 0.7671
# 4throw_117thcolumn <--> 104throw_117thcolumn : 0.7206
# 4throw_118thcolumn <--> 104throw_118thcolumn : 0.7214
# 4throw_119thcolumn <--> 5throw_119thcolumn : 0.7270
# 4throw_119thcolumn <--> 104throw_119thcolumn : 0.7483
# 4throw_120thcolumn <--> 5throw_120thcolumn : 0.7167
# 4throw_120thcolumn <--> 104throw_120thcolumn : 0.7401
# 4throw_121thcolumn <--> 5throw_121thcolumn : 0.7208
# 4throw_121thcolumn <--> 104throw_121thcolumn : 0.7581
# 4throw_122thcolumn <--> 5throw_122thcolumn : 0.7030
# 4throw_122thcolumn <--> 104throw_122thcolumn : 0.7463
# 4throw_123thcolumn <--> 5throw_123thcolumn : 0.7184
# 4throw_123thcolumn <--> 104throw_123thcolumn : 0.7082
# 4throw_124thcolumn <--> 5throw_124thcolumn : 0.7112
# 4throw_124thcolumn <--> 104throw_124thcolumn : 0.7066
# 4throw_126thcolumn <--> 5throw_126thcolumn : 0.7152
# 4throw_126thcolumn <--> 104throw_126thcolumn : 0.7313
# 4throw_127thcolumn <--> 5throw_127thcolumn : 0.7050
# 4throw_127thcolumn <--> 104throw_127thcolumn : 0.7104
# 4throw_128thcolumn <--> 5throw_128thcolumn : 0.7005
# 4throw_128thcolumn <--> 104throw_128thcolumn : 0.7167
# 4throw_129thcolumn <--> 104throw_129thcolumn : 0.7063
# 4throw_131thcolumn <--> 5throw_131thcolumn : 0.7182
# 4throw_133thcolumn <--> 104throw_133thcolumn : 0.7581
# 4throw_134thcolumn <--> 5throw_134thcolumn : 0.7113
# 4throw_134thcolumn <--> 104throw_134thcolumn : 0.7700
# 4throw_135thcolumn <--> 104throw_135thcolumn : 0.7226
# 4throw_137thcolumn <--> 104throw_137thcolumn : 0.7564
# 4throw_138thcolumn <--> 104throw_138thcolumn : 0.7153
# 4throw_139thcolumn <--> 5throw_139thcolumn : 0.7137
# 4throw_139thcolumn <--> 104throw_139thcolumn : 0.7480
# 4throw_140thcolumn <--> 5throw_140thcolumn : 0.7883
# 4throw_140thcolumn <--> 104throw_140thcolumn : 0.7842
# 4throw_141thcolumn <--> 5throw_141thcolumn : 0.7117
# 4throw_142thcolumn <--> 5throw_142thcolumn : 0.7832
# 4throw_142thcolumn <--> 104throw_142thcolumn : 0.8066
# 4throw_144thcolumn <--> 5throw_144thcolumn : 0.7079
# 4throw_144thcolumn <--> 104throw_144thcolumn : 0.7082
# 4throw_145thcolumn <--> 5throw_145thcolumn : 0.7115
# 4throw_145thcolumn <--> 104throw_145thcolumn : 0.7283
# 4throw_146thcolumn <--> 5throw_146thcolumn : 0.7013
# 4throw_146thcolumn <--> 104throw_146thcolumn : 0.7098
# 4throw_147thcolumn <--> 104throw_147thcolumn : 0.7001
# 4throw_148thcolumn <--> 104throw_148thcolumn : 0.7021
# 4throw_149thcolumn <--> 5throw_149thcolumn : 0.7419
# 4throw_149thcolumn <--> 104throw_149thcolumn : 0.7395
# 4throw_150thcolumn <--> 5throw_150thcolumn : 0.7232
# 4throw_151thcolumn <--> 5throw_151thcolumn : 0.7169
# 4throw_151thcolumn <--> 104throw_151thcolumn : 0.7457
# 4throw_152thcolumn <--> 5throw_152thcolumn : 0.7124
# 4throw_152thcolumn <--> 104throw_152thcolumn : 0.7413
# 4throw_153thcolumn <--> 104throw_153thcolumn : 0.7092
# 4throw_154thcolumn <--> 5throw_154thcolumn : 0.7228
# 4throw_154thcolumn <--> 104throw_154thcolumn : 0.7479
# 4throw_155thcolumn <--> 5throw_155thcolumn : 0.7004
# 4throw_155thcolumn <--> 104throw_155thcolumn : 0.7222
# 4throw_158thcolumn <--> 5throw_158thcolumn : 0.7033
# 4throw_158thcolumn <--> 104throw_158thcolumn : 0.7060
# 4throw_159thcolumn <--> 5throw_159thcolumn : 0.7044
# 4throw_159thcolumn <--> 104throw_159thcolumn : 0.7158
# 4throw_163thcolumn <--> 5throw_163thcolumn : 0.7435
# 4throw_163thcolumn <--> 104throw_163thcolumn : 0.7818
# 4throw_164thcolumn <--> 5throw_164thcolumn : 0.7697
# 4throw_164thcolumn <--> 104throw_164thcolumn : 0.7877
# 4throw_165thcolumn <--> 104throw_165thcolumn : 0.7405
# 4throw_166thcolumn <--> 5throw_166thcolumn : 0.7088
# 4throw_166thcolumn <--> 104throw_166thcolumn : 0.7415
# 4throw_167thcolumn <--> 5throw_167thcolumn : 0.7151
# 4throw_167thcolumn <--> 104throw_167thcolumn : 0.7539
# 4throw_168thcolumn <--> 5throw_168thcolumn : 0.7151
# 4throw_168thcolumn <--> 104throw_168thcolumn : 0.7532
# 4throw_169thcolumn <--> 104throw_169thcolumn : 0.7003
# 4throw_170thcolumn <--> 104throw_170thcolumn : 0.7112
# 4throw_171thcolumn <--> 104throw_171thcolumn : 0.7369
# 4throw_172thcolumn <--> 5throw_172thcolumn : 0.7099
# 4throw_172thcolumn <--> 104throw_172thcolumn : 0.7359
# 4throw_173thcolumn <--> 5throw_173thcolumn : 0.7097
# 4throw_173thcolumn <--> 104throw_173thcolumn : 0.7277
# 4throw_174thcolumn <--> 5throw_174thcolumn : 0.7118
# 4throw_174thcolumn <--> 104throw_174thcolumn : 0.7144
# 4throw_175thcolumn <--> 104throw_175thcolumn : 0.7209
# 4throw_177thcolumn <--> 104throw_177thcolumn : 0.7008
# 4throw_178thcolumn <--> 104throw_178thcolumn : 0.7103
# 4throw_179thcolumn <--> 104throw_179thcolumn : 0.7015
# 4throw_180thcolumn <--> 5throw_180thcolumn : 0.7150
# 4throw_180thcolumn <--> 104throw_180thcolumn : 0.7510
# 4throw_181thcolumn <--> 5throw_181thcolumn : 0.7131
# 4throw_181thcolumn <--> 104throw_181thcolumn : 0.7668
# 4throw_182thcolumn <--> 104throw_182thcolumn : 0.7181
# 4throw_183thcolumn <--> 104throw_183thcolumn : 0.7207
# 4throw_184thcolumn <--> 104throw_184thcolumn : 0.7177
# 4throw_185thcolumn <--> 104throw_185thcolumn : 0.7473
# 4throw_186thcolumn <--> 104throw_186thcolumn : 0.7081
# 4throw_188thcolumn <--> 104throw_188thcolumn : 0.7049
# 4throw_189thcolumn <--> 5throw_189thcolumn : 0.7035
# 4throw_189thcolumn <--> 104throw_189thcolumn : 0.7309
# 4throw_190thcolumn <--> 104throw_190thcolumn : 0.7222
# 4throw_191thcolumn <--> 104throw_191thcolumn : 0.7086
# 4throw_192thcolumn <--> 104throw_192thcolumn : 0.7050
# 4throw_193thcolumn <--> 5throw_193thcolumn : 0.7034
# 4throw_193thcolumn <--> 104throw_193thcolumn : 0.7092
# 4throw_195thcolumn <--> 5throw_195thcolumn : 0.7290
# 4throw_195thcolumn <--> 104throw_195thcolumn : 0.7180
# 4throw_196thcolumn <--> 5throw_196thcolumn : 0.7108
# 4throw_196thcolumn <--> 104throw_196thcolumn : 0.7224
# 4throw_197thcolumn <--> 5throw_197thcolumn : 0.7094
# 4throw_197thcolumn <--> 104throw_197thcolumn : 0.7393
# 4throw_198thcolumn <--> 5throw_198thcolumn : 0.7157
# 4throw_198thcolumn <--> 104throw_198thcolumn : 0.7239
# 4throw_199thcolumn <--> 5throw_199thcolumn : 0.7204
# 4throw_199thcolumn <--> 104throw_199thcolumn : 0.7162
# 5throw_6thcolumn <--> 6throw_105thcolumn : 0.7744
# 5throw_7thcolumn <--> 5throw_9thcolumn : 0.7909
# 5throw_7thcolumn <--> 5throw_106thcolumn : 0.8160
# 5throw_7thcolumn <--> 5throw_108thcolumn : 0.7171
# 5throw_7thcolumn <--> 5throw_109thcolumn : 0.7094
# 5throw_7thcolumn <--> 7throw_105thcolumn : 0.7134
# 5throw_8thcolumn <--> 5throw_107thcolumn : 0.7598
# 5throw_8thcolumn <--> 8throw_11thcolumn : 0.7462
# 5throw_8thcolumn <--> 8throw_105thcolumn : 0.8022
# 5throw_9thcolumn <--> 5throw_106thcolumn : 0.7260
# 5throw_9thcolumn <--> 5throw_107thcolumn : 0.7158
# 5throw_9thcolumn <--> 5throw_108thcolumn : 0.8741
# 5throw_9thcolumn <--> 5throw_109thcolumn : 0.8082
# 5throw_9thcolumn <--> 5throw_110thcolumn : 0.7161
# 5throw_9thcolumn <--> 9throw_105thcolumn : 0.7145
# 5throw_10thcolumn <--> 5throw_110thcolumn : 0.7723
# 5throw_10thcolumn <--> 10throw_105thcolumn : 0.7425
# 5throw_12thcolumn <--> 5throw_114thcolumn : 0.7190
# 5throw_12thcolumn <--> 12throw_105thcolumn : 0.7577
# 5throw_13thcolumn <--> 11throw_13thcolumn : 0.7169
# 5throw_13thcolumn <--> 13throw_105thcolumn : 0.7833
# 5throw_14thcolumn <--> 5throw_15thcolumn : 0.7615
# 5throw_14thcolumn <--> 14throw_105thcolumn : 0.7649
# 5throw_15thcolumn <--> 11throw_15thcolumn : 0.7042
# 5throw_15thcolumn <--> 15throw_105thcolumn : 0.7797
# 5throw_16thcolumn <--> 11throw_16thcolumn : 0.7323
# 5throw_16thcolumn <--> 16throw_105thcolumn : 0.8163
# 5throw_17thcolumn <--> 11throw_17thcolumn : 0.7234
# 5throw_17thcolumn <--> 17throw_105thcolumn : 0.7961
# 5throw_18thcolumn <--> 5throw_120thcolumn : 0.7000
# 5throw_18thcolumn <--> 5throw_121thcolumn : 0.8311
# 5throw_18thcolumn <--> 11throw_18thcolumn : 0.7383
# 5throw_18thcolumn <--> 18throw_105thcolumn : 0.7955
# 5throw_19thcolumn <--> 5throw_122thcolumn : 0.8014
# 5throw_19thcolumn <--> 11throw_19thcolumn : 0.7228
# 5throw_19thcolumn <--> 19throw_105thcolumn : 0.7819
# 5throw_20thcolumn <--> 11throw_20thcolumn : 0.7176
# 5throw_20thcolumn <--> 20throw_105thcolumn : 0.7964
# 5throw_21thcolumn <--> 21throw_105thcolumn : 0.7833
# 5throw_22thcolumn <--> 22throw_105thcolumn : 0.7470
# 5throw_23thcolumn <--> 5throw_127thcolumn : 0.7324
# 5throw_23thcolumn <--> 23throw_105thcolumn : 0.7707
# 5throw_24thcolumn <--> 11throw_24thcolumn : 0.7180
# 5throw_24thcolumn <--> 24throw_105thcolumn : 0.7766
# 5throw_25thcolumn <--> 11throw_25thcolumn : 0.7002
# 5throw_25thcolumn <--> 25throw_105thcolumn : 0.7672
# 5throw_26thcolumn <--> 5throw_129thcolumn : 0.8904
# 5throw_26thcolumn <--> 26throw_105thcolumn : 0.7794
# 5throw_26thcolumn <--> 105throw_129thcolumn : 0.7151
# 5throw_27thcolumn <--> 11throw_27thcolumn : 0.7067
# 5throw_27thcolumn <--> 27throw_105thcolumn : 0.7816
# 5throw_28thcolumn <--> 11throw_28thcolumn : 0.7017
# 5throw_28thcolumn <--> 28throw_105thcolumn : 0.7983
# ...
# 112throw_150thcolumn <--> 137throw_150thcolumn : 0.7499
# 112throw_152thcolumn <--> 137throw_152thcolumn : 0.7156
# 112throw_153thcolumn <--> 137throw_153thcolumn : 0.7033
# 112throw_155thcolumn <--> 137throw_155thcolumn : 0.7633
# 112throw_158thcolumn <--> 137throw_158thcolumn : 0.7040
# 112throw_166thcolumn <--> 136throw_166thcolumn : 0.7546
# 112throw_166thcolumn <--> 137throw_166thcolumn : 0.7771
# 112throw_168thcolumn <--> 136throw_168thcolumn : 0.7025
# 112throw_168thcolumn <--> 137throw_168thcolumn : 0.7274
# 112throw_169thcolumn <--> 137throw_169thcolumn : 0.7216
# 112throw_171thcolumn <--> 137throw_171thcolumn : 0.7142
# 112throw_172thcolumn <--> 137throw_172thcolumn : 0.7014
# 112throw_173thcolumn <--> 137throw_173thcolumn : 0.7097
# 112throw_174thcolumn <--> 137throw_174thcolumn : 0.7277
# 112throw_175thcolumn <--> 137throw_175thcolumn : 0.7208
# 112throw_177thcolumn <--> 137throw_177thcolumn : 0.7021
# 112throw_178thcolumn <--> 137throw_178thcolumn : 0.7140
# 112throw_179thcolumn <--> 137throw_179thcolumn : 0.7297
# 112throw_181thcolumn <--> 137throw_181thcolumn : 0.7111
# 112throw_182thcolumn <--> 137throw_182thcolumn : 0.7323
# 112throw_183thcolumn <--> 137throw_183thcolumn : 0.7386
# 112throw_184thcolumn <--> 137throw_184thcolumn : 0.7274
# 112throw_185thcolumn <--> 137throw_185thcolumn : 0.7153
# 112throw_186thcolumn <--> 136throw_186thcolumn : 0.7054
# 112throw_186thcolumn <--> 137throw_186thcolumn : 0.7663
# 112throw_187thcolumn <--> 137throw_187thcolumn : 0.7261
# 112throw_188thcolumn <--> 112throw_191thcolumn : 0.7218
# 112throw_188thcolumn <--> 137throw_188thcolumn : 0.7097
# 112throw_189thcolumn <--> 137throw_189thcolumn : 0.7161
# 112throw_192thcolumn <--> 137throw_192thcolumn : 0.7318
# 112throw_193thcolumn <--> 137throw_193thcolumn : 0.7120
# 112throw_194thcolumn <--> 137throw_194thcolumn : 0.7136
# 112throw_195thcolumn <--> 137throw_195thcolumn : 0.7087
# 112throw_196thcolumn <--> 137throw_196thcolumn : 0.7277
# 112throw_197thcolumn <--> 136throw_197thcolumn : 0.7029
# 112throw_197thcolumn <--> 137throw_197thcolumn : 0.7582
# 112throw_198thcolumn <--> 137throw_198thcolumn : 0.7790
# 112throw_199thcolumn <--> 137throw_199thcolumn : 0.7764
# 113throw_120thcolumn <--> 113throw_121thcolumn : 0.7423
# 113throw_120thcolumn <--> 120throw_129thcolumn : 0.7068
# 113throw_121thcolumn <--> 121throw_129thcolumn : 0.7089
# 113throw_134thcolumn <--> 113throw_165thcolumn : 0.7086
# 113throw_179thcolumn <--> 113throw_184thcolumn : 0.7165
# 113throw_188thcolumn <--> 113throw_191thcolumn : 0.7030
# 114throw_115thcolumn <--> 114throw_117thcolumn : 0.7678
# 114throw_188thcolumn <--> 114throw_191thcolumn : 0.7482
# 115throw_119thcolumn <--> 117throw_119thcolumn : 0.7860
# 115throw_120thcolumn <--> 115throw_121thcolumn : 0.7550
# 115throw_120thcolumn <--> 117throw_120thcolumn : 0.7626
# 115throw_121thcolumn <--> 117throw_121thcolumn : 0.8013
# 115throw_123thcolumn <--> 117throw_123thcolumn : 0.7395
# 115throw_124thcolumn <--> 117throw_124thcolumn : 0.7795
# 115throw_125thcolumn <--> 117throw_125thcolumn : 0.7564
# 115throw_126thcolumn <--> 117throw_126thcolumn : 0.7724
# 115throw_128thcolumn <--> 117throw_128thcolumn : 0.7234
# 115throw_129thcolumn <--> 117throw_129thcolumn : 0.7202
# 115throw_130thcolumn <--> 117throw_130thcolumn : 0.7071
# 115throw_131thcolumn <--> 117throw_131thcolumn : 0.7625
# 115throw_132thcolumn <--> 117throw_132thcolumn : 0.7522
# 115throw_133thcolumn <--> 117throw_133thcolumn : 0.7424
# 115throw_134thcolumn <--> 117throw_134thcolumn : 0.7590
# 115throw_135thcolumn <--> 117throw_135thcolumn : 0.7623
# 115throw_136thcolumn <--> 117throw_136thcolumn : 0.7134
# 115throw_137thcolumn <--> 117throw_137thcolumn : 0.7023
# 115throw_138thcolumn <--> 117throw_138thcolumn : 0.7613
# 115throw_139thcolumn <--> 117throw_139thcolumn : 0.7655
# 115throw_140thcolumn <--> 117throw_140thcolumn : 0.7435
# 115throw_141thcolumn <--> 117throw_141thcolumn : 0.7356
# 115throw_142thcolumn <--> 117throw_142thcolumn : 0.7026
# 115throw_144thcolumn <--> 117throw_144thcolumn : 0.7408
# 115throw_145thcolumn <--> 117throw_145thcolumn : 0.7225
# 115throw_146thcolumn <--> 117throw_146thcolumn : 0.7396
# 115throw_147thcolumn <--> 117throw_147thcolumn : 0.7574
# 115throw_148thcolumn <--> 117throw_148thcolumn : 0.7576
# 115throw_149thcolumn <--> 117throw_149thcolumn : 0.7311
# 115throw_150thcolumn <--> 117throw_150thcolumn : 0.7417
# 115throw_151thcolumn <--> 117throw_151thcolumn : 0.7240
# 115throw_152thcolumn <--> 117throw_152thcolumn : 0.7425
# 115throw_153thcolumn <--> 117throw_153thcolumn : 0.7266
# 115throw_154thcolumn <--> 117throw_154thcolumn : 0.7087
# 115throw_155thcolumn <--> 117throw_155thcolumn : 0.7751
# 115throw_163thcolumn <--> 117throw_163thcolumn : 0.7275
# 115throw_164thcolumn <--> 117throw_164thcolumn : 0.7343
# 115throw_165thcolumn <--> 117throw_165thcolumn : 0.7556
# 115throw_166thcolumn <--> 117throw_166thcolumn : 0.7331
# 115throw_167thcolumn <--> 117throw_167thcolumn : 0.7089
# 115throw_168thcolumn <--> 117throw_168thcolumn : 0.7476
# 115throw_169thcolumn <--> 117throw_169thcolumn : 0.7086
# 115throw_170thcolumn <--> 117throw_170thcolumn : 0.7480
# 115throw_172thcolumn <--> 117throw_172thcolumn : 0.7152
# 115throw_173thcolumn <--> 117throw_173thcolumn : 0.7479
# 115throw_174thcolumn <--> 117throw_174thcolumn : 0.7355
# 115throw_175thcolumn <--> 117throw_175thcolumn : 0.7510
# 115throw_178thcolumn <--> 117throw_178thcolumn : 0.7766
# 115throw_179thcolumn <--> 117throw_179thcolumn : 0.7437
# 115throw_180thcolumn <--> 117throw_180thcolumn : 0.7408
# 115throw_181thcolumn <--> 117throw_181thcolumn : 0.7347
# 115throw_182thcolumn <--> 117throw_182thcolumn : 0.7837
# 115throw_183thcolumn <--> 117throw_183thcolumn : 0.7550
# 115throw_184thcolumn <--> 117throw_184thcolumn : 0.7133
# 115throw_185thcolumn <--> 117throw_185thcolumn : 0.7662
# 115throw_186thcolumn <--> 117throw_186thcolumn : 0.7171
# 115throw_188thcolumn <--> 115throw_191thcolumn : 0.7234
# 115throw_188thcolumn <--> 117throw_188thcolumn : 0.7100
# 115throw_189thcolumn <--> 117throw_189thcolumn : 0.7657
# 115throw_190thcolumn <--> 117throw_190thcolumn : 0.7030
# 115throw_191thcolumn <--> 117throw_191thcolumn : 0.7207
# 115throw_192thcolumn <--> 117throw_192thcolumn : 0.7151
# 115throw_194thcolumn <--> 117throw_194thcolumn : 0.7573
# 115throw_195thcolumn <--> 117throw_195thcolumn : 0.7359
# 115throw_196thcolumn <--> 117throw_196thcolumn : 0.7514
# 115throw_197thcolumn <--> 117throw_197thcolumn : 0.7456
# 115throw_198thcolumn <--> 117throw_198thcolumn : 0.7628
# 115throw_199thcolumn <--> 117throw_199thcolumn : 0.7689
# 116throw_124thcolumn <--> 124throw_139thcolumn : 0.7258
# 116throw_129thcolumn <--> 118throw_129thcolumn : 0.7047
# 116throw_131thcolumn <--> 118throw_131thcolumn : 0.7290
# 116throw_131thcolumn <--> 131throw_137thcolumn : 0.7200
# 116throw_131thcolumn <--> 131throw_139thcolumn : 0.7499
# 116throw_140thcolumn <--> 139throw_140thcolumn : 0.7135
# 116throw_150thcolumn <--> 139throw_150thcolumn : 0.7456
# 116throw_166thcolumn <--> 139throw_166thcolumn : 0.7362
# 116throw_171thcolumn <--> 139throw_171thcolumn : 0.7051
# 116throw_172thcolumn <--> 139throw_172thcolumn : 0.7061
# 116throw_178thcolumn <--> 139throw_178thcolumn : 0.7039
# 116throw_183thcolumn <--> 139throw_183thcolumn : 0.7149
# 116throw_185thcolumn <--> 139throw_185thcolumn : 0.7002
# 116throw_188thcolumn <--> 116throw_191thcolumn : 0.7471
# 116throw_197thcolumn <--> 139throw_197thcolumn : 0.7076
# 116throw_198thcolumn <--> 118throw_198thcolumn : 0.7009
# 116throw_198thcolumn <--> 137throw_198thcolumn : 0.7087
# 116throw_198thcolumn <--> 139throw_198thcolumn : 0.7247
# 116throw_199thcolumn <--> 139throw_199thcolumn : 0.7059
# 117throw_120thcolumn <--> 117throw_121thcolumn : 0.7212
# 117throw_188thcolumn <--> 117throw_191thcolumn : 0.7168
# 118throw_188thcolumn <--> 118throw_191thcolumn : 0.7207
# 119throw_188thcolumn <--> 119throw_191thcolumn : 0.7305
# 120throw_125thcolumn <--> 120throw_126thcolumn : 0.7142
# 120throw_125thcolumn <--> 120throw_128thcolumn : 0.7188
# 120throw_125thcolumn <--> 121throw_125thcolumn : 0.7197
# 120throw_126thcolumn <--> 121throw_126thcolumn : 0.7079
# 120throw_127thcolumn <--> 120throw_128thcolumn : 0.7161
# 120throw_128thcolumn <--> 121throw_128thcolumn : 0.7074
# 120throw_129thcolumn <--> 121throw_129thcolumn : 0.7572
# 120throw_141thcolumn <--> 120throw_145thcolumn : 0.7031
# 120throw_149thcolumn <--> 121throw_149thcolumn : 0.7107
# 120throw_168thcolumn <--> 121throw_168thcolumn : 0.7155
# 120throw_171thcolumn <--> 121throw_171thcolumn : 0.7096
# 120throw_172thcolumn <--> 121throw_172thcolumn : 0.7152
# 120throw_173thcolumn <--> 121throw_173thcolumn : 0.7167
# 120throw_175thcolumn <--> 121throw_175thcolumn : 0.7536
# 120throw_177thcolumn <--> 121throw_177thcolumn : 0.7049
# 120throw_178thcolumn <--> 121throw_178thcolumn : 0.7443
# 120throw_179thcolumn <--> 120throw_184thcolumn : 0.7218
# 120throw_183thcolumn <--> 121throw_183thcolumn : 0.7064
# 120throw_188thcolumn <--> 120throw_191thcolumn : 0.7362
# 120throw_198thcolumn <--> 121throw_198thcolumn : 0.7035
# 121throw_133thcolumn <--> 122throw_133thcolumn : 0.7057
# 121throw_134thcolumn <--> 121throw_165thcolumn : 0.7003
# 121throw_148thcolumn <--> 122throw_148thcolumn : 0.7097
# 121throw_188thcolumn <--> 121throw_191thcolumn : 0.7436
# 122throw_188thcolumn <--> 122throw_191thcolumn : 0.7209
# 123throw_163thcolumn <--> 124throw_163thcolumn : 0.7097
# 123throw_188thcolumn <--> 123throw_191thcolumn : 0.7087
# 123throw_195thcolumn <--> 124throw_195thcolumn : 0.7303
# 124throw_134thcolumn <--> 124throw_165thcolumn : 0.7472
# 125throw_131thcolumn <--> 126throw_131thcolumn : 0.7034
# 125throw_131thcolumn <--> 128throw_131thcolumn : 0.7212
# 125throw_138thcolumn <--> 126throw_138thcolumn : 0.7319
# 125throw_138thcolumn <--> 128throw_138thcolumn : 0.7072
# 125throw_139thcolumn <--> 126throw_139thcolumn : 0.7249
# 125throw_139thcolumn <--> 128throw_139thcolumn : 0.7295
# 125throw_148thcolumn <--> 126throw_148thcolumn : 0.7033
# 125throw_150thcolumn <--> 126throw_150thcolumn : 0.7190
# 125throw_155thcolumn <--> 126throw_155thcolumn : 0.7042
# 125throw_155thcolumn <--> 128throw_155thcolumn : 0.7150
# 125throw_173thcolumn <--> 126throw_173thcolumn : 0.7040
# 125throw_175thcolumn <--> 128throw_175thcolumn : 0.7008
# 125throw_178thcolumn <--> 126throw_178thcolumn : 0.7306
# 125throw_178thcolumn <--> 128throw_178thcolumn : 0.7051
# 125throw_195thcolumn <--> 126throw_195thcolumn : 0.7041
# 125throw_198thcolumn <--> 126throw_198thcolumn : 0.7027
# 125throw_198thcolumn <--> 128throw_198thcolumn : 0.7049
# 125throw_199thcolumn <--> 128throw_199thcolumn : 0.7049
# 127throw_131thcolumn <--> 128throw_131thcolumn : 0.7210
# 127throw_138thcolumn <--> 128throw_138thcolumn : 0.7178
# 127throw_150thcolumn <--> 128throw_150thcolumn : 0.7074
# 127throw_173thcolumn <--> 128throw_173thcolumn : 0.7031
# 127throw_174thcolumn <--> 128throw_174thcolumn : 0.7011
# 127throw_175thcolumn <--> 128throw_175thcolumn : 0.7003
# 127throw_183thcolumn <--> 128throw_183thcolumn : 0.7027
# 127throw_188thcolumn <--> 127throw_191thcolumn : 0.7017
# 127throw_197thcolumn <--> 128throw_197thcolumn : 0.7016
# 127throw_198thcolumn <--> 128throw_198thcolumn : 0.7462
# 127throw_199thcolumn <--> 128throw_199thcolumn : 0.7050
# 128throw_188thcolumn <--> 128throw_191thcolumn : 0.7168
# 129throw_134thcolumn <--> 129throw_165thcolumn : 0.7111
# 129throw_179thcolumn <--> 129throw_184thcolumn : 0.7086
# 130throw_188thcolumn <--> 130throw_191thcolumn : 0.7024
# 131throw_134thcolumn <--> 131throw_135thcolumn : 0.7256
# 131throw_134thcolumn <--> 131throw_165thcolumn : 0.7416
# 131throw_136thcolumn <--> 131throw_137thcolumn : 0.7688
# 131throw_141thcolumn <--> 131throw_145thcolumn : 0.7257
# 131throw_145thcolumn <--> 131throw_146thcolumn : 0.7664
# 131throw_170thcolumn <--> 131throw_189thcolumn : 0.7092
# 131throw_172thcolumn <--> 131throw_183thcolumn : 0.7141
# 131throw_179thcolumn <--> 131throw_184thcolumn : 0.7277
# 131throw_188thcolumn <--> 131throw_191thcolumn : 0.7742
# 132throw_142thcolumn <--> 135throw_142thcolumn : 0.7438
# 133throw_145thcolumn <--> 133throw_146thcolumn : 0.7001
# 134throw_142thcolumn <--> 135throw_142thcolumn : 0.7465
# 134throw_142thcolumn <--> 142throw_165thcolumn : 0.7497
# 134throw_161thcolumn <--> 161throw_165thcolumn : 0.7095
# 134throw_167thcolumn <--> 135throw_167thcolumn : 0.7064
# 134throw_171thcolumn <--> 165throw_171thcolumn : 0.7499
# 134throw_179thcolumn <--> 165throw_179thcolumn : 0.7280
# 134throw_181thcolumn <--> 165throw_181thcolumn : 0.7292
# 134throw_183thcolumn <--> 135throw_183thcolumn : 0.7048
# 134throw_183thcolumn <--> 165throw_183thcolumn : 0.7468
# 134throw_184thcolumn <--> 165throw_184thcolumn : 0.7312
# 134throw_185thcolumn <--> 165throw_185thcolumn : 0.7017
# 134throw_186thcolumn <--> 165throw_186thcolumn : 0.7077
# 134throw_187thcolumn <--> 165throw_187thcolumn : 0.7077
# 134throw_189thcolumn <--> 165throw_189thcolumn : 0.7205
# 134throw_192thcolumn <--> 165throw_192thcolumn : 0.7068
# 134throw_193thcolumn <--> 165throw_193thcolumn : 0.7458
# 134throw_196thcolumn <--> 165throw_196thcolumn : 0.7281
# 134throw_197thcolumn <--> 165throw_197thcolumn : 0.7428
# 134throw_198thcolumn <--> 135throw_198thcolumn : 0.7237
# 134throw_198thcolumn <--> 165throw_198thcolumn : 0.7452
# 134throw_199thcolumn <--> 165throw_199thcolumn : 0.7225
# 136throw_140thcolumn <--> 137throw_140thcolumn : 0.7322
# 136throw_166thcolumn <--> 137throw_166thcolumn : 0.7596
# 136throw_166thcolumn <--> 141throw_166thcolumn : 0.7083
# 136throw_171thcolumn <--> 137throw_171thcolumn : 0.7167
# 136throw_188thcolumn <--> 136throw_191thcolumn : 0.7431
# 136throw_196thcolumn <--> 136throw_197thcolumn : 0.7058
# 136throw_198thcolumn <--> 137throw_198thcolumn : 0.7338
# 136throw_199thcolumn <--> 137throw_199thcolumn : 0.7093
# 137throw_188thcolumn <--> 137throw_191thcolumn : 0.7548
# 138throw_145thcolumn <--> 138throw_146thcolumn : 0.7033
# 140throw_188thcolumn <--> 140throw_191thcolumn : 0.7474
# 141throw_174thcolumn <--> 145throw_174thcolumn : 0.7016
# 141throw_183thcolumn <--> 145throw_183thcolumn : 0.7422
# 141throw_193thcolumn <--> 145throw_193thcolumn : 0.7004
# 141throw_198thcolumn <--> 145throw_198thcolumn : 0.7364
# 142throw_188thcolumn <--> 142throw_191thcolumn : 0.7554
# 144throw_150thcolumn <--> 145throw_150thcolumn : 0.7176
# 144throw_174thcolumn <--> 145throw_174thcolumn : 0.7037
# 144throw_183thcolumn <--> 145throw_183thcolumn : 0.7246
# 144throw_198thcolumn <--> 145throw_198thcolumn : 0.7142
# 145throw_150thcolumn <--> 146throw_150thcolumn : 0.7529
# 145throw_158thcolumn <--> 146throw_158thcolumn : 0.7172
# 145throw_166thcolumn <--> 146throw_166thcolumn : 0.7442
# 145throw_170thcolumn <--> 146throw_170thcolumn : 0.7038
# 145throw_173thcolumn <--> 146throw_173thcolumn : 0.7344
# 145throw_174thcolumn <--> 146throw_174thcolumn : 0.7556
# 145throw_181thcolumn <--> 146throw_181thcolumn : 0.7101
# 145throw_183thcolumn <--> 146throw_183thcolumn : 0.7516
# 145throw_184thcolumn <--> 146throw_184thcolumn : 0.7632
# 145throw_184thcolumn <--> 154throw_184thcolumn : 0.7284
# 145throw_189thcolumn <--> 146throw_189thcolumn : 0.7120
# 145throw_193thcolumn <--> 146throw_193thcolumn : 0.7127
# 145throw_196thcolumn <--> 146throw_196thcolumn : 0.7159
# 145throw_197thcolumn <--> 146throw_197thcolumn : 0.7066
# 145throw_198thcolumn <--> 146throw_198thcolumn : 0.7802
# 145throw_199thcolumn <--> 146throw_199thcolumn : 0.7221
# 146throw_174thcolumn <--> 149throw_174thcolumn : 0.7540
# 146throw_184thcolumn <--> 149throw_184thcolumn : 0.7629
# 146throw_184thcolumn <--> 154throw_184thcolumn : 0.7156
# 147throw_188thcolumn <--> 147throw_191thcolumn : 0.7052
# 150throw_188thcolumn <--> 150throw_191thcolumn : 0.7304
# 158throw_193thcolumn <--> 188throw_193thcolumn : 0.7091
# 159throw_179thcolumn <--> 159throw_184thcolumn : 0.7112
# 159throw_186thcolumn <--> 159throw_187thcolumn : 0.7266
# 166throw_188thcolumn <--> 166throw_191thcolumn : 0.7229
# 167throw_188thcolumn <--> 167throw_191thcolumn : 0.7266
# 168throw_186thcolumn <--> 168throw_187thcolumn : 0.7102
# 168throw_188thcolumn <--> 168throw_191thcolumn : 0.7098
# 168throw_196thcolumn <--> 168throw_197thcolumn : 0.7020
# 174throw_188thcolumn <--> 174throw_191thcolumn : 0.7026
# 181throw_188thcolumn <--> 181throw_191thcolumn : 0.7030
# 183throw_188thcolumn <--> 183throw_191thcolumn : 0.7097
# 188throw_193thcolumn <--> 191throw_193thcolumn : 0.7117
# 188throw_198thcolumn <--> 191throw_198thcolumn : 0.7256

# %%
to_drop = set()
for corr in significant_spearman_fcm:
    if abs(corr['correlation']) >= 0.7:
        to_drop.add(corr['feature2'])

len(to_drop)
# Out:
# 6865

# %%
cleaned_fcm = train_fcm.drop(columns=list(to_drop))

# %%
numerical_data_fcm = cleaned_fcm.select_dtypes(include=np.number)

# Pearson أسرع بكثير
pearson_corr_fcm = numerical_data_fcm.corr(method='pearson')

significant_pearson_fcm = find_significant_correlations(
    pearson_corr_fcm,
    threshold=0.7
)

print(f"Number of highly correlated pairs: {len(significant_pearson_fcm)}")

# عرض أول 10 فقط
for corr in significant_pearson_fcm[:10]:
    print(f"{corr['feature1']} <--> {corr['feature2']} : {corr['correlation']:.3f}")
# Out:
# Number of highly correlated pairs: 1287
# 0throw_5thcolumn <--> 0throw_11thcolumn : 0.707
# 0throw_17thcolumn <--> 0throw_119thcolumn : 0.703
# 0throw_22thcolumn <--> 0throw_125thcolumn : 0.708
# 0throw_32thcolumn <--> 6throw_32thcolumn : 0.700
# 0throw_57thcolumn <--> 6throw_57thcolumn : 0.703
# 0throw_84thcolumn <--> 0throw_85thcolumn : 0.717
# 0throw_86thcolumn <--> 6throw_86thcolumn : 0.720
# 0throw_95thcolumn <--> 6throw_95thcolumn : 0.719
# 0throw_112thcolumn <--> 0throw_137thcolumn : 0.724
# 0throw_125thcolumn <--> 0throw_126thcolumn : 0.712

# %% [markdown]
# No correlations > 0.7

# %%
cleaned_fcm.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1090 entries, 0 to 1212
# Columns: 13036 entries, participant_id to 198throw_199thcolumn
# dtypes: float64(13035), str(1)
# memory usage: 108.4 MB

# %%
fcm_columns = cleaned_fcm.columns
test_fcm = test_fcm[fcm_columns]

# %%
test_fcm.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 304 entries, 0 to 303
# Columns: 13036 entries, participant_id to 198throw_199thcolumn
# dtypes: float64(13035), str(1)
# memory usage: 30.2 MB

# %% [markdown]
# ### ✅ Same sizes for test and train data

# %% [markdown]
# You have two types of data:
#
# - MRI correlation data (already scaled: values between -1 and 1) → ✅ No scaling needed
#
# - Psychometric/behavioral data → Needs scaling

# %% [markdown]
# ✅ Best overall scaler for consistency across different models:
#
# StandardScaler (z-score scaling)
#
# It standardizes the data to mean = 0 and std = 1.
#
# This works well for most models and won’t squash outliers as aggressively as MinMax, which might be safer for the psychometric scores.

# %%
train_quan.iloc[:, 1:]
# Out:
#       EHQ_EHQ_Total  ColorVision_CV_Score  APQ_P_APQ_P_CP  APQ_P_APQ_P_ID  \
# 0            100.00                  13.0             3.0            15.0
# 1             92.27                  14.0             3.0            12.0
# 2             86.67                  14.0             3.0            21.0
# 3             93.34                  14.0             3.0            11.0
# 4              0.00                  14.0             8.0            12.0
# ...             ...                   ...             ...             ...
# 1208         100.00                  14.0             3.0            14.0
# 1209          46.67                  14.0             3.0            18.0
# 1210         -40.00                  14.0             3.0            19.0
# 1211         100.00                  14.0             3.0             9.0
# 1212          87.80                  14.0             3.0             8.0
#
#       APQ_P_APQ_P_INV  APQ_P_APQ_P_OPD  APQ_P_APQ_P_PM  APQ_P_APQ_P_PP  \
# 0                44.0             14.0            20.0            27.0
# 1                35.0             25.0            28.0            30.0
# 2                37.0             18.0            26.0            28.0
# 3                42.0             15.0            20.0            28.0
# 4                35.0             22.0            12.0            24.0
# ...               ...              ...             ...             ...
# 1208             36.0             18.0            13.0            22.0
# 1209             42.0             21.0            15.0            25.0
# 1210             34.0             20.0            20.0            25.0
# 1211             45.0             23.0            11.0            30.0
# 1212             45.0             16.0            13.0            24.0
#
#       SDQ_SDQ_Conduct_Problems  SDQ_SDQ_Emotional_Problems  \
# 0                          3.0                         4.0
# 1                          5.0                         4.0
# 2                          3.0                         7.0
# 3                          0.0                         0.0
# 4                          6.0                         7.0
# ...                        ...                         ...
# 1208                       5.0                         5.0
# 1209                       2.0                         0.0
# 1210                       2.0                         3.0
# 1211                       1.0                         0.0
# 1212                       2.0                         2.0
#
#       SDQ_SDQ_Generating_Impact  SDQ_SDQ_Hyperactivity  SDQ_SDQ_Peer_Problems  \
# 0                           5.0                    8.0                    2.0
# 1                           5.0                    8.0                    3.0
# 2                          10.0                    7.0                    7.0
# 3                           0.0                    3.0                    2.0
# 4                           8.0                    9.0                    1.0
# ...                         ...                    ...                    ...
# 1208                        5.0                    8.0                    2.0
# 1209                        0.0                    3.0                    0.0
# 1210                        3.0                    7.0                    2.0
# 1211                        5.0                    7.0                    2.0
# 1212                        4.0                    7.0                    0.0
#
#       SDQ_SDQ_Prosocial
# 0                   9.0
# 1                   8.0
# 2                   7.0
# 3                   6.0
# 4                   4.0
# ...                 ...
# 1208                8.0
# 1209                7.0
# 1210                9.0
# 1211                7.0
# 1212                5.0
#
# [1090 rows x 14 columns]

# %%
test_quan.iloc[:, 1:]
# Out:
#      EHQ_EHQ_Total  ColorVision_CV_Score  APQ_P_APQ_P_CP  APQ_P_APQ_P_ID  \
# 0            60.03                  14.0             5.0            16.0
# 1            86.71                  12.0             3.0            13.0
# 2            26.68                  13.0             3.0            14.0
# 3            93.38                  13.0             3.0            19.0
# 4           -93.38                  14.0             3.0            13.0
# ..             ...                   ...             ...             ...
# 299          86.71                  14.0             3.0            17.0
# 300          73.37                  14.0             5.0            12.0
# 301          87.84                  13.0             3.0            14.0
# 302          46.76                  14.0             3.0            16.0
# 303          87.84                  13.0             3.0            13.0
#
#      APQ_P_APQ_P_INV  APQ_P_APQ_P_OPD  APQ_P_APQ_P_PM  APQ_P_APQ_P_PP  \
# 0               41.0             19.0            11.0            26.0
# 1               43.0             18.0            15.0            28.0
# 2               36.0             16.0            14.0            25.0
# 3               41.0             17.0            18.0            27.0
# 4               42.0             19.0            16.0            28.0
# ..               ...              ...             ...             ...
# 299             41.0             17.0            11.0            25.0
# 300             38.0             22.0             9.0            29.0
# 301             42.0             15.0            10.0            28.0
# 302             43.0             18.0            12.0            22.0
# 303             47.0             16.0            10.0            30.0
#
#      SDQ_SDQ_Conduct_Problems  SDQ_SDQ_Emotional_Problems  \
# 0                         2.0                         3.0
# 1                         2.0                         8.0
# 2                         1.0                         1.0
# 3                         4.0                         4.0
# 4                         2.0                         6.0
# ..                        ...                         ...
# 299                       1.0                         7.0
# 300                       2.0                         2.0
# 301                       1.0                         4.0
# 302                       5.0                         2.0
# 303                       0.0                         0.0
#
#      SDQ_SDQ_Generating_Impact  SDQ_SDQ_Hyperactivity  SDQ_SDQ_Peer_Problems  \
# 0                          2.0                    7.0                    0.0
# 1                          7.0                    3.0                    3.0
# 2                          1.0                    5.0                    0.0
# 3                          8.0                    6.0                    1.0
# 4                          5.0                   10.0                    0.0
# ..                         ...                    ...                    ...
# 299                        5.0                    6.0                    4.0
# 300                        5.0                    9.0                    3.0
# 301                        4.0                    3.0                    3.0
# 302                        6.0                    5.0                    9.0
# 303                        3.0                    4.0                    0.0
#
#      SDQ_SDQ_Prosocial
# 0                  8.0
# 1                  9.0
# 2                  9.0
# 3                  6.0
# 4                 10.0
# ..                 ...
# 299                7.0
# 300                8.0
# 301               10.0
# 302                0.0
# 303               10.0
#
# [304 rows x 14 columns]

# %%
scaler = StandardScaler()
scaled_values = scaler.fit_transform(train_quan.iloc[:, 1:])  # exclude participant_id

scaled_train_quan = pd.concat([train_quan[['participant_id']], pd.DataFrame(scaled_values, columns=train_quan.columns[1:], index=train_quan.index)], axis=1)

# %%
scaled_test_values = scaler.transform(test_quan.iloc[:, 1:])  # exclude participant_id

scaled_test_quan = pd.concat([test_quan[['participant_id']], pd.DataFrame(scaled_test_values, columns=test_quan.columns[1:], index=test_quan.index)],axis=1)

# %%
scaled_train_quan.describe()
# Out:
#        EHQ_EHQ_Total  ColorVision_CV_Score  APQ_P_APQ_P_CP  APQ_P_APQ_P_ID  \
# count   1.090000e+03          1.090000e+03    1.090000e+03    1.090000e+03
# mean   -1.499310e-16          1.271154e-16    1.352639e-16    2.281559e-16
# std     1.000459e+00          1.000459e+00    1.000459e+00    1.000459e+00
# min    -3.197460e+00         -6.095753e+00   -1.363566e+00   -2.342471e+00
# 25%    -2.622368e-01          2.777441e-01   -6.241198e-01   -6.656147e-01
# 50%     4.047774e-01          2.777441e-01   -6.241198e-01   -1.066624e-01
# 75%     6.943573e-01          2.777441e-01    1.153265e-01    7.317659e-01
# max     8.050260e-01          2.777441e-01    6.030897e+00    4.085479e+00
#
#        APQ_P_APQ_P_INV  APQ_P_APQ_P_OPD  APQ_P_APQ_P_PM  APQ_P_APQ_P_PP  \
# count     1.090000e+03     1.090000e+03    1.090000e+03    1.090000e+03
# mean      3.080105e-16    -2.526012e-16    1.311897e-16   -3.935690e-16
# std       1.000459e+00     1.000459e+00    1.000459e+00    1.000459e+00
# min      -3.472872e+00    -3.297059e+00   -2.278552e+00   -4.042677e+00
# 25%      -7.686959e-01    -5.856710e-01   -7.042731e-01   -7.911141e-01
# 50%       6.335825e-02     1.685981e-02   -1.139186e-01    1.843546e-01
# 75%       6.873989e-01     6.193906e-01    4.764360e-01    8.346672e-01
# max       2.143494e+00     3.029514e+00    4.018563e+00    1.484980e+00
#
#        SDQ_SDQ_Conduct_Problems  SDQ_SDQ_Emotional_Problems  \
# count              1.090000e+03                1.090000e+03
# mean               5.214993e-17               -5.826124e-17
# std                1.000459e+00                1.000459e+00
# min               -1.013521e+00               -1.072471e+00
# 25%               -1.013521e+00               -6.044992e-01
# 50%               -2.449872e-02               -1.365275e-01
# 75%                4.700125e-01                7.994159e-01
# max                3.931591e+00                3.607246e+00
#
#        SDQ_SDQ_Generating_Impact  SDQ_SDQ_Hyperactivity  \
# count               1.090000e+03            1090.000000
# mean                2.281559e-17               0.000000
# std                 1.000459e+00               1.000459
# min                -1.459522e+00              -1.968564
# 25%                -7.458031e-01              -0.536881
# 50%                -3.208459e-02              -0.178960
# 75%                 6.816339e-01               0.894802
# max                 2.109071e+00               1.610643
#
#        SDQ_SDQ_Peer_Problems  SDQ_SDQ_Prosocial
# count           1.090000e+03       1.090000e+03
# mean            6.844678e-17      -1.857841e-16
# std             1.000459e+00       1.000459e+00
# min            -1.081401e+00      -3.684714e+00
# 25%            -1.081401e+00      -8.220353e-01
# 50%            -1.156271e-01       1.321910e-01
# 75%             8.501469e-01       1.086417e+00
# max             3.264582e+00       1.086417e+00

# %%
scaled_test_quan.describe()
# Out:
#        EHQ_EHQ_Total  ColorVision_CV_Score  APQ_P_APQ_P_CP  APQ_P_APQ_P_ID  \
# count     303.000000            295.000000      289.000000      289.000000
# mean       -0.012592             -0.067937       -0.386166       -0.034134
# std         0.987232              0.904250        0.599135        1.013775
# min        -3.198460             -6.095753       -1.363566       -2.062995
# 25%        -0.194395             -0.177506       -0.624120       -0.665615
# 50%         0.272095              0.277744       -0.624120       -0.106662
# 75%         0.672544              0.277744       -0.624120        0.731766
# max         0.806027              0.277744        3.073112        2.688099
#
#        APQ_P_APQ_P_INV  APQ_P_APQ_P_OPD  APQ_P_APQ_P_PM  APQ_P_APQ_P_PP  \
# count       289.000000       289.000000      289.000000      289.000000
# mean         -0.012937        -0.366758       -0.124813       -0.197057
# std           1.072016         1.012252        0.970378        1.067705
# min          -4.096913        -3.297059       -1.491413       -5.018145
# 25%          -0.768696        -1.188202       -0.901058       -0.791114
# 50%           0.063358        -0.284406       -0.310703       -0.140802
# 75%           0.687399         0.318125        0.476436        0.834667
# max           2.143494         2.728248        2.837854        1.484980
#
#        SDQ_SDQ_Conduct_Problems  SDQ_SDQ_Emotional_Problems  \
# count                274.000000                  274.000000
# mean                  -0.078642                    0.046221
# std                    0.975671                    1.001053
# min                   -1.013521                   -1.072471
# 25%                   -1.013521                   -0.604499
# 50%                   -0.519010                   -0.136528
# 75%                    0.470012                    0.799416
# max                    3.931591                    3.607246
#
#        SDQ_SDQ_Generating_Impact  SDQ_SDQ_Hyperactivity  \
# count                 274.000000             274.000000
# mean                   -0.051621               0.030044
# std                     0.959155               1.009700
# min                    -1.459522              -1.968564
# 25%                    -0.745803              -0.536881
# 50%                    -0.032085               0.178960
# 75%                     0.681634               0.894802
# max                     2.109071               1.610643
#
#        SDQ_SDQ_Peer_Problems  SDQ_SDQ_Prosocial
# count             274.000000         274.000000
# mean               -0.156161           0.001594
# std                 0.964477           0.994646
# min                -1.081401          -3.684714
# 25%                -1.081401          -0.822035
# 50%                -0.598514           0.132191
# 75%                 0.367260           1.086417
# max                 3.264582           1.086417

# %% [markdown]
# * **Pre-Interview- Demographics/Family**
#     * `PreInt_Demos_Fam_Child_Ethnicity`: Ethnicity of child (categorical int)
#         * 0 = Not Hispanic or Latino
#         * 1 = Hispanic or Latino
#         * 2 = Decline to specify
#         * 3 = Unknown
#     * `PreInt_Demos_Fam_Child_Race`: Race of child (categorical int)
#         * 0 = White/Caucasian
#         * 1 = Black/African American
#         * 2 = Hispanic
#         * 3 = Asian
#         * 4 = Indian
#         * 5 = Native American Indian
#         * 6 = American Indian/Alaskan Native
#         * 7 = Native Hawaiian/Other Pacific Islander
#         * 8 = Two or more races
#         * 9 = Other race
#         * 10 = Unknown
#         * 11 = Choose not to specify

# %%
train_cat = pd.get_dummies(train_cat, columns=['PreInt_Demos_Fam_Child_Ethnicity', 'PreInt_Demos_Fam_Child_Race'], drop_first=False)
test_cat = pd.get_dummies(test_cat, columns=['PreInt_Demos_Fam_Child_Ethnicity', 'PreInt_Demos_Fam_Child_Race'], drop_first=False)

# %%
train_cat.columns
# Out:
# Index(['participant_id', 'PreInt_Demos_Fam_Child_Ethnicity_0.0',
#        'PreInt_Demos_Fam_Child_Ethnicity_1.0',
#        'PreInt_Demos_Fam_Child_Ethnicity_2.0',
#        'PreInt_Demos_Fam_Child_Ethnicity_3.0',
#        'PreInt_Demos_Fam_Child_Race_0.0', 'PreInt_Demos_Fam_Child_Race_1.0',
#        'PreInt_Demos_Fam_Child_Race_2.0', 'PreInt_Demos_Fam_Child_Race_3.0',
#        'PreInt_Demos_Fam_Child_Race_4.0', 'PreInt_Demos_Fam_Child_Race_7.0',
#        'PreInt_Demos_Fam_Child_Race_8.0', 'PreInt_Demos_Fam_Child_Race_9.0',
#        'PreInt_Demos_Fam_Child_Race_10.0', 'PreInt_Demos_Fam_Child_Race_11.0'],
#       dtype='str')

# %%
test_cat.columns
# Out:
# Index(['participant_id', 'PreInt_Demos_Fam_Child_Ethnicity_0.0',
#        'PreInt_Demos_Fam_Child_Ethnicity_1.0',
#        'PreInt_Demos_Fam_Child_Ethnicity_2.0',
#        'PreInt_Demos_Fam_Child_Ethnicity_3.0',
#        'PreInt_Demos_Fam_Child_Race_0.0', 'PreInt_Demos_Fam_Child_Race_1.0',
#        'PreInt_Demos_Fam_Child_Race_2.0', 'PreInt_Demos_Fam_Child_Race_3.0',
#        'PreInt_Demos_Fam_Child_Race_4.0', 'PreInt_Demos_Fam_Child_Race_7.0',
#        'PreInt_Demos_Fam_Child_Race_8.0', 'PreInt_Demos_Fam_Child_Race_9.0',
#        'PreInt_Demos_Fam_Child_Race_11.0'],
#       dtype='str')

# %% [markdown]
#     'PreInt_Demos_Fam_Child_Ethnicity_2.0'
#     'PreInt_Demos_Fam_Child_Ethnicity_3.0'
# Dropping this 2 columns = Unknown or not specified

# %% [markdown]
#     'PreInt_Demos_Fam_Child_Race_7.0'
#     'PreInt_Demos_Fam_Child_Race_8.0'
#     'PreInt_Demos_Fam_Child_Race_9.0'
#     'PreInt_Demos_Fam_Child_Race_11.0'
#
# Dropping this columns = minority, unknown, other, not specified

# %%
print(train_cat.head())
print(test_cat.head())
# Out:
#   participant_id  PreInt_Demos_Fam_Child_Ethnicity_0.0  \
# 0   00aIpNTbG5uh                                 False
# 1   00fV0OyyoLfw                                  True
# 2   04X1eiS79T4B                                 False
# 3   05ocQutkURd6                                 False
# 4   06YUNBA9ZRLq                                  True
#
#    PreInt_Demos_Fam_Child_Ethnicity_1.0  PreInt_Demos_Fam_Child_Ethnicity_2.0  \
# 0                                  True                                 False
# 1                                 False                                 False
# 2                                  True                                 False
# 3                                 False                                 False
# 4                                 False                                 False
#
#    PreInt_Demos_Fam_Child_Ethnicity_3.0  PreInt_Demos_Fam_Child_Race_0.0  \
# 0                                 False                             True
# 1                                 False                            False
# 2                                 False                            False
# 3                                  True                            False
# 4                                 False                            False
#
#    PreInt_Demos_Fam_Child_Race_1.0  PreInt_Demos_Fam_Child_Race_2.0  \
# 0                            False                            False
# 1                            False                            False
# 2                            False                             True
# 3                            False                            False
# 4                             True                            False
#
#    PreInt_Demos_Fam_Child_Race_3.0  PreInt_Demos_Fam_Child_Race_4.0  \
# 0                            False                            False
# 1                            False                            False
# 2                            False                            False
# 3                            False                            False
# 4                            False                            False
#
#    PreInt_Demos_Fam_Child_Race_7.0  PreInt_Demos_Fam_Child_Race_8.0  \
# 0                            False                            False
# 1                            False                            False
# 2                            False                            False
# 3                            False                             True
# 4                            False                            False
#
#    PreInt_Demos_Fam_Child_Race_9.0  PreInt_Demos_Fam_Child_Race_10.0  \
# 0                            False                             False
# 1                             True                             False
# 2                            False                             False
# 3                            False                             False
# 4                            False                             False
#
#    PreInt_Demos_Fam_Child_Race_11.0
# 0                             False
# 1                             False
# 2                             False
# 3                             False
# 4                             False
#   participant_id  PreInt_Demos_Fam_Child_Ethnicity_0.0  \
# 0   Cfwaf5FX7jWK                                  True
# 1   vhGrzmvA3Hjq                                  True
# 2   ULliyEXjy4OV                                  True
# 3   LZfeAb1xMtql                                  True
# 4   EnFOUv0YK1RG                                 False
#
#    PreInt_Demos_Fam_Child_Ethnicity_1.0  PreInt_Demos_Fam_Child_Ethnicity_2.0  \
# 0                                 False                                 False
# 1                                 False                                 False
# 2                                 False                                 False
# 3                                 False                                 False
# 4                                 False                                  True
#
#    PreInt_Demos_Fam_Child_Ethnicity_3.0  PreInt_Demos_Fam_Child_Race_0.0  \
# 0                                 False                             True
# 1                                 False                             True
# 2                                 False                             True
# 3                                 False                             True
# 4                                 False                             True
#
#    PreInt_Demos_Fam_Child_Race_1.0  PreInt_Demos_Fam_Child_Race_2.0  \
# 0                            False                            False
# 1                            False                            False
# 2                            False                            False
# 3                            False                            False
# 4                            False                            False
#
#    PreInt_Demos_Fam_Child_Race_3.0  PreInt_Demos_Fam_Child_Race_4.0  \
# 0                            False                            False
# 1                            False                            False
# 2                            False                            False
# 3                            False                            False
# 4                            False                            False
#
#    PreInt_Demos_Fam_Child_Race_7.0  PreInt_Demos_Fam_Child_Race_8.0  \
# 0                            False                            False
# 1                            False                            False
# 2                            False                            False
# 3                            False                            False
# 4                            False                            False
#
#    PreInt_Demos_Fam_Child_Race_9.0  PreInt_Demos_Fam_Child_Race_11.0
# 0                            False                             False
# 1                            False                             False
# 2                            False                             False
# 3                            False                             False
# 4                            False                             False

# %% [markdown]
# ### Delete columns:
#
# * **Pre-Interview- Demographics/Family**
#     * `PreInt_Demos_Fam_Child_Ethnicity`: Ethnicity of child (categorical int)
#         * 2 = Decline to specify
#         * 3 = Unknown
#     * `PreInt_Demos_Fam_Child_Race`: Race of child (categorical int)
#         * 10 = Unknown
#         * 11 = Choose not to specify

# %%
train_cat.drop('PreInt_Demos_Fam_Child_Ethnicity_2.0',  axis = 1, inplace=True)
train_cat.drop('PreInt_Demos_Fam_Child_Ethnicity_3.0',  axis = 1, inplace=True)
train_cat.drop('PreInt_Demos_Fam_Child_Race_7.0',  axis = 1, inplace=True)
train_cat.drop('PreInt_Demos_Fam_Child_Race_8.0',  axis = 1, inplace=True)
train_cat.drop('PreInt_Demos_Fam_Child_Race_9.0',  axis = 1, inplace=True)
train_cat.drop('PreInt_Demos_Fam_Child_Race_11.0',  axis = 1, inplace=True)

# %%
test_cat.drop('PreInt_Demos_Fam_Child_Ethnicity_2.0',  axis = 1, inplace=True)
test_cat.drop('PreInt_Demos_Fam_Child_Ethnicity_3.0',  axis = 1, inplace=True)
test_cat.drop('PreInt_Demos_Fam_Child_Race_7.0',  axis = 1, inplace=True)
test_cat.drop('PreInt_Demos_Fam_Child_Race_8.0',  axis = 1, inplace=True)
test_cat.drop('PreInt_Demos_Fam_Child_Race_9.0',  axis = 1, inplace=True)
test_cat.drop('PreInt_Demos_Fam_Child_Race_11.0',  axis = 1, inplace=True)

# %% [markdown]
#     ✅ Handling nulls
#
#     ✅ Deleting features
#
#     ✅ Get Dummies for categorical data - and cleaning columns
#
#     ✅ Standard Scaler for quantity data
#
#     ✅ Test data scaling to fit train data

# %% [markdown]
# # 3. Dimensionality reduction

# %% [markdown]
# ✅ Reasons to Use PCA
#
# High Dimensionality (19,900 features):
#
# Your dataset has many features (19,900 columns). PCA helps reduce the number of features by transforming them into principal components (PCs) while retaining as much variance as possible. This could improve computational efficiency, reduce overfitting, and simplify your model.
#
# Correlated Features:
#
# PCA is great when features are highly correlated. If your features are correlated (e.g., related brain scan features), PCA can help create new, uncorrelated components that might capture more meaningful information.
#
# Noise Reduction:
#
# By reducing dimensions, PCA can help reduce the noise in the data, especially when you have many irrelevant or noisy features.
#
# Improve Model Training Time:
#
# With fewer features, training models (especially complex ones like neural networks) can be faster and more efficient.
#
# 🚫 Reasons You Might Not Want to Use PCA
#
# Interpretability:
#
# The principal components created by PCA are linear combinations of your original features, making them harder to interpret. If interpretability of individual features is crucial (e.g., understanding which specific brain scan features influence ADHD prediction), PCA may not be ideal.
#
# Loss of Information:
#
# Although PCA retains most of the variance, you may lose some useful information if you discard too many components. For sensitive tasks like predicting ADHD, even small changes in feature space might matter.
#
# Explaining the Targets:
#
# For your multi-target prediction problem, it's important to check how the principal components correlate with ADHD_Outcome and Sex_F. PCA might create components that are not directly related to the targets, making your model performance worse.

# %%
X_train = cleaned_fcm.drop(columns=['participant_id'])
X_test = test_fcm.drop(columns=['participant_id'])

pca = PCA(n_components=0.95, svd_solver='full')  # Or set fixed number, like PCA(n_components=300)

X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)

train_fcm_pca = pd.DataFrame(X_train_pca)
train_fcm_pca['participant_id'] = cleaned_fcm['participant_id'].values

test_fcm_pca = pd.DataFrame(X_test_pca)
test_fcm_pca['participant_id'] = test_fcm['participant_id'].values

# %%
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.grid(True)
plt.show()

# %%
print("Number of PCA components:", train_fcm_pca.shape[1] - 1)
# Out:
# Number of PCA components: 818

# %% [markdown]
# # 4. Train Test Split

# %%
cleaned_fcm.info()
test_fcm.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1090 entries, 0 to 1212
# Columns: 13036 entries, participant_id to 198throw_199thcolumn
# dtypes: float64(13035), str(1)
# memory usage: 108.4 MB
# <class 'pandas.DataFrame'>
# RangeIndex: 304 entries, 0 to 303
# Columns: 13036 entries, participant_id to 198throw_199thcolumn
# dtypes: float64(13035), str(1)
# memory usage: 30.2 MB

# %%
train_fcm_pca.info()
test_fcm_pca.info()
train_sol.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1090 entries, 0 to 1089
# Columns: 819 entries, 0 to participant_id
# dtypes: float64(818), str(1)
# memory usage: 6.8 MB
# <class 'pandas.DataFrame'>
# RangeIndex: 304 entries, 0 to 303
# Columns: 819 entries, 0 to participant_id
# dtypes: float64(818), str(1)
# memory usage: 1.9 MB
# <class 'pandas.DataFrame'>
# Index: 1090 entries, 0 to 1212
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   participant_id  1090 non-null   str
#  1   ADHD_Outcome    1090 non-null   int64
#  2   Sex_F           1090 non-null   int64
# dtypes: int64(2), str(1)
# memory usage: 34.1 KB

# %%
# دمج كل مصادر الـ features مع بعض: PCA components (connectome) + البيانات الديموغرافية (train_cat) + البيانات الكمية/السلوكية زي SDQ/APQ (scaled_train_quan)
# ده التعديل الأساسي: قبل كده كان بيتم الاعتماد بس على train_fcm_pca واللي بيانات المخ فيها ضعيفة الارتباط بالـ target،
# وكانت بتتجاهل أقوى الأعمدة اللي ظهرت في الـ EDA (SDQ_Hyperactivity, SDQ_Externalizing, SDQ_Difficulties_Total)
df_pca = train_fcm_pca.merge(train_cat, on='participant_id') \
                       .merge(scaled_train_quan, on='participant_id') \
                       .merge(train_sol, on='participant_id')

# Drop participant_id to get the features and target variables
X = df_pca.drop(columns=['participant_id', 'ADHD_Outcome', 'Sex_F'])
y = df_pca[['ADHD_Outcome', 'Sex_F']]

# %%
# نفس الدمج لكن مع الـ connectome الخام (من غير PCA) لو حابة تقارني الأداء بين النسخة المختصرة (PCA) والنسخة الكاملة
full_df = cleaned_fcm.merge(train_cat, on='participant_id') \
                      .merge(scaled_train_quan, on='participant_id') \
                      .merge(train_sol, on='participant_id')

# Drop participant_id to get the features and target variables
X_full = full_df.drop(columns=['participant_id', 'ADHD_Outcome', 'Sex_F'])
y_full = full_df[['ADHD_Outcome', 'Sex_F']]

# %%
# Create a combined stratification column
stratify_col = y['Sex_F'].astype(str) + "_" + y['ADHD_Outcome'].astype(str)

# %%
# Split X and y, stratify on ADHD outcome
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123, stratify=stratify_col)

# %%
# Split X and y, stratify on ADHD outcome
X_train_full, X_test_full, y_train_full, y_test_full = train_test_split(X_full, y_full, test_size=0.2, random_state=123, stratify=stratify_col)

# %%
# ADHD outcome
y_train_adhd = y_train['ADHD_Outcome']
y_test_adhd = y_test['ADHD_Outcome']

# Sex
y_train_sex = y_train['Sex_F']
y_test_sex = y_test['Sex_F']

# %%
print("Feature data with PCA:")
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)

print("\nCombined target data:")
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)

print("\nIndividual target variables:")
print("y_train_adhd shape:", y_train_adhd.shape)
print("y_test_adhd shape:", y_test_adhd.shape)

print("y_train_sex shape:", y_train_sex.shape)
print("y_test_sex shape:", y_test_sex.shape)

print("\nFeature data - NO PCA:")
print("X_train shape:", X_train_full.shape)
print("X_test shape:", X_test_full.shape)

print("\nCombined target data:")
print("y_train shape:", y_train_full.shape)
print("y_test shape:", y_test_full.shape)
# Out:
# Feature data with PCA:
# X_train shape: (872, 840)
# X_test shape: (218, 840)
#
# Combined target data:
# y_train shape: (872, 2)
# y_test shape: (218, 2)
#
# Individual target variables:
# y_train_adhd shape: (872,)
# y_test_adhd shape: (218,)
# y_train_sex shape: (872,)
# y_test_sex shape: (218,)
#
# Feature data - NO PCA:
# X_train shape: (872, 13057)
# X_test shape: (218, 13057)
#
# Combined target data:
# y_train shape: (872, 2)
# y_test shape: (218, 2)

# %% [markdown]
# # 5. Data Export

# %%
import os

# Create the directories if they don't exist
os.makedirs('../data/processed', exist_ok=True)
os.makedirs('../data/processed/model', exist_ok=True)

# Export train datasets
train_cat.to_csv('../data/processed/train_cat_processed.csv', index=False)
train_fcm_pca.to_csv('../data/processed/train_fcm_pca.csv', index=False)
scaled_train_quan.to_csv('../data/processed/scaled_train_quan.csv', index=False)
train_sol.to_csv('../data/processed/train_sol.csv', index=False)

# Export test datasets
test_cat.to_csv('../data/processed/test_cat_processed.csv', index=False)
test_fcm_pca.to_csv('../data/processed/test_fcm_pca.csv', index=False)
scaled_test_quan.to_csv('../data/processed/scaled_test_quan.csv', index=False)

cleaned_fcm.to_csv('../data/processed/train_fcm_full.csv', index=False)
test_fcm.to_csv('../data/processed/test_fcm_full.csv', index=False)

# %% [markdown]
# Exporting data for model:

# %%
# Export feature splits
X_train.to_csv("../data/processed/model/X_train.csv", index=False)
X_test.to_csv("../data/processed/model/X_test.csv", index=False)

# %%
# Export combined targets
y_train.to_csv("../data/processed/model/y_train.csv", index=False)
y_test.to_csv("../data/processed/model/y_test.csv", index=False)

# %% [markdown]
# Let's have also train_full:

# %%
# Export feature splits
X_train_full.to_csv("../data/processed/model/X_train_full.csv", index=False)
X_test_full.to_csv("../data/processed/model/X_test_full.csv", index=False)

# %%
# Export combined targets
y_train_full.to_csv("../data/processed/model/y_train_full.csv", index=False)
y_test_full.to_csv("../data/processed/model/y_test_full.csv", index=False)

# %% [markdown]
# Seperate target datatabases

# %%
# Export individual targets
y_train_adhd.to_csv("../data/processed/model/y_train_adhd.csv", index=False)
y_test_adhd.to_csv("../data/processed/model/y_test_adhd.csv", index=False)

y_train_sex.to_csv("../data/processed/model/y_train_sex.csv", index=False)
y_test_sex.to_csv("../data/processed/model/y_test_sex.csv", index=False)

# %%
import os

save_path = "../data/processed/model"

os.makedirs(save_path, exist_ok=True)

# %%
X_train.to_csv(
    "../data/processed/model/X_train.csv",
    index=False
)

X_test.to_csv(
    "../data/processed/model/X_test.csv",
    index=False
)

# %%
y_train.to_csv(
    "../data/processed/model/y_train.csv",
    index=False
)

y_test.to_csv(
    "../data/processed/model/y_test.csv",
    index=False
)

# %%
import shutil

shutil.make_archive(
    "processed_model",
    'zip',
    "../data/processed/model"
)
# Out:
# 'c:\\Users\\Admin\\Downloads\\processed_model.zip'
